# %% [markdown]
# # Análisis de Precios de Artículos de Invierno de Zara
# ## Autor: Julyanna J. Beiner
# ## Fecha: 01/10/2024

# %% [markdown]
# ## Introducción
# En este proyecto, analizamos los precios de una colección de artículos de Zara para determinar si el precio promedio supera los 50 euros  :)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url= "https://www.zara.com/"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}


response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("Conexión exitosa")
else:
    print("Error en la conexión:", response.status_code)
# Out:
# Conexión exitosa

# %%
url = "https://www.zara.com/es/es/mujer-prendas-exterior-l1184.html?v1=2419032&regionGroupId=110"  
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# %%
response = requests.get(url, headers=headers)

# %%
if response.status_code == 200:
    print('Conexión exitosa')
else:
    print('Error en la conexión', response.status_code)
# Out:
# Conexión exitosa

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
product_prices = []
product_colores = []
product_materiales = []

# %%
images = soup.find_all('img', class_='media-image__image media__wrapper--media')

# %%
product_names = []
for img in images[:30]:  
    product_name = img.get('alt', 'Nombre no encontrado')  
    product_names.append(product_name)

# %%
product_names
# Out:
# ['ANORAK WATER AND WIND PROTECTION - Negro de Zara',
#  'ABRIGO CORTO DOBLE FAZ 100% PIEL - Tostado de Zara',
#  'ABRIGO CORTO DOBLE FAZ 100% PIEL - Tostado de Zara',
#  'ABRIGO CORTO EFECTO PELO - Marrón / Topo de Zara',
#  'PLUMÍFERO CAPUCHA WATER AND WIND PROTECTION - Negro de Zara',
#  'ANORAK LARGO CAPUCHA WATER REPELLENT - Negro de Zara',
#  'PLUMÍFERO CAPUCHA WATER AND WIND PROTECTION - Khaki de Zara',
#  'ABRIGO LARGO EFECTO PELO - Gris topo de Zara',
#  'ABRIGO CON LANA CINTURÓN ZW COLLECTION - Khaki de Zara',
#  'ABRIGO LARGO PUNTO OCHOS - Crudo de Zara',
#  'ABRIGO MEZCLA LANA ZW COLLECTION - Burgundy de Zara',
#  'CHAQUETA ACOLCHADA ZW COLLECTION - Crudo de Zara',
#  'ANORAK ACOLCHADO CORTO WATER AND WIND PROTECTION - Crudo de Zara',
#  'ABRIGO OVERSIZE SOFT - Negro de Zara',
#  'ABRIGO OVERSIZE SOFT - Gris de Zara',
#  'ABRIGO COMBINADO LANA ZW COLLECTION - Gris medio de Zara',
#  'ABRIGO LANA 100% ZW COLLECTION - Tostado de Zara',
# ...

# %%
product_links = []

# %%
for product in soup.find_all('a', class_='product-link', limit=30):
    link = product['href']
    product_links.append(link)

# %%
for link in product_links:
    print(link)
# Out:
# https://www.zara.com/es/es/anorak-water-and-wind-protection-p04749740.html
# https://www.zara.com/es/es/abrigo-corto-doble-faz-100-piel-p01814200.html
# https://www.zara.com/es/es/abrigo-corto-doble-faz-100-piel-p01814200.html
# https://www.zara.com/es/es/abrigo-corto-efecto-pelo-p05854221.html
# https://www.zara.com/es/es/plumifero-capucha-water-and-wind-protection-p03046235.html
# https://www.zara.com/es/es/anorak-largo-capucha-water-repellent-p08372226.html
# https://www.zara.com/es/es/plumifero-capucha-water-and-wind-protection-p03046235.html
# https://www.zara.com/es/es/abrigo-largo-efecto-pelo-p06318243.html
# https://www.zara.com/es/es/abrigo-con-lana-cinturon-zw-collection-p03811241.html
# https://www.zara.com/es/es/abrigo-largo-punto-ochos-p03653109.html
# https://www.zara.com/es/es/abrigo-mezcla-lana-zw-collection-p09231756.html
# https://www.zara.com/es/es/chaqueta-acolchada-zw-collection-p00518259.html
# ...

# %%
product_links = [
    "https://www.zara.com/es/es/abrigo-efecto-pelo-p06318242.html",
    "https://www.zara.com/es/es/abrigo-cruzado-bolsillos-p06318238.html",
    "https://www.zara.com/es/es/abrigo-soft-p08073259.html",
    "https://www.zara.com/es/es/abrigo-corto-efecto-pelo-p06318270.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/abrigo-largo-con-lana-p09731147.html",
    "https://www.zara.com/es/es/abrigo-cruzado-con-lana-p09094141.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-con-lana-p09225147.html",
    "https://www.zara.com/es/es/abrigo-cinturon-con-lana-p03046341.html",
    "https://www.zara.com/es/es/abrigo-boucle-con-lana-manteco-zw-collection-p09543778.html",
    "https://www.zara.com/es/es/abrigo-entallado-mezcla-lana-zw-collection-p09047632.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/anorak-acolchado-punto-p06318229.html",
    "https://www.zara.com/es/es/chaleco-acolchado-punto-p06318224.html",
    "https://www.zara.com/es/es/abrigo-largo-borreguillo-p01255856.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518257.html",
    "https://www.zara.com/es/es/abrigo-efecto-pelo-joyas-zw-collection-p04360248.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518259.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-p03046353.html"
]


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive'
}


for product_link in product_links:
    
    response = requests.get(product_link, headers=headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        
        description = soup.find('p').get_text(strip=True)  
        print(f"Descripción del producto: {description}")
    else:
        print(f"Error al acceder a {product_link}: {response.status_code}")
# Out:
# Descripción del producto: Abrigo de cuello solapa y manga larga. Bolsillos delanteros. Cierre frontal con corchete oculto.
# Descripción del producto: Abrigo de cuello solapa y manga larga. Bolsillos delanteros de vivo y bolsillos con solapa. Cierre frontal cruzado con botones.
# Descripción del producto: Abrigo de cuello solapa y manga larga. Bolsillos delanteros de vivo. Cierre frontal con botones.
# Descripción del producto: Abrigo con capucha y manga larga. Bolsillos laterales ocultos en costura. Cierre frontal con botones a presión ocultos.
# Descripción del producto: Anorak acolchado resistente al agua y al viento con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (1,8º) y actividad moderada (-31,7ºC). Cuello subido con capucha ajustable con cordones elásticos y manga larga. Bolsillos delanteros con forro polar interior. Cierre frontal con cremallera.
# ...

# %%
product_links = [
    "https://www.zara.com/es/es/abrigo-efecto-pelo-p06318242.html",
    "https://www.zara.com/es/es/abrigo-cruzado-bolsillos-p06318238.html",
    "https://www.zara.com/es/es/abrigo-soft-p08073259.html",
    "https://www.zara.com/es/es/abrigo-corto-efecto-pelo-p06318270.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/abrigo-largo-con-lana-p09731147.html",
    "https://www.zara.com/es/es/abrigo-cruzado-con-lana-p09094141.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-con-lana-p09225147.html",
    "https://www.zara.com/es/es/abrigo-cinturon-con-lana-p03046341.html",
    "https://www.zara.com/es/es/abrigo-boucle-con-lana-manteco-zw-collection-p09543778.html",
    "https://www.zara.com/es/es/abrigo-entallado-mezcla-lana-zw-collection-p09047632.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/anorak-acolchado-punto-p06318229.html",
    "https://www.zara.com/es/es/chaleco-acolchado-punto-p06318224.html",
    "https://www.zara.com/es/es/abrigo-largo-borreguillo-p01255856.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518257.html",
    "https://www.zara.com/es/es/abrigo-efecto-pelo-joyas-zw-collection-p04360248.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518259.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-p03046353.html"
    
]

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive'
}


for product_link in product_links:
    
    response = requests.get(product_link, headers=headers)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        
        color_element = soup.find('p', class_='product-color-extended-name')
        color = color_element.get_text(strip=True) if color_element else 'Color no encontrado'
        print(f"Color del producto: {color}")

    else:
        print(f"Error al acceder a {product_link}: {response.status_code}")
# Out:
# Color del producto: Crudo | 6318/242
# Color del producto: Rojo | 6318/238
# Color del producto: Tostado | 8073/259
# Color del producto: Camel claro | 6318/270
# Color del producto: Negro | 8073/225
# Color del producto: Negro | 8073/225
# Color del producto: Negro | 9731/147
# Color del producto: Negro | 9094/141
# Color del producto: Negro | 9225/147
# Color del producto: Negro | 3046/341
# Color del producto: Gris topo | 9543/778
# Color del producto: Blanco | 9047/632
# Color del producto: Color:Negro | 3046/299
# Color del producto: Color:Negro | 3046/299
# Color del producto: Color:Negro | 3046/299
# Color del producto: Crudo | 6318/229
# Color del producto: Crudo | 6318/224
# Color del producto: Color:Negro | 1255/856
# Color del producto: Color:Crudo | 3046/241
# Color del producto: Color:Crudo | 3046/241
# Color del producto: Color:Crudo | 3046/241
# Color del producto: Negro | 0518/257
# Color del producto: Negro | 4360/248
# Color del producto: Color:Negro | 0518/259
# ...

# %%
urls = [
    'https://www.zara.com/es/es/abrigo-efecto-pelo-p06318242.html',
    'https://www.zara.com/es/es/abrigo-cruzado-bolsillos-p06318238.html',
    'https://www.zara.com/es/es/abrigo-soft-p08073259.html',
    "https://www.zara.com/es/es/abrigo-corto-efecto-pelo-p06318270.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html",
    "https://www.zara.com/es/es/abrigo-largo-con-lana-p09731147.html",
    "https://www.zara.com/es/es/abrigo-cruzado-con-lana-p09094141.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-con-lana-p09225147.html",
    "https://www.zara.com/es/es/abrigo-cinturon-con-lana-p03046341.html",
    "https://www.zara.com/es/es/abrigo-boucle-con-lana-manteco-zw-collection-p09543778.html",
    "https://www.zara.com/es/es/abrigo-entallado-mezcla-lana-zw-collection-p09047632.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/abrigo-oversize-soft-p03046299.html",
    "https://www.zara.com/es/es/anorak-acolchado-punto-p06318229.html",
    "https://www.zara.com/es/es/chaleco-acolchado-punto-p06318224.html",
    "https://www.zara.com/es/es/abrigo-largo-borreguillo-p01255856.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/anorak-acolchado-corto-water-and-wind-protection-p03046241.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518257.html",
    "https://www.zara.com/es/es/abrigo-efecto-pelo-joyas-zw-collection-p04360248.html",
    "https://www.zara.com/es/es/chaqueta-acolchada-water-repellent-zw-collection-p00518259.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/abrigo-soft-cinturon-capucha-p03046328.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/anorak-acolchado-capucha-windproof-p03046225.html",
    "https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-p03046353.html"
]


def extract_price(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36'
    }
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        
        price_span = soup.find('span', class_='money-amount__main')

        if price_span:
            return price_span.get_text(strip=True)
        else:
            return 'Precio no encontrado.'
    else:
        return f'Error al acceder a la página: {response.status_code}'


for url in urls:
    price = extract_price(url)
    print(f'Precio para {url}: {price}')
# Out:
# Precio para https://www.zara.com/es/es/abrigo-efecto-pelo-p06318242.html: 89,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-cruzado-bolsillos-p06318238.html: 49,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-soft-p08073259.html: 39,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-corto-efecto-pelo-p06318270.html: 49,95 EUR
# Precio para https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html: 69,95 EUR
# Precio para https://www.zara.com/es/es/anorak-reversible-largo-water-and-wind-protection-p08073225.html: 69,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-largo-con-lana-p09731147.html: 99,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-cruzado-con-lana-p09094141.html: 69,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-solapa-efecto-pelo-con-lana-p09225147.html: 99,95 EUR
# Precio para https://www.zara.com/es/es/abrigo-cinturon-con-lana-p03046341.html: 49,95 EUR
# ...

# %% [markdown]
# ### Ahora haremos lo mismo con pantalones

# %%
url2= "https://www.zara.com/es/es/mujer-pantalones-l1335.html?v1=2420795&regionGroupId=110"  
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
url2 = "https://www.zara.com/es/es/mujer-pantalones-l1335.html?v1=2420795&regionGroupId=110"  
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-pantalones-l1335.html?v1=2420795&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    images = soup.find_all('img', class_='media-image__image media__wrapper--media')

   
    pant_names = []
    for img in images[:30]:  
        pant_name = img.get('alt', 'Nombre no encontrado')  
        pant_names.append(pant_name)

  
    for name in pant_names:
        print(name)
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# PANTALÓN LARGO EVASÉ - Gris antracita de Zara
# PANTALÓN RECTO PUNTO BOTONES LATERALES - Negro de Zara
# PANTALÓN TOBILLERO BRILLOS - Negro de Zara
# PANTALÓN RECTO EFECTO PIEL - Negro de Zara
# PANTALÓN RECTO PUNTO - Marrón oscuro de Zara
# PANTALÓN PINZAS BAJO AJUSTABLE - Negro de Zara
# PANTALÓN ANCHO CINTURÓN - Gris de Zara
# PANTALÓN RECTO EFECTO PIEL - Negro de Zara
# PANTALÓN ESTAMPADO LONG LENGTH - Negro / Verde de Zara
# PANTALÓN ANCHO CINTURÓN - Gris de Zara
# PANTALÓN TIRO ALTO - Gris antracita de Zara
# PANTALÓN TOBILLERO SOFT - Negro de Zara
# PANTALÓN ANCHO ESTRUCTURA - Negro de Zara
# PANTALÓN RECTO ZW COLLECTION - Khaki oscuro de Zara
# PANTALÓN TOBILLERO PINZAS ZW COLLECTION - Gris topo de Zara
# PANTALÓN SOFT - Beige vigoré de Zara
# PANTALÓN SOFT - Gris vigoré de Zara
# PANTALÓN SATINADO PESPUNTES ZW COLLECTION - Negro de Zara
# PANTALÓN FELPA TEXTO BANDA LATERAL - Marino de Zara
# PANTALÓN BARREL BOTÓN BAJO - Negro de Zara
# ...

# %%
response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    pant_details = []
    for product in products[:30]:  
        pant_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        product_link = product.get('href')
        pant_details.append((pant_name, product_link))

    
    for name, link in pant_details:
        print(f"Nombre: {name}, Enlace: {link}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: PANTALÓN LARGO EVASÉ - Gris antracita de Zara, Enlace: https://www.zara.com/es/es/pantalon-largo-evase-p01223456.html
# Nombre: PANTALÓN RECTO PUNTO BOTONES LATERALES - Negro de Zara, Enlace: https://www.zara.com/es/es/pantalon-recto-punto-botones-laterales-p04192126.html
# Nombre: PANTALÓN TOBILLERO BRILLOS - Negro de Zara, Enlace: https://www.zara.com/es/es/pantalon-tobillero-brillos-p01689499.html
# Nombre: PANTALÓN RECTO EFECTO PIEL - Negro de Zara, Enlace: https://www.zara.com/es/es/pantalon-recto-efecto-piel-p08372330.html
# Nombre: PANTALÓN RECTO PUNTO - Marrón oscuro de Zara, Enlace: https://www.zara.com/es/es/pantalon-recto-punto-p00234108.html
# Nombre: PANTALÓN PINZAS BAJO AJUSTABLE - Negro de Zara, Enlace: https://www.zara.com/es/es/pantalon-pinzas-bajo-ajustable-p01689226.html
# Nombre: PANTALÓN ANCHO CINTURÓN - Gris de Zara, Enlace: https://www.zara.com/es/es/pantalon-ancho-cinturon-p04387275.html
# ...

# %%
product_links = [
    "https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html",
     "https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html",
     "https://www.zara.com/es/es/pantalon-tiro-alto-p01608431.html",
 "https://www.zara.com/es/es/pantalon-pijamero-franela-p08372417.html",
 "https://www.zara.com/es/es/pantalon-recto-pana-p05030508.html",
 "https://www.zara.com/es/es/pantalon-pijamero-terciopelo-p04391524.html",
 "https://www.zara.com/es/es/pantalon-efecto-moire-zw-collection-p09302096.html",
 "https://www.zara.com/es/es/pantalon-ancho-punto-p05536174.html",
 "https://www.zara.com/es/es/pantalon-cinturon-zw-collection-p09479272.html",
 "https://www.zara.com/es/es/pantalon-flare-terciopelo-zw-collection-p02731270.html",
 "https://www.zara.com/es/es/pantalon-combinado-tricot-p05644988.html",
 "https://www.zara.com/es/es/pantalon-combinado-p02298991.html",
 "https://www.zara.com/es/es/pantalon-jogger-varsity-efecto-lavado-p03253838.html",
 "https://www.zara.com/es/es/pantalon-jogger-varsity-efecto-lavado-p03253833.html",
 "https://www.zara.com/es/es/pantalon-pliegues-p05427525.html",
 "https://www.zara.com/es/es/pantalon-doble-pliegue-p01255506.html",
 "https://www.zara.com/es/es/leggings-botones-joya-tiro-medio-p08372298.html",
 "https://www.zara.com/es/es/pantalon-recto-brillo-p09011569.html",
 "https://www.zara.com/es/es/leggings-encaje-p01067932.html",
 "https://www.zara.com/es/es/pantalon-pliegues-p01255539.html",
 "https://www.zara.com/es/es/pantalon-franela-raya-diplomatica-p06929521.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p04661519.html",
 "https://www.zara.com/es/es/pantalon-franela-rayas-cordon-p06929516.html",
 "https://www.zara.com/es/es/pantalon-canale-soft-p00264677.html",
 "https://www.zara.com/es/es/pantalon-satinado-banda-lateral-p04661538.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p03152512.html",
 "https://www.zara.com/es/es/pantalon-banda-lateral-p03067525.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p03152512.html",
 "https://www.zara.com/es/es/leggings-lana-100-p01223919.html",
 "https://www.zara.com/es/es/leggings-lana-100-p01223919.html"
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36"
}

for link in product_links[:30]:  
    response = requests.get(link, headers=headers)  

    if response.status_code == 200:
        product_soup = BeautifulSoup(response.text, 'html.parser')

        
        price = product_soup.find('span', class_='money-amount__main')

        if price:
            print(f"Precio del producto en {link}: {price.get_text(strip=True)}")  
        else:
            print(f"No se encontró el precio para {link}.")
    else:
        print(f"Error al acceder a la página del producto: {link} - {response.status_code}")
# Out:
# Precio del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: 29,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: 29,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-tiro-alto-p01608431.html: 25,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-pijamero-franela-p08372417.html: 25,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-recto-pana-p05030508.html: 29,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-pijamero-terciopelo-p04391524.html: 29,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-efecto-moire-zw-collection-p09302096.html: 39,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-ancho-punto-p05536174.html: 29,95 EUR
# Precio del producto en https://www.zara.com/es/es/pantalon-cinturon-zw-collection-p09479272.html: 35,95 EUR
# ...

# %%
product_links = [
    "https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html",
     "https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html",
     "https://www.zara.com/es/es/pantalon-tiro-alto-p01608431.html",
 "https://www.zara.com/es/es/pantalon-pijamero-franela-p08372417.html",
 "https://www.zara.com/es/es/pantalon-recto-pana-p05030508.html",
 "https://www.zara.com/es/es/pantalon-pijamero-terciopelo-p04391524.html",
 "https://www.zara.com/es/es/pantalon-efecto-moire-zw-collection-p09302096.html",
 "https://www.zara.com/es/es/pantalon-ancho-punto-p05536174.html",
 "https://www.zara.com/es/es/pantalon-cinturon-zw-collection-p09479272.html",
 "https://www.zara.com/es/es/pantalon-flare-terciopelo-zw-collection-p02731270.html",
 "https://www.zara.com/es/es/pantalon-combinado-tricot-p05644988.html",
 "https://www.zara.com/es/es/pantalon-combinado-p02298991.html",
 "https://www.zara.com/es/es/pantalon-jogger-varsity-efecto-lavado-p03253838.html",
 "https://www.zara.com/es/es/pantalon-jogger-varsity-efecto-lavado-p03253833.html",
 "https://www.zara.com/es/es/pantalon-pliegues-p05427525.html",
 "https://www.zara.com/es/es/pantalon-doble-pliegue-p01255506.html",
 "https://www.zara.com/es/es/leggings-botones-joya-tiro-medio-p08372298.html",
 "https://www.zara.com/es/es/pantalon-recto-brillo-p09011569.html",
 "https://www.zara.com/es/es/leggings-encaje-p01067932.html",
 "https://www.zara.com/es/es/pantalon-pliegues-p01255539.html",
 "https://www.zara.com/es/es/pantalon-franela-raya-diplomatica-p06929521.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p04661519.html",
 "https://www.zara.com/es/es/pantalon-franela-rayas-cordon-p06929516.html",
 "https://www.zara.com/es/es/pantalon-canale-soft-p00264677.html",
 "https://www.zara.com/es/es/pantalon-satinado-banda-lateral-p04661538.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p03152512.html",
 "https://www.zara.com/es/es/pantalon-banda-lateral-p03067525.html",
 "https://www.zara.com/es/es/pantalon-raya-diplomatica-boxer-p03152512.html",
 "https://www.zara.com/es/es/leggings-lana-100-p01223919.html",
 "https://www.zara.com/es/es/leggings-lana-100-p01223919.html"
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36"
}

for link in product_links[:30]:
    response = requests.get(link, headers=headers)  

    if response.status_code == 200:
        product_soup = BeautifulSoup(response.text, 'html.parser')

       
        color_elements = product_soup.find_all('li', class_='product-detail-color-selector__color')
        
        colors = []
        for color in color_elements:
            color_name = color.find('span', class_='screen-reader-text')
            if color_name:
                colors.append(color_name.get_text(strip=True))  

        if colors:
            print(f"Colores del producto en {link}: {', '.join(colors)}")  
        else:
            print(f"No se encontraron colores para {link}.")
    else:
        print(f"Error al acceder a la página del producto: {link} - {response.status_code}")
# Out:
# Colores del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: Arena, Negro, Gris, marino, Gris Antracita
# Colores del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: Arena, Negro, Gris, marino, Gris Antracita
# Colores del producto en https://www.zara.com/es/es/pantalon-tiro-alto-p01608431.html: Tostado, Gris antracita
# Colores del producto en https://www.zara.com/es/es/pantalon-pijamero-franela-p08372417.html: Negro, Gris vigoré
# No se encontraron colores para https://www.zara.com/es/es/pantalon-recto-pana-p05030508.html.
# No se encontraron colores para https://www.zara.com/es/es/pantalon-pijamero-terciopelo-p04391524.html.
# No se encontraron colores para https://www.zara.com/es/es/pantalon-efecto-moire-zw-collection-p09302096.html.
# No se encontraron colores para https://www.zara.com/es/es/pantalon-ancho-punto-p05536174.html.
# ...

# %%
for link in product_links[:30]:  
    response = requests.get(link, headers=headers)  

    if response.status_code == 200:
        product_soup = BeautifulSoup(response.text, 'html.parser')

        # Encuentra la descripción del producto
        description_element = product_soup.find('p')  
        
        if description_element:
            product_description = description_element.get_text(strip=True)  
            print(f"Descripción del producto en {link}: {product_description}")  
        else:
            print(f"No se encontró la descripción para {link}.")
    else:
        print(f"Error al acceder a la página del producto: {link} - {response.status_code}")
# Out:
# Descripción del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.
# Descripción del producto en https://www.zara.com/es/es/pantalon-ancho-cintura-doble-p01608225.html: Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.
# Descripción del producto en https://www.zara.com/es/es/pantalon-tiro-alto-p01608431.html: Pantalón tobillero de tiro alto con detalle de costuras marcadas en delantero y espalda. Bolsillos delanteros de vivo. Cierre frontal con cremallera, botón interior y gancho metálico.
# ...

# %% [markdown]
# ### Ahora Vestidos

# %%
url = 'https://www.zara.com/es/es/mujer-vestidos-l1066.html?v1=2420896&regionGroupId=110'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}


response = requests.get(url, headers=headers)

if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    
    images = soup.find_all('img', class_='media-image__image media__wrapper--media')
    
    
    dress_names = []

   
    for img in images[:30]:
        dress_name = img.get('alt', 'Nombre no encontrado')  
        dress_names.append(dress_name)

   
    for name in dress_names:
        print(name)
else:
    print("Error al acceder a la página:", response.status_code)
# Out:
# VESTIDO MIDI PUNTO LISO - Azul pato de Zara
# VESTIDO SKATER PUNTO STRETCH - Burgundy de Zara
# VESTIDO CORTO PUNTO SOFT - Marrón / Topo de Zara
# VESTIDO INTERLOCK - Beige de Zara
# VESTIDO INTERLOCK - Marrón de Zara
# VESTIDO INTERLOCK - Negro de Zara
# VESTIDO CORTO VUELO - Negro de Zara
# VESTIDO CORTO BAJO VUELO - Burgundy de Zara
# VESTIDO MIDI DRAPEADO - Marrón de Zara
# VESTIDO MIDI ESCOTE PICO - Gris de Zara
# VESTIDO MINI PUNTO - Negro de Zara
# VESTIDO CORTO ESTRUCTURA - Marrón / Crudo de Zara
# VESTIDO CORTO ESTRUCTURA - Negro / Blanco de Zara
# VESTIDO CORTO ESTRUCTURA - Negro de Zara
# VESTIDO MIDI TERCIOPELO - Verde azul de Zara
# VESTIDO MULTIPOSICIÓN LENTEJUELAS ZW COLLECTION - Crudo de Zara
# VESTIDO SATINADO CONTRASTE ZW COLLECTION - Negro de Zara
# VESTIDO CORTO TABLAS - Negro de Zara
# VESTIDO CORTO EFECTO ANTE - Negro de Zara
# VESTIDO CUADROS FRANELA - Crudo / Negro de Zara
# MONO LARGO PANA - Rosa de Zara
# VESTIDO DENIM TRF FLOCK - Negro de Zara
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.zara.com/es/es/mujer-vestidos-l1066.html?v1=2420896&regionGroupId=110"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
}

response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    prices = []

    
    for product in products[:30]:  
        product_link = product.get('href')  
        if product_link:
            
            product_response = requests.get(product_link, headers=headers)
            if product_response.status_code == 200:
                product_soup = BeautifulSoup(product_response.text, 'html.parser')
                
                price_element = product_soup.find('span', class_='money-amount__main')
                if price_element:
                    price = price_element.get_text(strip=True)  
                    prices.append(price)
                else:
                    prices.append('Precio no encontrado')
            else:
                prices.append('Error al acceder al producto')
        else:
            prices.append('Enlace no encontrado')

    
    for price in prices:
        print(f"Precio: {price}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Precio: 39,95 EUR
# Precio: 22,95 EUR
# Precio: 29,95 EUR
# Precio: 22,95 EUR
# Precio: 22,95 EUR
# Precio: 22,95 EUR
# Precio: 35,95 EUR
# Precio: 35,95 EUR
# Precio: 29,95 EUR
# Precio: 27,95 EUR
# Precio: 25,95 EUR
# Precio: 29,95 EUR
# Precio: 22,95 EUR
# Precio: 22,95 EUR
# Precio: 22,95 EUR
# Precio: 29,95 EUR
# Precio: 69,95 EUR
# Precio: 39,95 EUR
# Precio: 35,95 EUR
# Precio: 35,95 EUR
# Precio: 39,95 EUR
# Precio: 39,95 EUR
# Precio: 49,95 EUR
# Precio: 69,95 EUR
# Precio: 59,95 EUR
# Precio: 29,95 EUR
# Precio: 59,95 EUR
# Precio: 69,95 EUR
# Precio: 35,95 EUR
# Precio: 35,95 EUR

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-vestidos-l1066.html?v1=2420896&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    descriptions = []
    for product in products[:30]:  
        
        product_link = product.get('href')
        
        
        product_response = requests.get(product_link, headers=headers)
        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            description_element = product_soup.find('p')
            
            if description_element:
                product_description = description_element.get_text(strip=True)  
                descriptions.append((product_link, product_description))
            else:
                descriptions.append((product_link, "Descripción no encontrada"))
        else:
            descriptions.append((product_link, f"Error al acceder: {product_response.status_code}"))

    
    for link, description in descriptions:
        print(f"Enlace: {link}, Descripción: {description}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Enlace: https://www.zara.com/es/es/vestido-midi-punto-liso-p02142222.html, Descripción: Vestido de cuello barco y manga larga con aplique dorado en hombro.
# Enlace: https://www.zara.com/es/es/vestido-skater-punto-stretch-p05584670.html, Descripción: Vestido corto confeccionado en tejido tipo punto. Cuello redondo y manga sisa. Bajo acabado en vuelo.
# Enlace: https://www.zara.com/es/es/vestido-corto-punto-soft-p05536148.html, Descripción: Vestido de cuello redondo y manga larga. Acabados en rib.
# Enlace: https://www.zara.com/es/es/vestido-interlock-p03641861.html, Descripción: Vestido confeccionado en tejido de punto elástico y flexible con trama compacta, mullida y opaca. Cuello redondo y manga por el codo. Bajo acabado en vuelo. Cierre en espalda con cremallera oculta en costura.
# ...

# %% [markdown]
# ### Info Jerseys

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-punto-l1152.html?v1=2419844&regionGroupId=110"


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    jersey_details = []
    for product in products[:30]:  
        jersey_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        product_link = product.get('href')
        jersey_details.append((jersey_name, product_link))

    
    for name, link in jersey_details:
        print(f"Nombre: {name}, Enlace: {link}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: CHAQUETA PUNTO JACQUARD ANIMAL - tigre de Zara, Enlace: https://www.zara.com/es/es/chaqueta-punto-jacquard-animal-p05755161.html
# Nombre: JERSEY PUNTO JACQUARD ANIMAL - crudo/kaki de Zara, Enlace: https://www.zara.com/es/es/jersey-punto-jacquard-animal-p05755160.html
# Nombre: TOP MANGA CORTA CON ALPACA Y LANA - Mostaza de Zara, Enlace: https://www.zara.com/es/es/top-manga-corta-con-alpaca-y-lana-p02488108.html
# Nombre: JERSEY PUNTO CUELLO ASIMÉTRICO - Lila de Zara, Enlace: https://www.zara.com/es/es/jersey-punto-cuello-asimetrico-p05536138.html
# Nombre: SUDADERA PUNTO JACQUARD ANIMAL - Leopardo de Zara, Enlace: https://www.zara.com/es/es/sudadera-punto-jacquard-animal-p02142195.html
# Nombre: JERSEY EFECTO PELO FLORES - Crudo de Zara, Enlace: https://www.zara.com/es/es/jersey-efecto-pelo-flores-p05063825.html
# Nombre: TOP PUNTO LAZO ORGANZA - Crudo de Zara, Enlace: https://www.zara.com/es/es/top-punto-lazo-organza-p02756126.html
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-punto-l1152.html?v1=2419844&regionGroupId=110"


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    product_links = []
    for product in products[:30]:  
        product_link = product.get('href')
        product_links.append(product_link)

    
    for link in product_links:
        print(link)
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# https://www.zara.com/es/es/chaqueta-punto-jacquard-animal-p05755161.html
# https://www.zara.com/es/es/jersey-punto-jacquard-animal-p05755160.html
# https://www.zara.com/es/es/top-manga-corta-con-alpaca-y-lana-p02488108.html
# https://www.zara.com/es/es/jersey-punto-cuello-asimetrico-p05536138.html
# https://www.zara.com/es/es/sudadera-punto-jacquard-animal-p02142195.html
# https://www.zara.com/es/es/jersey-efecto-pelo-flores-p05063825.html
# https://www.zara.com/es/es/top-punto-lazo-organza-p02756126.html
# https://www.zara.com/es/es/top-punto-lazo-organza-p02756127.html
# https://www.zara.com/es/es/jersey-punto-liso-p06771146.html
# https://www.zara.com/es/es/abrigo-largo-punto-ochos-p03653109.html
# https://www.zara.com/es/es/chaqueta-punto-jacquard-efecto-pelo-p09598195.html
# https://www.zara.com/es/es/chaqueta-oversize-punto-boton-metalico-p05536164.html
# https://www.zara.com/es/es/jersey-basico-punto-fino-p01509105.html
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-punto-l1152.html?v1=2419844&regionGroupId=110"


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    descriptions = []
    for product in products[:30]: 
        
        product_link = product.get('href')
        product_response = requests.get(product_link, headers=headers)

        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            description_element = product_soup.find('p')  
            
            if description_element:
                product_description = description_element.get_text(strip=True)  
                descriptions.append((product_link, product_description))
            else:
                descriptions.append((product_link, "Descripción no encontrada"))
        else:
            descriptions.append((product_link, f"Error al acceder al producto: {product_response.status_code}"))

    
    for link, description in descriptions:
        print(f"Enlace: {link}, Descripción: {description}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Enlace: https://www.zara.com/es/es/chaqueta-punto-jacquard-animal-p05755161.html, Descripción: Chaqueta de escote pico y manga larga. Bolsillos delanteros. Acabados en rib. Cierre frontal con botones.
# Enlace: https://www.zara.com/es/es/jersey-punto-jacquard-animal-p05755160.html, Descripción: Jersey de cuello subido y manga larga.
# Enlace: https://www.zara.com/es/es/top-manga-corta-con-alpaca-y-lana-p02488108.html, Descripción: Top confeccionado con alpaca y lana. Cuello redondo y manga corta.
# Enlace: https://www.zara.com/es/es/jersey-punto-cuello-asimetrico-p05536138.html, Descripción: Jersey de cuello con solapa asimétrica y manga larga. Botones en hombro.
# Enlace: https://www.zara.com/es/es/sudadera-punto-jacquard-animal-p02142195.html, Descripción: Sudadera oversize con capucha ajustable con cordones y manga larga. Bolsillo delantero. Acabados en rib.
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-punto-l1152.html?v1=2419844&regionGroupId=110"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    prices = []
    for product in products[:30]:  
        
        product_link = product.get('href')
        product_response = requests.get(product_link, headers=headers)

        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            price_element = product_soup.find('span', class_='money-amount__main')  
            
            if price_element:
                product_price = price_element.get_text(strip=True) 
                prices.append((product_link, product_price))
            else:
                prices.append((product_link, "Precio no encontrado"))
        else:
            prices.append((product_link, f"Error al acceder al producto: {product_response.status_code}"))

    
    for link, price in prices:
        print(f"Enlace: {link}, Precio: {price}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Enlace: https://www.zara.com/es/es/chaqueta-punto-jacquard-animal-p05755161.html, Precio: 39,95 EUR
# Enlace: https://www.zara.com/es/es/jersey-punto-jacquard-animal-p05755160.html, Precio: 29,95 EUR
# Enlace: https://www.zara.com/es/es/top-manga-corta-con-alpaca-y-lana-p02488108.html, Precio: 35,95 EUR
# Enlace: https://www.zara.com/es/es/jersey-punto-cuello-asimetrico-p05536138.html, Precio: 29,95 EUR
# Enlace: https://www.zara.com/es/es/sudadera-punto-jacquard-animal-p02142195.html, Precio: 49,95 EUR
# Enlace: https://www.zara.com/es/es/jersey-efecto-pelo-flores-p05063825.html, Precio: 25,95 EUR
# Enlace: https://www.zara.com/es/es/top-punto-lazo-organza-p02756126.html, Precio: 29,95 EUR
# Enlace: https://www.zara.com/es/es/top-punto-lazo-organza-p02756127.html, Precio: 29,95 EUR
# Enlace: https://www.zara.com/es/es/jersey-punto-liso-p06771146.html, Precio: 29,95 EUR
# Enlace: https://www.zara.com/es/es/abrigo-largo-punto-ochos-p03653109.html, Precio: 69,95 EUR
# ...

# %% [markdown]
# ### Info Camisetas

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-camisas-l1217.html?v1=2420369&regionGroupId=110"


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36'
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    product_names = []
    for product in products[:30]:  
        img_tag = product.find('img', class_='media-image__image media__wrapper--media')
        if img_tag:
            product_name = img_tag.get('alt', 'Nombre no encontrado') 
            product_names.append(product_name)

    
    for name in product_names:
        print(name)
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# CAMISA PLUMETI LAZOS - rosa claro de Zara
# BLUSA TUL ESTAMPADO - Azul de Zara
# BLUSA TUL ESTAMPADO - Negro / Arena de Zara
# BLUSA PAÑUELO ZW COLLECTION - Melocotón de Zara
# BLUSA BORDADA FRUNCES ZW COLLECTION - Marrón claro de Zara
# CAMISA BORDADOS CONTRASTE ZW COLLECTION - Blanco / Negro de Zara
# CAMISA CUADROS ZW COLLECTION - Burdeos claro de Zara
# BLUSA ROMÁNTICA ZW COLLECTION - Crudo de Zara
# CAMISA SATINADA BOLSILLOS ZW COLLECTION - Burgundy de Zara
# CAMISA Z1975 BÁSICA DENIM - Azul de Zara
# CAMISA Z1975 BÁSICA DENIM - Azul medio de Zara
# CAMISA BORDADOS CUADRO VICHY - Crudo / Negro de Zara
# BLUSA FLUIDA LAZO - Blanco de Zara
# BLUSA CUADROS LAZADA ZW COLLECTION - Blanco roto de Zara
# CAMISA RAYAS ZW COLLECTION - marron-vison de Zara
# CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de Zara
# BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro de Zara
# BLUSA VOLANTES ZW COLLECTION - Negro de Zara
# CAMISA MANGA BORDADA - Negro de Zara
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-camisas-l1217.html?v1=2420369&regionGroupId=110"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    # Crea el objeto BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-grid-product__link')

    
    product_links = []
    for product in products[:30]:  
        product_link = product.get('href')  
        product_links.append(product_link)

    
    for link in product_links:
        print(link)
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# https://www.zara.com/es/es/camisa-plumeti-lazos-p09961862.html
# https://www.zara.com/es/es/blusa-tul-estampado-p05039398.html
# https://www.zara.com/es/es/blusa-tul-estampado-p05039407.html
# https://www.zara.com/es/es/blusa-panuelo-zw-collection-p07521254.html
# https://www.zara.com/es/es/blusa-bordada-frunces-zw-collection-p07521263.html
# https://www.zara.com/es/es/camisa-bordados-contraste-zw-collection-p04437258.html
# https://www.zara.com/es/es/camisa-cuadros-zw-collection-p09626421.html
# https://www.zara.com/es/es/blusa-romantica-zw-collection-p06895267.html
# https://www.zara.com/es/es/camisa-satinada-bolsillos-zw-collection-p08987213.html
# https://www.zara.com/es/es/camisa-z1975-basica-denim-p01879221.html
# https://www.zara.com/es/es/camisa-z1975-basica-denim-p01879221.html
# https://www.zara.com/es/es/camisa-bordados-cuadro-vichy-p03564192.html
# https://www.zara.com/es/es/blusa-fluida-lazo-p04387240.html
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://www.zara.com/es/es/mujer-camisas-l1217.html?v1=2420369&regionGroupId=110'


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'Accept-Language': 'es-ES,es;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
}


response = requests.get(url, headers=headers)
if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    
    products = soup.find_all('a', class_='product-grid-product__link')  

    
    product_details = []
    
    
    for product in products[:30]:  
        
        product_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        
        
        product_link = product.get('href')
        
        
        product_response = requests.get(product_link, headers=headers)
        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            
            description_element = product_soup.find('div', class_='product-detail-description product-detail-info__description')
            if description_element:
                description = description_element.get_text(strip=True)
            else:
                description = "Descripción no encontrada"
        else:
            description = "Error al acceder a la página del producto"

        
        product_details.append((product_name, product_link, description))

    
    for name, link, desc in product_details:
        print(f"Nombre: {name}, Enlace: {link}, Descripción: {desc}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: CAMISA PLUMETI LAZOS - rosa claro de Zara, Enlace: https://www.zara.com/es/es/camisa-plumeti-lazos-p09961862.html, Descripción: Camisa de cuello solapa y manga larga. Detalle de lazos y tejido con bordados e hilo metalizado. Cierre frontal con botones ocultos por solapa.
# Nombre: BLUSA TUL ESTAMPADO - Azul de Zara, Enlace: https://www.zara.com/es/es/blusa-tul-estampado-p05039398.html, Descripción: Blusa de cuello solapa y escote pico cruzado. Manga larga. Detalle de frunces y lazada.
# Nombre: BLUSA TUL ESTAMPADO - Negro / Arena de Zara, Enlace: https://www.zara.com/es/es/blusa-tul-estampado-p05039407.html, Descripción: Blusa semitransparente de cuello subido. Manga larga y bajo acabados en volantes.
# ...

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-camisas-l1217.html?v1=2420369&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-link product-grid-product__link link')

    
    product_details = []

   
    for product in products[:30]:  
        product_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        product_link = product.get('href')

        
        product_response = requests.get(product_link, headers=headers)
        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')

            
            description_element = product_soup.find('div', class_='product-detail-info__description')
            product_description = description_element.get_text(strip=True) if description_element else 'Descripción no encontrada'

            
            price_element = product_soup.find('div', class_='product-detail-info__price')
            price = price_element.get_text(strip=True) if price_element else 'Precio no encontrado'

            
            product_details.append((product_name, product_link, product_description, price))

    
    for name, link, description, price in product_details:
        print(f"Nombre: {name}, Enlace: {link}, Descripción: {description}, Precio: {price}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: CAMISA PLUMETI LAZOS - rosa claro de Zara, Enlace: https://www.zara.com/es/es/camisa-plumeti-lazos-p09961862.html, Descripción: Camisa de cuello solapa y manga larga. Detalle de lazos y tejido con bordados e hilo metalizado. Cierre frontal con botones ocultos por solapa., Precio: 22,95 EUR
# Nombre: BLUSA TUL ESTAMPADO - Azul de Zara, Enlace: https://www.zara.com/es/es/blusa-tul-estampado-p05039398.html, Descripción: Blusa de cuello solapa y escote pico cruzado. Manga larga. Detalle de frunces y lazada., Precio: 19,95 EUR
# Nombre: BLUSA TUL ESTAMPADO - Negro / Arena de Zara, Enlace: https://www.zara.com/es/es/blusa-tul-estampado-p05039407.html, Descripción: Blusa semitransparente de cuello subido. Manga larga y bajo acabados en volantes., Precio: 15,95 EUR
# ...

# %% [markdown]
# ### Info Zapatos

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-zapatos-l1251.html?v1=2419160&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-link product-grid-product__link link')

   
    product_details = []

    
    for product in products[:30]:  
        product_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        product_link = product.get('href')

        
        product_response = requests.get(product_link, headers=headers)
        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')

            
            description_element = product_soup.find('div', class_='product-detail-info__description')
            product_description = description_element.get_text(strip=True) if description_element else 'Descripción no encontrada'

            
            price_element = product_soup.find('div', class_='product-detail-info__price')
            price = price_element.get_text(strip=True) if price_element else 'Precio no encontrado'

            
            product_details.append((product_name, product_link, product_description, price))

    
    for name, link, description, price in product_details:
        print(f"Nombre: {name}, Enlace: {link}, Descripción: {description}, Precio: {price}")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: BOTÍN TACÓN OJALES METÁLICOS - Negro de Zara, Enlace: https://www.zara.com/es/es/botin-tacon-ojales-metalicos-p11141410.html, Descripción: Zapato tipo botín con tacón. Detalles de ojales metálicos en el cuerpo. Cierre mediante cremallera trasera.Altura del tacón: 8,5 cm, Precio: 59,95 EUR
# Nombre: ZAPATO TACÓN BRILLOS - Plata de Zara, Enlace: https://www.zara.com/es/es/zapato-tacon-brillos-p11256410.html, Descripción: Zapato tacón con cuerpo en apliques brillantes. Escote redondo. Tacón ancho. Acabado en punta redonda.Altura del tacón: 5 cm, Precio: 39,95 EUR
# Nombre: ZAPATO TACÓN BRILLOS - Plata de Zara, Enlace: https://www.zara.com/es/es/zapato-tacon-brillos-p11256410.html, Descripción: Zapato tacón con cuerpo en apliques brillantes. Escote redondo. Tacón ancho. Acabado en punta redonda.Altura del tacón: 5 cm, Precio: 39,95 EUR
# ...

# %% [markdown]
# ### Info Chalecos

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-blazers-l1055.html?v1=2420942&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-link product-grid-product__link link')

    
    product_details = []

    
    for product in products[:30]:  
        
        product_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        
        
        product_link = product.get('href', 'Enlace no encontrado')

        
        product_response = requests.get(product_link, headers=headers)

        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            
            description_element = product_soup.find('div', class_='product-detail-description product-detail-info__description')
            product_description = description_element.get_text(strip=True) if description_element else 'Descripción no encontrada'
            
            
            price_element = product_soup.find('div', class_='product-detail-info__price')
            price = price_element.find('span', class_='money-amount__main').get_text(strip=True) if price_element else 'Precio no encontrado'
        else:
            product_description = 'Error al acceder a la descripción'
            price = 'Error al acceder al precio'

        product_details.append((product_name, product_link, product_description, price))

    
    for name, link, description, price in product_details:
        print(f"Nombre: {name}\nEnlace: {link}\nDescripción: {description}\nPrecio: {price}\n")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: BLAZER RECTA ESPIGA CON LANA - Gris Antracita de Zara
# Enlace: https://www.zara.com/es/es/blazer-recta-espiga-con-lana-p03046483.html
# Descripción: Blazer confeccionada con lana. Cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con un botón.
# Precio: 49,95 EUR
#
# Nombre: BLAZER ENTALLADA BRILLOS - Negro de Zara
# Enlace: https://www.zara.com/es/es/blazer-entallada-brillos-p01689599.html
# Descripción: Blazer de cuello solapa y manga larga con hombreras. Cintura entallada. Bolsillos delanteros con solapa. Detalle de brillos. Cierre frontal con corchete oculto.
# Precio: 49,95 EUR
#
# Nombre: BLAZER CUADROS ZW COLLECTION - ARENA/MARRÓN de Zara
# Enlace: https://www.zara.com/es/es/blazer-cuadros-zw-collection-p09296430.html
# Descripción: ZARA WOMAN COLLECTIONBlazer de cuello solapa y manga larga acabada en abertura y botones. Bolsillos de vivo en delantero. Forro interior a contraste. Cierre frontal con botón.
# Precio: 69,95 EUR
#
# ...

# %% [markdown]
# ### Info Bolsos

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.zara.com/es/es/mujer-bolsos-l1024.html?v1=2417728&regionGroupId=110"


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"
}


response = requests.get(url, headers=headers)


if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')

    
    products = soup.find_all('a', class_='product-link product-grid-product__link link')

    
    product_details = []

    
    for product in products[:30]:  
        # Nombre
        product_name = product.find('img', class_='media-image__image media__wrapper--media').get('alt', 'Nombre no encontrado')
        
        
        product_link = product.get('href', 'Enlace no encontrado')

        
        product_response = requests.get(product_link, headers=headers)

        if product_response.status_code == 200:
            product_soup = BeautifulSoup(product_response.text, 'html.parser')
            
            
            description_element = product_soup.find('div', class_='product-detail-description product-detail-info__description')
            product_description = description_element.get_text(strip=True) if description_element else 'Descripción no encontrada'
            
            
            price_element = product_soup.find('div', class_='product-detail-info__price')
            price = price_element.find('span', class_='money-amount__main').get_text(strip=True) if price_element else 'Precio no encontrado'
        else:
            product_description = 'Error al acceder a la descripción'
            price = 'Error al acceder al precio'

        product_details.append((product_name, product_link, product_description, price))

    
    for name, link, description, price in product_details:
        print(f"Nombre: {name}\nEnlace: {link}\nDescripción: {description}\nPrecio: {price}\n")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: BOLSO DE HOMBRO ANTE - Marrón de Zara
# Enlace: https://www.zara.com/es/es/bolso-de-hombro-ante-p16259410.html
# Descripción: Bolso formato de hombro en ante. Detalle de pespunte en el corte. Bolsillo interior con bolsillo. Asa de hombro. Cierre mediante cremallera con tirador.Alto x Ancho x Fondo: 17,5 x 38,5 x 13,5 cm.
# Precio: 99,95 EUR
#
# Nombre: BOLSO DE HOMBRO ANTE - Marrón de Zara
# Enlace: https://www.zara.com/es/es/bolso-de-hombro-ante-p16259410.html
# Descripción: Bolso formato de hombro en ante. Detalle de pespunte en el corte. Bolsillo interior con bolsillo. Asa de hombro. Cierre mediante cremallera con tirador.Alto x Ancho x Fondo: 17,5 x 38,5 x 13,5 cm.
# Precio: 99,95 EUR
#
# Nombre: BOLSO DE HOMBRO ANTE - Marrón de Zara
# Enlace: https://www.zara.com/es/es/bolso-de-hombro-ante-p16259410.html
# ...

# %%
import pandas as pd


nombres = [
    "MINI SACA TERCIOPELO FLOR",
    "MAXI SACA EFECTO TERCIOPELO",
    "BOLSO DE HOMBRO ALARGADO",
    "BANDOLERA EFECTO COCO SERRAJE",
    "BOLSO DE HOMBRO OVALADO CON EFECTO ENGOMADO",
    "BOLSO DE HOMBRO CON EFECTO ENGOMADO",
    "BANDOLERA DE SERIE",
    "CLUTCH EFECTO PIEL",
    "MALLET CON EFECTO BRILLO",
    "SACA PEQUEÑA",
    "BOLSO EFECTO COCODRILO",
    "BOLSO CANGURO",
    "SACA TERCIOPELO CON DETALLE FLOR ",
    "CLUTCH BRILLO",
    "BOLSO TOTE EFECTO COCODRILO",
]

descripciones = [
    "Bolso formato mini saca en efecto terciopelo. Detalle de flor en la parte delantera. Asa de mano y asa bandolera en cadena. Bolsillo interior con cierre mediante fruncido. Alto x Ancho x Fondo: 18 x 21 x 3,5 cm.",
    "Bolso formato maxi saca en efecto terciopelo. Asa bandolera. Detalle de flor en la parte delantera. Bolsillo interior con cierre mediante fruncido. Alto x Ancho x Fondo: 21,5 x 37 x 3 cm.",
    "Bolso formato de hombro con forma alargada. Detalle de tira con nudos laterales en el cuerpo. Doble asa de hombro. Bolsillo interior con cremallera. Cierre mediante cremallera. Alto x Ancho x Fondo: 18 x 36,5 x 13 cm.",
    "Bolso formato bandolera en serraje. Efecto coco en el cuerpo. Bolsillo interior con cremallera. Asa bandolera ajustable mediante hebilla. Cierre mediante cremallera. Alto x Ancho x Fondo: 17,5 x 25 x 7,5 cm.",
    "Bolso de hombro de formato ovalado con efecto engomado en la parte inferior. Repelente a la humedad superficial del agua, actúa como una barrera para que tus pertenencias se mantengan secas en todo momento. Cuenta con un detalle de tira ajustable con clip en los laterales y un bolsillo interior con cremallera. Su asa de hombro es ajustable que ofrece la comodidad de llevarlo a la altura que más se adapte a tus necesidades. Cierre mediante cremallera. Alto x Ancho x Fondo: 17 x 46,5 x 10 cm.",
    "Bolso de hombro de formato rectangular con efecto engomado. Asa larga ajustable. Bolsillo interior con cremallera. Cierre mediante cremallera. Alto x Ancho x Fondo: 20 x 40 x 10 cm.",
    "Bolso bandolera en material suave. Cierre mediante cremallera. Asa bandolera ajustable. Alto x Ancho x Fondo: 20 x 30 x 8 cm.",
    "Clutch en efecto piel con asa de mano. Cierre mediante cremallera. Alto x Ancho x Fondo: 15 x 25 x 3 cm.",
    "Mallet de efecto brillo con detalle de cadena en el cierre. Alto x Ancho x Fondo: 18 x 27 x 7 cm.",
    "Bolso de saca pequeña con asa ajustable. Cierre mediante fruncido. Alto x Ancho x Fondo: 16 x 22 x 5 cm.",
    "Bolso efecto cocodrilo con cierre mediante cremallera. Alto x Ancho x Fondo: 19 x 30 x 8 cm.",
    "Bolso tipo canguro con diseño suave. Asa de hombro larga. Cierre mediante cremallera. Alto x Ancho x Fondo: 20 x 35 x 10 cm.",
    "Bolso saca en terciopelo con detalle de flor en la parte delantera. Asa bandolera ajustable. Alto x Ancho x Fondo: 18 x 22 x 4 cm.",
    "Clutch con efecto brillo y cadena. Cierre mediante cremallera. Alto x Ancho x Fondo: 15 x 25 x 3 cm.",
    "Bolso tipo tote en efecto cocodrilo. Asa larga y corta. Alto x Ancho x Fondo: 28 x 38 x 12 cm.",
    
]

precios = [
    "39,95 EUR",
    "49,95 EUR",
    "35,95 EUR",
    "55,95 EUR",
    "35,95 EUR",
    "39,95 EUR",
    "49,95 EUR",
    "29,95 EUR",
    "45,95 EUR",
    "34,95 EUR",
    "59,95 EUR",
    "49,95 EUR",
    "39,95 EUR",
    "34,95 EUR",
    "69,95 EUR",
]

colores = [
    "Ocre",
    "Negro",
    "Negro",
    "1-155",
    "Negro",
    "Verde",
    "Azul",
    "Negro",
    "Verde",
    "Azul",
    "Negro",
    "Rosa",
    "Verde",
    "Negro",
    "Azul",
]


bolsos_df = pd.DataFrame({
    'Nombre': nombres,
    'Descripción': descripciones,
    'Precio': precios,
    'Color': colores,
})


bolsos_df['Categoría'] = 'Bolsos'  

bolsos_df.head()
# Out:
#                                         Nombre  \
# 0                    MINI SACA TERCIOPELO FLOR
# 1                  MAXI SACA EFECTO TERCIOPELO
# 2                     BOLSO DE HOMBRO ALARGADO
# 3                BANDOLERA EFECTO COCO SERRAJE
# 4  BOLSO DE HOMBRO OVALADO CON EFECTO ENGOMADO
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría
# 0    Bolsos
# 1    Bolsos
# 2    Bolsos
# 3    Bolsos
# 4    Bolsos

# %%
nombres = [
    "BLAZER SIN SOLAPA LENTEJUELAS - Negro / Plata de Zara",
    "BLAZER SIN SOLAPA LENTEJUELAS - Negro de Zara",
    "BLAZER CORTA BRILLO - Negro / Plata de Zara",
    "BLAZER OVERSIZE RAYA DIPLOMÁTICA - Gris oscuro de Zara",
    "CHALECO RAYA DIPLOMÁTICA - Gris antracita de Zara",
    "BLAZER RAYA DIPLOMÁTICA CINTURÓN - Gris antracita de Zara",
    "BLAZER OVERSIZE RAYA DIPLOMÁTICA - Marino de Zara",
    "CHALECO TRABILLA - Negro de Zara",
    "CHALECO TOP ENTALLADO - Petróleo claro de Zara",
    "BLAZER ENTALLADA BOTÓN DORADO - Tostado de Zara",
    "BLAZER SMOKING SOLAPA SATINADA - Negro de Zara",
    "CHALECO ACABADOS COMBINADO - Negro de Zara",
    "BLAZER RECTA ESPIGA CON LANA - Tostado de Zara",
    "BLAZER MANGA REMANGADA - Negro de Zara",
    "BLAZER ENTALLADA - Negro de Zara",
    "BLAZER CORTA PATA DE GALLO - Blanco / Negro de Zara",
    "BLAZER CRUZADA OVERSIZE - Khaki de Zara",
    "BLAZER ENTALLADA - Rosa de Zara",
    "BLAZER RECTA RAYA DIPLOMÁTICA - Marino de Zara",
    "BLAZER CRUZADA OVERSIZE - Negro de Zara",
    "BLAZER RECTA ESPIGA CON LANA - Gris vigoré de Zara",
    "BLAZER ENTALLADA HOMBRERAS - Gris de Zara",
    "BLAZER CORTA PATA DE GALLO - Blanco / Negro de Zara",
    "BLAZER OVERSIZE ZW COLLECTION - Negro de Zara",
    "BLAZER MAXI BOTÓN ZW COLLECTION - Negro de Zara",
    "BLAZER ESPIGA COMBINADA CAPUCHA - Gris vigoré de Zara",
    "BLAZER CRUZADA CINTURÓN ESPALDA - Morado de Zara",
    "BLAZER CRUZADA OVERSIZE - Negro de Zara",
    "BLAZER ESCOTE REDONDO - Negro de Zara",
]

descripciones = [
    "Blazer sin solapa con manga larga y hombreras. Detalle aplicación de lentejuelas. Cierre frontal con corchete oculto.",
    "Blazer de cuello sin solapa y manga larga con hombreras. Bolsillos delanteros. Cierre frontal con corchete oculto.",
    "Blazer corta con tejido efecto brillo. Cuello solapa y manga larga con hombreras. Cierre frontal cruzado con botones joya.",
    "Blazer oversize de cuello solapa y manga larga con hombreras. Bolsillos de vivo en delantero. Forro interior combinado. Bajo con aberturas laterales. Cierre frontal cruzado con botones.",
    "Chaleco de escote pico y manga sisa. Bolsillos de vivo en delantero. Forro interior combinado. Trabilla ajustable en espalda y bajo con aberturas. Cierre frontal con botones.",
    "Blazer de cuellos solapa y manga larga con hombreras.Cinturón fino en mismo tejido con lazada. Cierre frontal con botones.",
    "Blazer oversize de cuello solapa y manga larga con hombreras. Bolsillos de vivo en delantero. Forro interior combinado. Bajo con aberturas laterales. Cierre frontal cruzado con botones.",
    "Chaleco de escote pico y manga sisa. Falsos bolsillos de vivo en delantero. Detalle de trabilla ajustable en espalda. Cierre frontal con botones.",
    "Chaleco top entallado de cuello pico y manga sisa. Falso bolsillo de vivo en pecho. Cierre frontal con botones.",
    "Blazer de cuello solapa con escote pico y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con botones dorados.",
    "Blazer de cuello con solapa satinada y manga larga con hombreras. Cintura entallada. Bolsillos delanteros con solapa. Cierre frontal con botón forrado con tejido satinado.",
    "Chaleco de escote pico y manga sisa. Bolsillos delanteros de vivo. Detalle de acabados con tejido combinado semitransparente. Cierre frontal con corchetes ocultos.",
    "Blazer confeccionada con lana. Cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con un botón.",
    "Blazer abierta de cuello solapa y hombreras. Manga por debajo del codo acabada en vuelta con trabilla y botón dorado. Bolsillos delanteros con solapa.",
    "Blazer entallada de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Forro interior. Cierre frontal cruzado con botones.",
    "Blazer de cuello solapa y manga larga con hombreras. Cierre frontal cruzado con botones.",
    "Blazer amplia de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal cruzado con botones.",
    "Blazer entallada de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Forro interior. Cierre frontal cruzado con botones.",
    "Blazer de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Bajo con abertura en espalda. Cierre frontal con botones.",
    "Blazer amplia de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal cruzado con botones.",
    "Blazer confeccionada con lana. Cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con un botón.",
    "Blazer de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con un botón.",
    "Blazer de cuello redondo y manga larga con hombreras. Bolsillos delanteros de plastrón con solapa. Cierre frontal con botones.",
    "Blazer oversize con cuello solapa de muescas. Manga larga con hombro caído. Bolsillos con solapa en delantero y de vivo en pecho. Forro interior. Cierre frontal con botones.",
    "Blazer de cuello solapa con muesca. Manga larga con hombreras acabada en abertura. Bolsillos con solapa en delantero. Cierre frontal con maxi botones metálicos.",
    "Blazer de cuello con solapa y capucha combinada. Manga larga con hombreras. Bolsillos delanteros con solapa. Bajo con abertura en espalda. Cierre frontal con cremallera y botones.",
    "Blazer de cuello solapa y escote pico cruzado. Manga larga con hombreras. Bolsillos de vivo en delantero. Forro interior combinado a contraste. Detalle tira efecto cinturón en espalda. Cierre frontal cruzado con botones.",
    "Blazer amplia de cuello solapa y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal cruzado con botones.",
    "Blazer con escote redondo y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con botones dorados.",
]

precios = [
    "59,95 EUR", "59,95 EUR", "49,95 EUR", "59,95 EUR", "25,95 EUR", "39,95 EUR", "59,95 EUR",
    "25,95 EUR", "29,95 EUR", "49,95 EUR", "49,95 EUR", "27,95 EUR", "49,95 EUR", "39,95 EUR",
    "55,95 EUR", "55,95 EUR", "39,95 EUR", "55,95 EUR", "59,95 EUR", "39,95 EUR", "49,95 EUR",
    "49,95 EUR", "55,95 EUR", "59,95 EUR", "79,95 EUR", "49,95 EUR", "59,95 EUR", "39,95 EUR",
    "49,95 EUR",
]

colores = [
    "Negro / Plata", "Negro", "Negro / Plata", "Gris oscuro", "Gris antracita", "Gris antracita",
    "Marino", "Negro", "Petróleo claro", "Tostado", "Negro", "Negro", "Tostado", "Negro",
    "Negro", "Blanco / Negro", "Khaki", "Rosa", "Marino", "Negro", "Gris vigoré", "Gris",
    "Blanco / Negro", "Negro", "Negro", "Gris vigoré", "Morado", "Negro", "Negro"
]


chalecos_df = pd.DataFrame({
    'Nombre': nombres,
    'Descripción': descripciones,
    'Precio': precios,
    'Color': colores,
})


chalecos_df['Categoría'] = 'Blazers'


chalecos_df.head(30)
# Out:
#                                                Nombre  \
# 0   BLAZER SIN SOLAPA LENTEJUELAS - Negro / Plata ...
# 1       BLAZER SIN SOLAPA LENTEJUELAS - Negro de Zara
# 2         BLAZER CORTA BRILLO - Negro / Plata de Zara
# 3   BLAZER OVERSIZE RAYA DIPLOMÁTICA - Gris oscuro...
# 4   CHALECO RAYA DIPLOMÁTICA - Gris antracita de Zara
# 5   BLAZER RAYA DIPLOMÁTICA CINTURÓN - Gris antrac...
# 6   BLAZER OVERSIZE RAYA DIPLOMÁTICA - Marino de Zara
# 7                    CHALECO TRABILLA - Negro de Zara
# 8      CHALECO TOP ENTALLADO - Petróleo claro de Zara
# 9     BLAZER ENTALLADA BOTÓN DORADO - Tostado de Zara
# 10     BLAZER SMOKING SOLAPA SATINADA - Negro de Zara
# 11         CHALECO ACABADOS COMBINADO - Negro de Zara
# 12     BLAZER RECTA ESPIGA CON LANA - Tostado de Zara
# 13             BLAZER MANGA REMANGADA - Negro de Zara
# 14                   BLAZER ENTALLADA - Negro de Zara
# 15  BLAZER CORTA PATA DE GALLO - Blanco / Negro de...
# ...

# %%
nombres = [
    "BOTÍN PLANO PICADOS - Marrón de Zara", "BOTÍN PLANO PICADOS - Marrón de Zara",
    "BOTÍN PLANO PIEL CON PELO - Marrón de Zara", "BOTÍN PLANO PIEL CON PELO - Marrón de Zara",
    "BOTÍN COWBOY PIEL - Negro de Zara", "BOTÍN COWBOY PIEL - Negro de Zara",
    "BOTÍN TACÓN PIEL - Negro de Zara", "BOTÍN TACÓN PIEL - Negro de Zara",
    "BOTA HÍPICA EFECTO COCO - Negro de Zara", "BOTA HÍPICA EFECTO COCO - Negro de Zara",
    "BOTÍN PLANO HEBILLA - Negro de Zara", "BOTÍN PLANO HEBILLA - Negro de Zara",
    "BOTA TACÓN ALTO - Rojo Burdeos de Zara", "BOTA TACÓN ALTO - Rojo Burdeos de Zara",
    "BOTÍN TACÓN ANCHO PIEL - Negro de Zara", "BOTÍN TACÓN ANCHO PIEL - Negro de Zara",
    "ZAPATILLAS DEPORTIVAS SERRAJE - tostado de Zara", "ZUECO DETALLE PELO SERRAJE - Marrón de Zara",
    "ZUECO DETALLE PELO SERRAJE - Marrón de Zara", "BAILARINA ESTAMPADO ANIMAL - Leopardo de Zara",
    "BAILARINA ESTAMPADO ANIMAL - Leopardo de Zara", "BOTÍN SERRAJE - Marrón de Zara",
    "BOTÍN SERRAJE - Marrón de Zara", "BOTÍN DETALLE FRUNCIDO - Negro de Zara",
    "BOTÍN DETALLE FRUNCIDO - Negro de Zara", "BAILARINA TEJIDO DETALLE BRILLOS - Negro de Zara",
    "BAILARINA TEJIDO DETALLE BRILLOS - Negro de Zara", "DESTALONADO LAZO EFECTO TERCIOPELO - Negro de Zara",
    "DESTALONADO LAZO EFECTO TERCIOPELO - Negro de Zara", "ZAPATO TACÓN EFECTO ACHAROLADO - Negro de Zara"
]

enlaces = [
    "https://www.zara.com/es/es/botin-plano-picados-p11128410.html", "https://www.zara.com/es/es/botin-plano-picados-p11128410.html",
    "https://www.zara.com/es/es/botin-plano-piel-con-pelo-p11105410.html", "https://www.zara.com/es/es/botin-plano-piel-con-pelo-p11105410.html",
    "https://www.zara.com/es/es/botin-cowboy-piel-p11123410.html", "https://www.zara.com/es/es/botin-cowboy-piel-p11123410.html",
    "https://www.zara.com/es/es/botin-tacon-piel-p11111410.html", "https://www.zara.com/es/es/botin-tacon-piel-p11111410.html",
    "https://www.zara.com/es/es/bota-hipica-efecto-coco-p13019410.html", "https://www.zara.com/es/es/bota-hipica-efecto-coco-p13019410.html",
    "https://www.zara.com/es/es/botin-plano-hebilla-p13104410.html", "https://www.zara.com/es/es/botin-plano-hebilla-p13104410.html",
    "https://www.zara.com/es/es/bota-tacon-alto-p13010410.html", "https://www.zara.com/es/es/bota-tacon-alto-p13010410.html",
    "https://www.zara.com/es/es/botin-tacon-ancho-piel-p12105410.html", "https://www.zara.com/es/es/botin-tacon-ancho-piel-p12105410.html",
    "https://www.zara.com/es/es/zapatillas-deportivas-serraje-p15435410.html", "https://www.zara.com/es/es/zueco-detalle-pelo-serraje-p12549410.html",
    "https://www.zara.com/es/es/zueco-detalle-pelo-serraje-p12549410.html", "https://www.zara.com/es/es/bailarina-estampado-animal-p13522410.html",
    "https://www.zara.com/es/es/bailarina-estampado-animal-p13522410.html", "https://www.zara.com/es/es/botin-serraje-p11140410.html",
    "https://www.zara.com/es/es/botin-serraje-p11140410.html", "https://www.zara.com/es/es/botin-detalle-fruncido-p12158410.html",
    "https://www.zara.com/es/es/botin-detalle-fruncido-p12158410.html", "https://www.zara.com/es/es/bailarina-tejido-detalle-brillos-p12561410.html",
    "https://www.zara.com/es/es/bailarina-tejido-detalle-brillos-p12561410.html", "https://www.zara.com/es/es/destalonado-lazo-efecto-terciopelo-p12260410.html",
    "https://www.zara.com/es/es/destalonado-lazo-efecto-terciopelo-p12260410.html", "https://www.zara.com/es/es/zapato-tacon-efecto-acharolado-p12248410.html"
]

descripciones = [
    "Zapato tipo botín plano. Detalles en picado. Tirador trasero y delantero. Elásticos laterales. Acabado en punta redonda. Altura de la suela: 3 cm", 
    "Zapato tipo botín plano. Detalles en picado. Tirador trasero y delantero. Elásticos laterales. Acabado en punta redonda. Altura de la suela: 3 cm", 
    "Zapato tipo botín en piel con pelo. Caña ancha. Detalle de pespunte en el cuerpo. Acabado en punta redonda. Altura de la suela: 3,5 cm",
    "Zapato tipo botín en piel con pelo. Caña ancha. Detalle de pespunte en el cuerpo. Acabado en punta redonda. Altura de la suela: 3,5 cm",
    "Zapato tipo botín en piel. Estilo cowboy. Elásticos laterales. Tirador trasero. Acabado en punta. Altura del tacón: 9 cm",
    "Zapato tipo botín en piel. Estilo cowboy. Elásticos laterales. Tirador trasero. Acabado en punta. Altura del tacón: 9 cm",
    "Zapato tipo botín en piel. Tacón ancho y acabado en punta. Cierre mediante cremallera lateral. Altura del tacón: 8,5 cm",
    "Zapato tipo botín en piel. Tacón ancho y acabado en punta. Cierre mediante cremallera lateral. Altura del tacón: 8,5 cm",
    "Zapato tipo bota de caña. Efecto coco en el corte. Tirador trasero con detalle de pieza metálica. Acabado en punta redonda. Altura de la suela: 4,5 cm",
    "Zapato tipo bota de caña. Efecto coco en el corte. Tirador trasero con detalle de pieza metálica. Acabado en punta redonda. Altura de la suela: 4,5 cm",
    "Zapato tipo botín. Detalle de hebilla en la caña. Tirador trasero. Cierre mediante cremallera lateral. Acabado en punta redonda. Altura de la suela: 3,7 cm",
    "Zapato tipo botín. Detalle de hebilla en la caña. Tirador trasero. Cierre mediante cremallera lateral. Acabado en punta redonda. Altura de la suela: 3,7 cm",
    "Zapato tipo bota con tacón alto. Caña alta. Acabado en punta. Cierre mediante cremallera. Altura del tacón: 10 cm",
    "Zapato tipo bota con tacón alto. Caña alta. Acabado en punta. Cierre mediante cremallera. Altura del tacón: 10 cm",
    "Zapato tipo botín en piel. Tacón ancho. Acabado en punta redonda. Altura del tacón: 8 cm",
    "Zapato tipo botín en piel. Tacón ancho. Acabado en punta redonda. Altura del tacón: 8 cm",
    "Zapatillas deportivas tipo bamba en serraje. Acabado deshilachado. Cierre mediante cordones. Altura de la suela: 1 cm",
    "Zapato plano tipo zueco en piel de serraje. Pelo interior. Detalle de antifaz y pespunte en la parte delantera. Acabado en punta redonda. Altura de la suela: 3 cm",
    "Zapato plano tipo zueco en piel de serraje. Pelo interior. Detalle de antifaz y pespunte en la parte delantera. Acabado en punta redonda. Altura de la suela: 3 cm",
    "Zapato plano tipo bailarina. Estampado animal. Acabado en punta redonda. Altura de la suela: 0,5 cm",
    "Zapato plano tipo bailarina. Estampado animal. Acabado en punta redonda. Altura de la suela: 0,5 cm",
    "Zapato tipo botín en piel de serraje. Caña media. Acabado en punta redonda. Altura de la suela: 3,5 cm",
    "Zapato tipo botín en piel de serraje. Caña media. Acabado en punta redonda. Altura de la suela: 3,5 cm",
    "Zapato tipo botín con detalle fruncido en el corte. Acabado en punta redonda. Altura del tacón: 6,5 cm",
    "Zapato tipo botín con detalle fruncido en el corte. Acabado en punta redonda. Altura del tacón: 6,5 cm",
    "Zapato plano tipo bailarina en tejido. Detalle de brillos. Acabado en punta redonda. Altura de la suela: 0,5 cm",
    "Zapato plano tipo bailarina en tejido. Detalle de brillos. Acabado en punta redonda. Altura de la suela: 0,5 cm",
    "Zapato tipo destalonado con lazo decorativo en el empeine. Efecto terciopelo. Acabado en punta. Altura del tacón: 1,5 cm",
    "Zapato tipo destalonado con lazo decorativo en el empeine. Efecto terciopelo. Acabado en punta. Altura del tacón: 1,5 cm",
    "Zapato tipo salón con tacón alto. Efecto acharolado. Acabado en punta. Altura del tacón: 9 cm"
]

precios = [
    "39,95 EUR", "39,95 EUR", "99,95 EUR", "99,95 EUR", "69,95 EUR", "69,95 EUR",
    "99,95 EUR", "99,95 EUR", "149,95 EUR", "149,95 EUR", "49,95 EUR", "49,95 EUR",
    "99,95 EUR", "99,95 EUR", "79,95 EUR", "79,95 EUR", "59,95 EUR", "59,95 EUR",
    "59,95 EUR", "29,95 EUR", "29,95 EUR", "89,95 EUR", "89,95 EUR", "59,95 EUR",
    "59,95 EUR", "29,95 EUR", "29,95 EUR", "49,95 EUR", "49,95 EUR", "59,95 EUR"
]


zapatos_df = pd.DataFrame({
    'Nombre': nombres,
    'Enlace': enlaces,
    'Descripción': descripciones,
    'Precio': precios
})


zapatos_df.head()
# Out:
#                                        Nombre  \
# 0        BOTÍN PLANO PICADOS - Marrón de Zara
# 1        BOTÍN PLANO PICADOS - Marrón de Zara
# 2  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 3  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 4           BOTÍN COWBOY PIEL - Negro de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/botin-plano-picados...
# 1  https://www.zara.com/es/es/botin-plano-picados...
# 2  https://www.zara.com/es/es/botin-plano-piel-co...
# 3  https://www.zara.com/es/es/botin-plano-piel-co...
# 4  https://www.zara.com/es/es/botin-cowboy-piel-p...
#
#                                          Descripción     Precio
# 0  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR
# 1  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR
# 2  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR
# 3  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR
# ...

# %%
import pandas as pd

# %%
nombres = [
    "CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de Zara",
    "BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro de Zara",
    "BLUSA VOLANTES ZW COLLECTION - Negro de Zara",
    "BLUSA TUL ESTAMPADO - Azul de Zara",
    "BLUSA TUL ESTAMPADO - Negro / Arena de Zara",
    "CAMISA POPELÍN BOTONES DORADOS - Azul claro de Zara",
    "CAMISA CREPE ENTREDOSES - Negro de Zara",
    "CAMISA MAXI FLECOS ZW COLLECTION - Marrón de Zara",
    "CAMISA FLECOS ZW COLLECTION - Negro de Zara",
    "BLUSA BORDADA FRUNCES ZW COLLECTION - Marrón claro de Zara",
    "CAMISA LAZADAS VOLANTES - Blanco roto de Zara",
    "CAMISA VOLANTES - Marrón de Zara",
    "BLUSA MULTIPOSICIÓN ZW COLLECTION - Negro de Zara",
    "BLUSA HILO METALIZADO ZW COLLECTION - Negro de Zara",
    "POLO LISO LANA 100% - Gris de Zara",
    "POLO LISO LANA 100% - Toffe de Zara",
    "CAMISA SATINADA BOLSILLOS ZW COLLECTION - Burgundy de Zara",
    "CAMISA BORDADOS CUADRO VICHY - Crudo / Negro de Zara",
    "BLUSA VOLANTES ZW COLLECTION - Crudo de Zara",
    "CAMISA Z1975 BÁSICA DENIM - Azul de Zara",
    "CAMISA Z1975 BÁSICA DENIM - Azul medio de Zara",
    "BLUSA FLUIDA LAZO - Blanco de Zara",
    "BLUSA PAÑUELO ZW COLLECTION - Melocotón de Zara",
    "BLUSA VOLANTES ZW COLLECTION - Crudo de Zara",
]

enlaces = [
    "https://www.zara.com/es/es/camisa-denim-pespuntes-zw-collection-p04676240.html",
    "https://www.zara.com/es/es/blusa-romantica-volantes-zw-collection-p05107252.html",
    "https://www.zara.com/es/es/blusa-volantes-zw-collection-p09520209.html",
    "https://www.zara.com/es/es/blusa-tul-estampado-p05039398.html",
    "https://www.zara.com/es/es/blusa-tul-estampado-p05039407.html",
    "https://www.zara.com/es/es/camisa-popelin-botones-dorados-p09699255.html",
    "https://www.zara.com/es/es/camisa-crepe-entredoses-p09929225.html",
    "https://www.zara.com/es/es/camisa-maxi-flecos-zw-collection-p04786300.html",
    "https://www.zara.com/es/es/camisa-flecos-zw-collection-p04786299.html",
    "https://www.zara.com/es/es/blusa-bordada-frunces-zw-collection-p07521263.html",
    "https://www.zara.com/es/es/camisa-lazadas-volantes-p03920901.html",
    "https://www.zara.com/es/es/camisa-volantes-p03920902.html",
    "https://www.zara.com/es/es/blusa-multiposicion-zw-collection-p04786276.html",
    "https://www.zara.com/es/es/blusa-hilo-metalizado-zw-collection-p07521259.html",
    "https://www.zara.com/es/es/polo-liso-lana-100-p01223920.html",
    "https://www.zara.com/es/es/polo-liso-lana-100-p01223920.html",
    "https://www.zara.com/es/es/camisa-satinada-bolsillos-zw-collection-p08987213.html",
    "https://www.zara.com/es/es/camisa-bordados-cuadro-vichy-p03564192.html",
    "https://www.zara.com/es/es/blusa-volantes-zw-collection-p08544207.html",
    "https://www.zara.com/es/es/camisa-z1975-basica-denim-p01879221.html",
    "https://www.zara.com/es/es/camisa-z1975-basica-denim-p01879221.html",
    "https://www.zara.com/es/es/blusa-fluida-lazo-p04387240.html",
    "https://www.zara.com/es/es/blusa-panuelo-zw-collection-p07521254.html",
    "https://www.zara.com/es/es/blusa-volantes-zw-collection-p05235241.html",
]

descripciones = [
    "ZARA WOMAN COLLECTIONCamisa confeccionada en hilatura con mezcla de algodón. Cuello solapa y manga larga acabada en puño. Bolsillos de plastrón con solapa y botón en pecho. Detalle de pespuntes a tono. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa confeccionada en hilatura de viscosa. Cuello perkins con manga larga. Detalle de aplicación de bordados y lentejuelas. Volantes en mismo tejido. Cierre en espalda con abertura y botones.",
    "ZARA WOMAN COLLECTIONBlusa confeccionada en hilatura con viscosa y algodón. Escote pico y manga larga acabada en elástico. Detalle de volantes en mismo tejido. Bajo recto.",
    "Blusa de cuello solapa y escote pico cruzado. Manga larga. Detalle de frunces y lazada.",
    "Blusa semitransparente de cuello subido. Manga larga y bajo acabados en volantes.",
    "Camisa de cuello solapa y manga larga. Cierre frontal con botones ocultos y botones dorados con relieve.",
    "Camisa de cuello solapa y manga larga. Detalle de entredoses delanteros a tono. Cierre frontal con botón dorado y botones ocultos por solapa.",
    "ZARA WOMAN COLLECTIONCamisa de cuello solapa y manga larga acabada en puño. Detalle de maxi flecos en mismo tejido. Bajo redondeado asimétrico. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONCamisa de cuello solapa y manga larga acabada en puño. Detalle de flecos en mismo tejido. Bajo redondeado. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa confeccionada en hilatura de viscosa 100%. Cuello redondo desflecado y manga larga. Detalle de frunces y bordados a tono.",
    "Camisa semitransparente de escote pico y lazada en mismo tejido. Manga larga acabada en abertura ajustable. Detalle de volantes combinados a tono. Cierre frontal con botones forrados.",
    "Camisa semitransparente de cuello subido ajustable con lazada. Manga larga. Detalle de volantes en mismo tejido. Este artículo no incluye forro interior.",
    "ZARA WOMAN COLLECTIONBlusa multiposición confeccionada en hilatura de viscosa. Cuello redondo y manga larga ajustable con lazadas. Detalle de pliegues delanteros y lazada en cuello. Bajo asimétrico. Cierre en cuello con botón.",
    "ZARA WOMAN COLLECTIONBlusa de cuello redondo con lazo en mismo tejido. Manga larga acabada en puño. Detalle de aplicación de hilo metalizado. Bajo asimétrico.",
    "Polo semitransparente confeccionado en hilatura de lana 100%. Cuello solapa y manga larga. Cierre frontal con botones.",
    "Polo semitransparente confeccionado en hilatura de lana 100%. Cuello solapa y manga larga. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONCamisa confeccionada en hilatura de viscosa 100%. Cuello solapa y manga larga acabada en puño. Detalle de aplicación de bordados a tono. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONCamisa de cuello solapa y manga larga. Detalle de bordados en puño. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa de cuello redondo con lazo en mismo tejido. Manga larga acabada en puño. Bajo asimétrico. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa de cuello redondo con lazo en mismo tejido. Manga larga acabada en puño. Bajo asimétrico. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa de cuello redondo con lazo en mismo tejido. Manga larga acabada en puño. Bajo asimétrico. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTIONBlusa confeccionada en hilatura de viscosa. Cuello redondo y manga larga. Detalle de volantes en mismo tejido. Cierre en espalda con abertura y botones.",
    "ZARA WOMAN COLLECTIONCamisa confeccionada en hilatura de algodón 100%. Cuello solapa y manga larga. Detalle de estampado a rayas en toda la prenda. Bajo recto.",
    "Camisa de cuello solapa y manga larga. Detalle de bordados en puño. Cierre frontal con botones."
]

precios = [
    29.99, 35.99, 39.99, 19.99, 22.99, 29.99, 32.99, 45.99, 39.99,
    24.99, 27.99, 33.99, 19.99, 22.99, 27.99, 34.99, 38.99, 40.99,
    29.99, 35.99, 39.99, 45.99, 29.99, 35.99
]



camisas_df = pd.DataFrame({
    'Nombre': nombres,
    'Enlace': enlaces,
    'Descripción': descripciones,
    'Precio': precios
})


camisas_df.head(20)
# Out:
#                                                Nombre  \
# 0   CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de...
# 1   BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro...
# 2        BLUSA VOLANTES ZW COLLECTION - Negro de Zara
# 3                  BLUSA TUL ESTAMPADO - Azul de Zara
# 4         BLUSA TUL ESTAMPADO - Negro / Arena de Zara
# 5   CAMISA POPELÍN BOTONES DORADOS - Azul claro de...
# 6             CAMISA CREPE ENTREDOSES - Negro de Zara
# 7   CAMISA MAXI FLECOS ZW COLLECTION - Marrón de Zara
# 8         CAMISA FLECOS ZW COLLECTION - Negro de Zara
# 9   BLUSA BORDADA FRUNCES ZW COLLECTION - Marrón c...
# 10      CAMISA LAZADAS VOLANTES - Blanco roto de Zara
# 11                   CAMISA VOLANTES - Marrón de Zara
# 12  BLUSA MULTIPOSICIÓN ZW COLLECTION - Negro de Zara
# 13  BLUSA HILO METALIZADO ZW COLLECTION - Negro de...
# 14                 POLO LISO LANA 100% - Gris de Zara
# 15                POLO LISO LANA 100% - Toffe de Zara
# ...

# %%
nombres_abrigos = [
    "ABRIGO LARGO CON LANA - Negro de Zara",
    "ABRIGO CRUZADO CON LANA - Negro de Zara",
    "ABRIGO OVERSIZE SOFT - Gris de Zara",
    "ABRIGO OVERSIZE SOFT - Beige de Zara",
    "ABRIGO OVERSIZE SOFT - Negro de Zara",
    "ABRIGO SOLAPA EFECTO PELO CON LANA - Negro de Zara",
    "ABRIGO CINTURÓN CON LANA - Negro de Zara",
    "ANORAK ACOLCHADO CORTO WATER AND WIND PROTECTION - Crudo de Zara",
    "ANORAK ACOLCHADO CORTO WATER AND WIND PROTECTION - Khaki de Zara",
    "ANORAK ACOLCHADO CORTO WATER AND WIND PROTECTION - Negro de Zara",
    "ANORAK WATER AND WIND PROTECTION - Negro de Zara",
    "ABRIGO SOFT CINTURÓN CAPUCHA - Negro de Zara",
    "ABRIGO SOFT CINTURÓN CAPUCHA - Beige de Zara",
    "ABRIGO SOFT CINTURÓN CAPUCHA - Crudo de Zara",
    "CHAQUETA ACOLCHADA ZW COLLECTION - Crudo de Zara",
    "ABRIGO LARGO EFECTO PELO - Gris topo de Zara",
    "PLUMÍFERO CAPUCHA WATER AND WIND PROTECTION - Negro de Zara",
    "ANORAK LARGO ACOLCHADO CAPUCHA - Negro de Zara",
    "PLUMÍFERO CAPUCHA WATER AND WIND PROTECTION - Khaki de Zara",
    "ABRIGO LARGO BORREGUILLO - Blanco roto de Zara",
    "ABRIGO CON LANA CINTURÓN ZW COLLECTION - Khaki de Zara",
    "ABRIGO LARGO PUNTO OCHOS - Crudo de Zara",
    "ABRIGO MEZCLA LANA ZW COLLECTION - Burgundy de Zara",
    "ANORAK ACOLCHADO WATER REPELLENT - Crudo de Zara",
    "ABRIGO LARGO BORREGUILLO - Blanco roto de Zara",
    "ABRIGO EFECTO PELO - Blanco roto de Zara",
    "ANORAK ACOLCHADO WATER REPELLENT - Negro de Zara",
    "ABRIGO EFECTO PELO ESTAMPADO ANIMAL - Leopardo de Zara",
    "ABRIGO LARGO BORREGUILLO - Negro de Zara",
    "ABRIGO CORTO EFECTO PELO - Gris perla de Zara"
]

descripcion_abrigos = [
    "Abrigo de cuello solapa y manga larga. Bolsillos delanteros. Cierre frontal con corchete oculto.",
    "Abrigo de cuello solapa y manga larga. Bolsillos delanteros de vivo y bolsillos con solapa. Cierre frontal cruzado con botones.",
    "Abrigo de cuello solapa y manga larga. Bolsillos delanteros de vivo. Cierre frontal con botones.",
    "Abrigo con capucha y manga larga. Bolsillos laterales ocultos en costura. Cierre frontal con botones a presión ocultos.",
    "Anorak acolchado resistente al agua y al viento con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (1,8º) y actividad moderada (-31,7ºC). Cuello subido con capucha ajustable con cordones elásticos y manga larga. Bolsillos delanteros con forro polar interior. Cierre frontal con cremallera.",
    "Anorak acolchado resistente al agua y al viento con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (1,8º) y actividad moderada (-31,7ºC). Cuello subido con capucha ajustable con cordones elásticos y manga larga. Bolsillos delanteros con forro polar interior. Cierre frontal con cremallera.",
    "Abrigo confeccionado con lana. Cuello solapa y manga larga con hombreras. Bolsillos delanteros de vivo. Bajo con abertura en espalda. Cierre frontal con un botón.",
    "Abrigo confeccionado con lana. Cuello solapa y manga larga con hombreras. Bolsillos delanteros. Cierre frontal cruzado con botones.",
    "Abrigo confeccionado con lana. Cuello con solapa efecto pelo y manga larga. Bolsillos delanteros con solapa. Bajo con abertura trasera. Cierre frontal con botones y cinturón del mismo tejido.",
    "Abrigo confeccionado con lana. Cuello subido y manga larga con hombreras. Bolsillos delanteros con solapa. Cierre frontal con botones dorados con relieve y cinturón.",
    "ZARA WOMAN COLLECTION. Abrigo confeccionado en hilatura con lana Manteco 55%. Cuello solapa de muescas y manga larga acabada en abertura y botones. Bolsillos en delantero. Forro interior a tono. Cierre frontal con botones.",
    "ZARA WOMAN COLLECTION. Abrigo confeccionado en hilatura con mezcla de lana. Cuello solapa de muescas y manga larga acabada en abertura y botones. Bolsillos con solapa en delantero. Forro interior a tono. Cierre frontal cruzado con botones.",
    "Abrigo amplio de cuello solapa y manga larga acabada con trabilla y botón. Bolsillos delanteros de vivo. Cierre frontal cruzado con botones.",
    "Abrigo amplio de cuello solapa y manga larga acabada con trabilla y botón. Bolsillos delanteros de vivo. Cierre frontal cruzado con botones.",
    "Abrigo amplio de cuello solapa y manga larga acabada con trabilla y botón. Bolsillos delanteros de vivo. Cierre frontal cruzado con botones.",
    "Anorak con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (8,6º) y actividad moderada (-17,6ºC). Cuello subido y manga larga acabada en elástico. Bolsillos delanteros de vivo con forro polar interior. Bajo acabado con elástico interior. Cierre frontal con cremallera.",
    "Chaleco de cuello subido y manga sisa. Bolsillos delanteros de vivo con forro polar interior. Bajo acabado con elástico interior. Cierre frontal con cremallera.",
    "Abrigo largo de cuello solapa y manga larga. Bolsillos laterales ocultos en costura. Forro interior. Cierre frontal con botones.",
    "Anorak resistente al agua y al viento, con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (9º) y actividad moderada (-18ºC). Cuello alto con capucha ajustable con cordones y manga larga con puño interior. Bolsillos delanteros con forro polar interior y cierre de cremallera. Bajo ajustable con cordones elásticos laterales. Cierre frontal con cremallera.",
    "Anorak resistente al agua y al viento, con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (9º) y actividad moderada (-18ºC). Cuello alto con capucha ajustable con cordones y manga larga con puño interior. Bolsillos delanteros con forro polar interior y cierre de cremallera. Bajo ajustable con cordones elásticos laterales. Cierre frontal con cremallera.",
    "Anorak resistente al agua y al viento, con aislamiento térmico para climas fríos. Comodidad dentro del rango de temperaturas específicas para baja actividad (9º) y actividad moderada (-18ºC). Cuello alto con capucha ajustable con cordones y manga larga con puño interior. Bolsillos delanteros con forro polar interior y cierre de cremallera. Bajo ajustable con cordones elásticos laterales. Cierre frontal con cremallera.",
    "Abrigo de cuello solapa con aplicación desmontable efecto pelo y manga larga. Bolsillos delanteros de vivo. Bajo con abertura en espalda. Cierre frontal cruzado con botones y cinturón a tono."
]

color_abrigos = [
    "Crudo", "Rojo", "Tostado", "Camel claro", "Negro", "Negro", "Negro", "Negro", "Negro", "Negro",
    "Gris topo", "Blanco", "Negro", "Negro", "Crudo", "Crudo", "Crudo", "Negro", "Crudo", "Crudo",
    "Negro", "Negro", "Negro", "Crudo", "Crudo", "Crudo", "Crudo", "Tostado", "Gris claro", "Negro", "Crudo", "Crudo"
]

precios_abrigos = [
    "89,95 EUR", "49,95 EUR", "39,95 EUR", "49,95 EUR", "69,95 EUR", "69,95 EUR", "99,95 EUR",
    "69,95 EUR", "99,95 EUR", "49,95 EUR", "129,00 EUR", "129,00 EUR", "59,95 EUR", "59,95 EUR",
    "59,95 EUR", "59,95 EUR", "45,95 EUR", "79,95 EUR", "39,95 EUR", "39,95 EUR", "39,95 EUR",
    "59,95 EUR", "99,95 EUR", "79,95 EUR", "39,95 EUR", "39,95 EUR", "39,95 EUR", "59,95 EUR",
    "59,95 EUR", "59,95 EUR"
]


max_len = max(len(nombres_abrigos), len(descripcion_abrigos), len(color_abrigos), len(precios_abrigos))

nombres_abrigos.extend([None] * (max_len - len(nombres_abrigos)))
descripcion_abrigos.extend([None] * (max_len - len(descripcion_abrigos)))
color_abrigos.extend([None] * (max_len - len(color_abrigos)))
precios_abrigos.extend([None] * (max_len - len(precios_abrigos)))


abrigos_df = pd.DataFrame({
    'Nombre': nombres_abrigos,
    'Descripción': descripcion_abrigos,
    'Color': color_abrigos,
    'Precio': precios_abrigos
})


abrigos_df.head()
# Out:
#                                     Nombre  \
# 0    ABRIGO LARGO CON LANA - Negro de Zara
# 1  ABRIGO CRUZADO CON LANA - Negro de Zara
# 2      ABRIGO OVERSIZE SOFT - Gris de Zara
# 3     ABRIGO OVERSIZE SOFT - Beige de Zara
# 4     ABRIGO OVERSIZE SOFT - Negro de Zara
#
#                                          Descripción        Color     Precio
# 0  Abrigo de cuello solapa y manga larga. Bolsill...        Crudo  89,95 EUR
# 1  Abrigo de cuello solapa y manga larga. Bolsill...         Rojo  49,95 EUR
# 2  Abrigo de cuello solapa y manga larga. Bolsill...      Tostado  39,95 EUR
# 3  Abrigo con capucha y manga larga. Bolsillos la...  Camel claro  49,95 EUR
# 4  Anorak acolchado resistente al agua y al vient...        Negro  69,95 EUR

# %%
import pandas as pd


nombre = [
    "PANTALÓN JOGGER SOFT - Crudo de Zara",
    "PANTALÓN JOGGER SOFT - Camel claro de Zara",
    "PANTALÓN JOGGER SOFT - Khaki claro de Zara",
    "PANTALÓN TOBILLERO BRILLOS - Negro de Zara",
    "PANTALÓN LARGO EVASÉ - Gris antracita de Zara",
    "PANTALÓN RECTO PUNTO BOTONES LATERALES - Negro de Zara",
    "PANTALÓN RECTO EFECTO PIEL - Negro de Zara",
    "PANTALÓN ESTAMPADO LONG LENGTH - Negro / Verde de Zara",
    "PANTALÓN ANCHO CINTURÓN - Gris de Zara",
    "PANTALÓN RECTO EFECTO PIEL - Negro de Zara",
    "PANTALÓN RECTO PUNTO - Marrón oscuro de Zara",
    "PANTALÓN PINZAS BAJO AJUSTABLE - Negro de Zara",
    "PANTALÓN TIRO ALTO - Gris antracita de Zara",
    "PANTALÓN TOBILLERO SOFT - Negro de Zara",
    "JEANS Z1975 RECTOS TIRO ALTO - Azul medio de Zara",
    "PANTALÓN ANCHO ESTRUCTURA - Negro de Zara",
    "PANTALÓN RECTO ZW COLLECTION - Khaki oscuro de Zara",
    "PANTALÓN TOBILLERO PINZAS ZW COLLECTION - Gris topo de Zara",
    "PANTALÓN SOFT - Beige vigoré de Zara",
    "PANTALÓN SOFT - Gris vigoré de Zara",
    "PANTALÓN PANA CORDONES - Marino de Zara",
    "PANTALÓN SATINADO PESPUNTES ZW COLLECTION - Negro de Zara",
    "PANTALÓN BARREL BOTÓN BAJO - Negro de Zara",
    "PANTALÓN BARREL BOTÓN BAJO - Gris medio de Zara",
    "PANTALÓN BOXER VIVO LATERAL - Negro de Zara",
    "PANTALÓN BOXER VIVO LATERAL - Petróleo claro de Zara",
    "PANTALÓN JOGGER TEXTO BANDA - Gris medio de Zara",
    "PANTALÓN FELPA TEXTO BANDA LATERAL - Marino de Zara",
    "PANTALÓN FLARE INTERLOCK COSTURAS - Marrón de Zara",
    "BERMUDA LARGA PINZAS ZW COLLECTION - Khaki de Zara"
]

precio = [
    "29,95 EUR",
    "29,95 EUR",
    "25,95 EUR",
    "25,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "25,95 EUR",
    "25,95 EUR",
    "22,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "22,95 EUR",
    "25,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "25,95 EUR",
    "35,95 EUR",
]

descripcion = [
    "Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.",
    "Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.",
    "Pantalón tobillero de tiro alto con detalle de costuras marcadas en delantero y espalda. Bolsillos delanteros de vivo. Cierre frontal con cremallera, botón interior y gancho metálico.",
    "Pantalón de tiro alto con cintura elástica. Bolsillos delanteros y bolsillos de plastrón en espalda. Pernera recta. Cierre frontal con cremallera y botón.",
    "Pantalón de tiro bajo con trabillas. Bolsillos laterales y de vivo en espalda. Cierre frontal con cremallera, botón interior y ganchos metálicos.",
    "Pantalón de tiro medio y cintura elástica. Bolsillos laterales. Pierna recta.",
    "ZARA WOMAN COLLECTION. Pantalón de tiro medio confeccionado en hilatura con algodón. Bolsillos en delantero y espalda. Detalle de efecto moiré y raya planchada en delantero. Cierre frontal con cremallera, botón y gancho metálico.",
    "Pantalón de tiro alto con cintura elástica. Pernera ancha.",
    "ZARA WOMAN COLLECTION. Pantalón confeccionado en hilatura con mezcla de algodón. Tiro medio y cintura con trabillas. Bolsillos laterales y de vivo en espalda. Cinturón ajustable con hebilla metálica. Detalle de raya planchada en delantero. Cierre frontal con cremallera, botón y gancho metálico.",
    "ZARA WOMAN COLLECTION. Pantalón de tiro medio y cintura con trabillas. Bolsillos en delantero y espalda. Bajo acabado en línea evasé. Cierre frontal con cremallera, botón y ganchos metálicos.",
    "Pantalón de tiro medio y cintura con elástico interior. Detalle de banda lateral con aplicación de tejido en tricot a tono. Pierna recta.",
    "Pantalón de tiro medio y cintura ajustable con cordones. Bajo con detalle de aplicación de tejido tipo punto en rib a tono.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales. Detalle de texto combinado a contraste en delantero. Bajo acabado en puño elástico. Debido al proceso de tintado y lavado, el color de cada prenda es único y especial por lo que puede presentar diferencias con respecto al mostrado en la foto.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales. Detalle de texto combinado a contraste en delantero. Debido al proceso de tintado y lavado, el color de cada prenda es único y especial por lo que puede presentar diferencias con respecto al mostrado en la foto.",
    "Pantalón de tiro medio con trabillas. Bolsillos laterales y de vivo en espalda. Detalle de pliegues en delantero. Cierre frontal con cremallera y ganchos metálicos.",
    "Pantalón de tiro alto con trabillas. Detalle de doble pliegue. Bolsillos laterales y falsos bolsillos de vivo en espalda. Cierre frontal con cremallera y botón.",
    "Leggings de tiro medio con cintura elástica. Detalle de falsos botones joya delanteros.",
    "Pantalón de tiro alto con tejido efecto brillo. Bolsillos delanteros. Pernera recta. Cierre frontal con cremallera, botón interior y gancho.",
    "Leggings semitransparente confeccionado en encaje suave. Tiro alto y cintura elástica. Forro interior combinado a tono.",
    "Pantalón de tiro alto con bolsillos laterales ocultos en costura, falsos bolsillos de vivo en espalda. Detalle de pliegues en delantero. Pierna ancha. Cierre frontal con cremallera, botón interior y gancho metálico.",
    "Pantalón de tiro medio con trabillas. Bolsillos laterales ocultos en costura y falsos bolsillos de vivo en espalda. Detalle de pliegues en delantero. Pierna recta ancha. Cierre frontal con cremallera, botón interior y ganchos metálicos.",
    "Pantalón de tiro alto con cintura elástica efecto boxer a tono con detalle de botones. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste. Cierre frontal con cremallera y gancho metálico.",
    "Pantalón de tiro medio con trabillas. Cintura elástica ajustable con cordón en mismo tejido. Bolsillos laterales y de plastrón es espalda. Pierna recta ancha.",
    "Pantalón confeccionado en hilatura con algodón. Tiro medio y cintura con elástico interior. Pierna ancha.",
    "Pantalón de tiro medio con cintura elástica ajustable con lazada. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste.",
    "Leggings semitransparente de tiro alto con cintura elástica. Detalle de encaje. Cierre lateral con cremallera.",
    "Pantalón de tiro medio con cintura elástica. Detalle de pliegues en delantero. Pierna recta.",
    "Pantalón de tiro alto con cintura elástica. Pierna recta.",
    "Pantalón de tiro alto con cintura elástica. Detalle de pliegues en delantero. Pierna ancha.",
]

color = [
    "Crudo",
    "Camel claro",
    "Khaki claro",
    "Negro",
    "Gris antracita",
    "Negro",
    "Negro",
    "Negro / Verde",
    "Gris",
    "Negro",
    "Marrón oscuro",
    "Negro",
    "Gris antracita",
    "Negro",
    "Azul medio",
    "Negro",
    "Khaki oscuro",
    "Gris topo",
    "Beige vigoré",
    "Gris vigoré",
    "Marino",
    "Negro",
    "Negro",
    "Gris medio",
    "Negro",
    "Petróleo claro",
    "Gris medio",
    "Marino",
    "Marrón",
    "Khaki"
]


print(f"Longitud de 'nombre': {len(nombre)}")
print(f"Longitud de 'precio': {len(precio)}")
print(f"Longitud de 'descripcion': {len(descripcion)}")
print(f"Longitud de 'color': {len(color)}")


if (len(nombre) == len(precio) == len(descripcion) == len(color)):
   
    pantalones_df = pd.DataFrame({
        "Nombre": nombre,
        "Precio": precio,
        "Descripción": descripcion,
        "Color": color
    })

   
    print(pantalones_df.head())
else:
    print("Error: Las listas no tienen la misma longitud.")
# Out:
# Longitud de 'nombre': 30
# Longitud de 'precio': 30
# Longitud de 'descripcion': 30
# Longitud de 'color': 30
#                                           Nombre     Precio  \
# 0           PANTALÓN JOGGER SOFT - Crudo de Zara  29,95 EUR
# 1     PANTALÓN JOGGER SOFT - Camel claro de Zara  29,95 EUR
# 2     PANTALÓN JOGGER SOFT - Khaki claro de Zara  25,95 EUR
# 3     PANTALÓN TOBILLERO BRILLOS - Negro de Zara  25,95 EUR
# 4  PANTALÓN LARGO EVASÉ - Gris antracita de Zara  29,95 EUR
#
#                                          Descripción           Color
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro
# 3  Pantalón de tiro alto con cintura elástica. Bo...           Negro
# 4  Pantalón de tiro bajo con trabillas. Bolsillos...  Gris antracita

# %%
nombres = [
    "VESTIDO MINI PUNTO CINTURÓN",
    "VESTIDO MINI PUNTO CINTURÓN",
    "VESTIDO MIDI PUNTO LISO",
    "VESTIDO MIDI TERCIOPELO",
    "VESTIDO MINI LENTEJUELAS ASIMÉTRICO",
    "VESTIDO MIDI SATINADO CUT OUT",
    "VESTIDO MINI SATINADO CUT OUT",
    "VESTIDO MIDI SATINADO",
    "VESTIDO CORTO VUELO",
    "VESTIDO CORTO BAJO VUELO",
    "VESTIDO MIDI DRAPEADO",
    "VESTIDO INTERLOCK",
    "VESTIDO INTERLOCK",
    "VESTIDO INTERLOCK",
    "VESTIDO MULTIPOSICIÓN LENTEJUELAS ZW COLLECTION",
    "VESTIDO SATINADO CONTRASTE ZW COLLECTION",
    "VESTIDO SKATER PUNTO STRETCH",
    "VESTIDO CORTO PUNTO SOFT",
    "VESTIDO CORTO TABLAS",
    "VESTIDO CORTO EFECTO ANTE",
    "VESTIDO CUADROS FRANELA",
    "MONO LARGO PANA",
    "VESTIDO DENIM TRF FLOCK",
    "VESTIDO MIDI ESCOTE PICO",
    "VESTIDO MINI PUNTO",
    "VESTIDO CORTO ESTRUCTURA",
    "VESTIDO CORTO ESTRUCTURA",
    "VESTIDO CORTO ESTRUCTURA",
    "VESTIDO MIDI TERCIOPELO",
    "VESTIDO LARGO CREMALLERAS ZW COLLECTION"
]

colores = [
    "Negro / Marrón",
    "Negro / Marrón",
    "Azul pato",
    "Rojo oscuro",
    "Rojo",
    "Negro",
    "Rojo",
    "Rojo vivo",
    "Negro",
    "Burgundy",
    "Marrón",
    "Beige",
    "Marrón",
    "Negro",
    "Crudo",
    "Negro",
    "Burgundy",
    "Marrón / Topo",
    "Negro",
    "Negro",
    "Crudo / Negro",
    "Rosa",
    "Negro",
    "Gris",
    "Negro",
    "Marrón / Crudo",
    "Negro / Blanco",
    "Negro",
    "Verde azul",
    "Negro"
]

precios = [
    "35,95 EUR",
    "35,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "39,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "22,95 EUR",
    "22,95 EUR",
    "22,95 EUR",
    "69,95 EUR",
    "39,95 EUR",
    "22,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "39,95 EUR",
    "39,95 EUR",
    "49,95 EUR",
    "27,95 EUR",
    "25,95 EUR",
    "29,95 EUR",
    "22,95 EUR",
    "22,95 EUR",
    "22,95 EUR",
    "29,95 EUR"
]

descripcion = [
    "Vestido de cuello redondo y manga sisa. Detalle de cinturón. Bajo en evasé. Cierre lateral con cremallera oculta en costura.",
    "Vestido de cuello barco y manga larga con aplique dorado en hombro.",
    "Vestido de cuello halter con escote pico fluido y espalda descubierta. Bajo con abertura en espalda. Cierre trasero con cremallera oculta en costura.",
    "Vestido de cuello subido y manga larga asimétrica. Detalle de lentejuelas y espalda abierta. Cierre lateral con cremallera oculta en costura. Forro interior.",
    "Vestido de escote pico y tirantes anchos. Detalle de abertura frontal en pecho. Cierre en espalda con cremallera oculta en costura.",
    "Vestido de escote redondo y tirantes anchos. Detalle de abertura en espalda. Cierre lateral con cremallera oculta en costura.",
    "Vestido de cuello redondo y manga sisa enroscada. Detalle de frunces en cintura.",
    "Vestido corto de cuello redondo y manga sisa. Bajo acabado en vuelo. Cierre en espalda con cremallera oculta en costura.",
    "Vestido corto de cuello barco y manga sisa. Bolsillos laterales ocultos en costura. Bajo acabado con vuelo. Forro interior. Cierre en espalda con cremallera oculta en costura.",
    "Vestido midi confeccionado en tejido tipo punto. Cuello subido y manga muy corta. Tejido drapeado. Bajo con abertura en espalda. Forro interior. Cierre con cremallera oculta en espalda.",
    "Vestido confeccionado en tejido de punto elástico y flexible con trama compacta, mullida y opaca. Cuello redondo y manga por el codo. Bajo acabado en vuelo. Cierre en espalda con cremallera oculta en costura.",
    "Vestido confeccionado en tejido de punto elástico y flexible con trama compacta, mullida y opaca. Cuello redondo y manga por el codo. Bajo acabado en vuelo. Cierre en espalda con cremallera oculta en costura.",
    "Vestido confeccionado en tejido de punto elástico y flexible con trama compacta, mullida y opaca. Cuello redondo y manga por el codo. Bajo acabado en vuelo. Cierre en espalda con cremallera oculta en costura.",
    "Vestido largo con cuello redondo confeccionado en tejido con lentejuelas. Manga larga extraíbles con cremalleras ocultas en costura. Bajo acabado con abertura. Cierre en espalda con cremallera oculta.",
    "Vestido corto de cuello redondo y manga sisa. Acabados a contraste. Cierre en espalda con cremallera oculta en costura.",
    "Vestido corto confeccionado en tejido tipo punto. Cuello redondo y manga sisa. Bajo acabado en vuelo.",
    "Vestido de cuello redondo y manga larga. Acabados en rib.",
    "Vestido corto de cuello piso y manga sisa. Detalle de cinturón con hebilla forrada. Bajo acabado en tablas. Forro interior. Cierre frontal con botones.",
    "Vestido corto de escote pico y manga sisa. Falsos bolsillos con solapa en delantero. Bajo acabado en tablas. Cierre lateral con cremallera oculta en costura.",
    "Vestido midi confeccionada en tejido de algodón con acabado franela. Escote redondo y tirantes finos. Cierre lateral con cremallera oculta en costura.",
    "Mono largo de escote recto y tirantes ajustables. Bolsillos laterales y de plastrón en pecho y espalda. Cierre con botones laterales.",
    "Vestido corto de cuello redondo y manga larga. Tejido flocado. Cierre en espalda con cremallera metálica.",
    "Vestido con escote pico y manga larga.",
    "Vestido corto de cuello redondo y manga sisa. Falsos bolsillos de vivo con botón en delantero. Bajo acabado en línea evasé. Cierre en espalda con cremallera oculta en costura.",
    "Vestido de cuello redondo y manga sisa. Detalle de bajo acabado con botones metálicos con relieve.",
    "Vestido corto de cuello redondo y manga corta. Detalle de tejido con estructura. Cierre en espalda con abertura y lazadas.",
    "Vestido corto de cuello redondo y manga corta. Detalle de tejido con estructura. Cierre en espalda con abertura y lazadas.",
    "Vestido corto de cuello redondo y manga corta. Detalle de tejido con estructura. Cierre en espalda con abertura y lazadas.",
    "Vestido de cuello redondo con nudo delantero y mangas asimétricas. Detalle de hebilla dorada y frunces en cintura. Bajo con abertura frontal. Cierre en espalda con cremallera oculta en costura."
]

max_length = max(len(nombres), len(colores), len(precios), len(descripcion))


nombres += [None] * (max_length - len(nombres))
colores += [None] * (max_length - len(colores))
precios += [None] * (max_length - len(precios))
descripcion += [None] * (max_length - len(descripcion))


vestidos_df = pd.DataFrame({
    'Nombre': nombres,
    'Color': colores,
    'Precio': precios,
    'Descripción': descripcion
})


vestidos_df.head(20)
# Out:
#                                              Nombre           Color  \
# 0                       VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón
# 1                       VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón
# 2                           VESTIDO MIDI PUNTO LISO       Azul pato
# 3                           VESTIDO MIDI TERCIOPELO     Rojo oscuro
# 4               VESTIDO MINI LENTEJUELAS ASIMÉTRICO            Rojo
# 5                     VESTIDO MIDI SATINADO CUT OUT           Negro
# 6                     VESTIDO MINI SATINADO CUT OUT            Rojo
# 7                             VESTIDO MIDI SATINADO       Rojo vivo
# 8                               VESTIDO CORTO VUELO           Negro
# 9                          VESTIDO CORTO BAJO VUELO        Burgundy
# 10                            VESTIDO MIDI DRAPEADO          Marrón
# 11                                VESTIDO INTERLOCK           Beige
# 12                                VESTIDO INTERLOCK          Marrón
# ...

# %%
nombres = [
    "JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara",
    "JERSEY PUNTO BOTONES LATERALES - Gris de Zara",
    "JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara",
    "CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara",
    "JERSEY PUNTO ABIERTO - Negro de Zara",
    "JERSEY PUNTO CALADOS - Mantequilla de Zara",
    "JERSEY PUNTO CUELLO VOLANTES - Crudo de Zara",
    "CHAQUETA PUNTO JACQUARD ANIMAL - Tigre de Zara",
    "JERSEY PUNTO JACQUARD ANIMAL - Crudo/Kaki de Zara",
    "TOP MANGA CORTA CON ALPACA Y LANA - Mostaza de Zara",
    "JERSEY PUNTO CUELLO ASIMÉTRICO - Lila de Zara",
    "SUDADERA PUNTO JACQUARD ANIMAL - Leopardo de Zara",
    "JERSEY EFECTO PELO FLORES - Crudo de Zara",
    "TOP PUNTO LAZO ORGANZA - Crudo de Zara",
    "TOP PUNTO LAZO ORGANZA - Negro de Zara",
    "JERSEY PUNTO LISO - Marino de Zara",
    "ABRIGO LARGO PUNTO OCHOS - Crudo de Zara",
    "CHAQUETA CRUZADA LANA 100% - Negro de Zara",
    "CHAQUETA CRUZADA LANA 100% - Marrón de Zara",
    "JERSEY PUNTO JACQUARD CUADROS - Negro / Marrón de Zara",
    "CHAQUETA POINTELLE CON LANA Y ALPACA - Blanco de Zara",
    "CHAQUETA PUNTO JACQUARD ROMBOS - Multicolor de Zara",
    "JERSEY PUNTO JACQUARD - Crudo / Marino de Zara",
    "JERSEY PUNTO PEDRERÍA CON ALPACA - Verde agua de Zara",
    "CHAQUETA PUNTO APLIQUE DORADO - Gris oscuro de Zara",
    "JERSEY PUNTO EFECTO PELO BROCHES - Marrón de Zara",
    "JERSEY PUNTO JACQUARD CUADROS - Negro / Marrón de Zara",
    "JERSEY SOFT PUNTO - Gris claro de Zara",
    "JERSEY OVERSIZE PUNTO JACQUARD - Multicolor de Zara",
    "JERSEY PONCHO PUNTO CALADOS - Crudo de Zara"
]

color = [
    "Leopardo",
    "Gris",
    "Crudo",
    "Gris",
    "Negro",
    "Mantequilla",
    "Crudo",
    "Tigre",
    "Crudo/Kaki",
    "Mostaza",
    "Lila",
    "Leopardo",
    "Crudo",
    "Crudo",
    "Negro",
    "Marino",
    "Crudo",
    "Negro",
    "Marrón",
    "Negro / Marrón",
    "Blanco",
    "Multicolor",
    "Crudo / Marino",
    "Verde agua",
    "Gris oscuro",
    "Marrón",
    "Negro / Marrón",
    "Gris claro",
    "Multicolor",
    "Crudo"
]

descripcion = [
    "Acabados en rib.",
    "Bajo acabado con botones laterales.",
    "Acabados con volantes y bajo con cordón delantero.",
    "Escote pico y manga larga. Cierre frontal con botones.",
    "Detalle de tiras laterales.",
    "Jersey de punto abierto con cuello redondo y manga larga.",
    "Acabados en puño.",
    "Bolsillos delanteros. Acabados en rib. Cierre frontal con botones.",
    "Jersey de cuello subido y manga larga.",
    "Cuello redondo y manga corta.",
    "Botones en hombro.",
    "Bolsillo delantero. Acabados en rib.",
    "Tejido tacto suave. Detalle de aplicación de flores en relieve combinadas a tono.",
    "Detalle de lazo combinado en organza. Cierre frontal con botones.",
    "Detalle de lazo combinado en organza.",
    "Acabados en rib.",
    "Bolsillos delanteros de plastrón. Acabados en rib.",
    "Cierre frontal cruzado con botones.",
    "Cierre frontal cruzado con botones.",
    "Detalle de jacquard y tejido efecto cepillado.",
    "Cuello redondo y manga larga. Cierre frontal con botones.",
    "Bolsillos delanteros de plastrón. Detalle de jacquard y tejido efecto cepillado. Cierre frontal con botones a presión ocultos.",
    "Acabados en rib.",
    "Detalle de aplicación de abalorios joya. Acabados en rib.",
    "Detalle de aplique dorado delantero.",
    "Detalle de tejido efecto pelo y broches delanteros. Acabados en rib.",
    "Detalle de jacquard y tejido efecto cepillado.",
    "Acabados en rib.",
    "Detalle de jacquard y tejido efecto cepillado.",
    "Jersey estilo poncho de cuello subido y manga larga."
]
precios = [
    "29,95 EUR",
    "27,95 EUR",
    "49,95 EUR",
    "29,95 EUR",
    "39,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "49,95 EUR",
    "25,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "69,95 EUR",
    "45,95 EUR",
    "45,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "49,95 EUR",
    "29,95 EUR",
    "59,95 EUR",
    "39,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "27,95 EUR",
    "35,95 EUR",
    "59,95 EUR"
]

lengths = {
    "nombres": len(nombres),
    "color": len(color),
    "descripcion": len(descripcion),
    "precios": len(precios),
}

print(lengths)


max_length = max(lengths.values())
nombres += [None] * (max_length - len(nombres))
color += [None] * (max_length - len(color))
descripcion += [None] * (max_length - len(descripcion))
precios += [None] * (max_length - len(precios))


data = {
    "Nombre": nombres,
    "Color": color,
    "Descripción": descripcion,
    "Precio": precios
}

jerseys_df = pd.DataFrame(data)
# Out:
# {'nombres': 30, 'color': 30, 'descripcion': 30, 'precios': 30}

# %%
jerseys_df.head(20)
# Out:
#                                                Nombre           Color  \
# 0     JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara        Leopardo
# 1       JERSEY PUNTO BOTONES LATERALES - Gris de Zara            Gris
# 2      JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara           Crudo
# 3        CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara            Gris
# 4                JERSEY PUNTO ABIERTO - Negro de Zara           Negro
# 5          JERSEY PUNTO CALADOS - Mantequilla de Zara     Mantequilla
# 6        JERSEY PUNTO CUELLO VOLANTES - Crudo de Zara           Crudo
# 7      CHAQUETA PUNTO JACQUARD ANIMAL - Tigre de Zara           Tigre
# 8   JERSEY PUNTO JACQUARD ANIMAL - Crudo/Kaki de Zara      Crudo/Kaki
# 9   TOP MANGA CORTA CON ALPACA Y LANA - Mostaza de...         Mostaza
# 10      JERSEY PUNTO CUELLO ASIMÉTRICO - Lila de Zara            Lila
# 11  SUDADERA PUNTO JACQUARD ANIMAL - Leopardo de Zara        Leopardo
# ...

# %%
nombre = [
    "PANTALÓN JOGGER SOFT - Crudo de Zara",
    "PANTALÓN JOGGER SOFT - Camel claro de Zara",
    "PANTALÓN JOGGER SOFT - Khaki claro de Zara",
    "PANTALÓN TOBILLERO BRILLOS - Negro de Zara",
    "PANTALÓN LARGO EVASÉ - Gris antracita de Zara",
    "PANTALÓN RECTO PUNTO BOTONES LATERALES - Negro de Zara",
    "PANTALÓN RECTO EFECTO PIEL - Negro de Zara",
    "PANTALÓN ESTAMPADO LONG LENGTH - Negro / Verde de Zara",
    "PANTALÓN ANCHO CINTURÓN - Gris de Zara",
    "PANTALÓN RECTO EFECTO PIEL - Negro de Zara",
    "PANTALÓN RECTO PUNTO - Marrón oscuro de Zara",
    "PANTALÓN PINZAS BAJO AJUSTABLE - Negro de Zara",
    "PANTALÓN TIRO ALTO - Gris antracita de Zara",
    "PANTALÓN TOBILLERO SOFT - Negro de Zara",
    "JEANS Z1975 RECTOS TIRO ALTO - Azul medio de Zara",
    "PANTALÓN ANCHO ESTRUCTURA - Negro de Zara",
    "PANTALÓN RECTO ZW COLLECTION - Khaki oscuro de Zara",
    "PANTALÓN TOBILLERO PINZAS ZW COLLECTION - Gris topo de Zara",
    "PANTALÓN SOFT - Beige vigoré de Zara",
    "PANTALÓN SOFT - Gris vigoré de Zara",
    "PANTALÓN PANA CORDONES - Marino de Zara",
    "PANTALÓN SATINADO PESPUNTES ZW COLLECTION - Negro de Zara",
    "PANTALÓN BARREL BOTÓN BAJO - Negro de Zara",
    "PANTALÓN BARREL BOTÓN BAJO - Gris medio de Zara",
    "PANTALÓN BOXER VIVO LATERAL - Negro de Zara",
    "PANTALÓN BOXER VIVO LATERAL - Petróleo claro de Zara",
    "PANTALÓN JOGGER TEXTO BANDA - Gris medio de Zara",
    "PANTALÓN FELPA TEXTO BANDA LATERAL - Marino de Zara",
    "PANTALÓN FLARE INTERLOCK COSTURAS - Marrón de Zara",
    "BERMUDA LARGA PINZAS ZW COLLECTION - Khaki de Zara"
]

precio = [
    "29,95 EUR",
    "29,95 EUR",
    "25,95 EUR",
    "25,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "39,95 EUR",
    "29,95 EUR",
    "25,95 EUR",
    "25,95 EUR",
    "22,95 EUR",
    "29,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "22,95 EUR",
    "25,95 EUR",
    "35,95 EUR",
    "29,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "35,95 EUR",
    "25,95 EUR",
    "35,95 EUR",
]

descripcion = [
    "Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.",
    "Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado. Pinzas frontales. Bolsillos delanteros y falso bolsillo de vivo en espalda. Pernera ancha.",
    "Pantalón tobillero de tiro alto con detalle de costuras marcadas en delantero y espalda. Bolsillos delanteros de vivo. Cierre frontal con cremallera, botón interior y gancho metálico.",
    "Pantalón de tiro alto con cintura elástica. Bolsillos delanteros y bolsillos de plastrón en espalda. Pernera recta. Cierre frontal con cremallera y botón.",
    "Pantalón de tiro bajo con trabillas. Bolsillos laterales y de vivo en espalda. Cierre frontal con cremallera, botón interior y ganchos metálicos.",
    "Pantalón de tiro medio y cintura elástica. Bolsillos laterales. Pierna recta.",
    "ZARA WOMAN COLLECTION. Pantalón de tiro medio confeccionado en hilatura con algodón. Bolsillos en delantero y espalda. Detalle de efecto moiré y raya planchada en delantero. Cierre frontal con cremallera, botón y gancho metálico.",
    "Pantalón de tiro alto con cintura elástica. Pernera ancha.",
    "ZARA WOMAN COLLECTION. Pantalón confeccionado en hilatura con mezcla de algodón. Tiro medio y cintura con trabillas. Bolsillos laterales y de vivo en espalda. Cinturón ajustable con hebilla metálica. Detalle de raya planchada en delantero. Cierre frontal con cremallera, botón y gancho metálico.",
    "ZARA WOMAN COLLECTION. Pantalón de tiro medio y cintura con trabillas. Bolsillos en delantero y espalda. Bajo acabado en línea evasé. Cierre frontal con cremallera, botón y ganchos metálicos.",
    "Pantalón de tiro medio y cintura con elástico interior. Detalle de banda lateral con aplicación de tejido en tricot a tono. Pierna recta.",
    "Pantalón de tiro medio y cintura ajustable con cordones. Bajo con detalle de aplicación de tejido tipo punto en rib a tono.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales. Detalle de texto combinado a contraste en delantero. Bajo acabado en puño elástico. Debido al proceso de tintado y lavado, el color de cada prenda es único y especial por lo que puede presentar diferencias con respecto al mostrado en la foto.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales. Detalle de texto combinado a contraste en delantero. Debido al proceso de tintado y lavado, el color de cada prenda es único y especial por lo que puede presentar diferencias con respecto al mostrado en la foto.",
    "Pantalón de tiro medio con trabillas. Bolsillos laterales y de vivo en espalda. Detalle de pliegues en delantero. Cierre frontal con cremallera y ganchos metálicos.",
    "Pantalón de tiro alto con trabillas. Detalle de doble pliegue. Bolsillos laterales y falsos bolsillos de vivo en espalda. Cierre frontal con cremallera y botón.",
    "Leggings de tiro medio con cintura elástica. Detalle de falsos botones joya delanteros.",
    "Pantalón de tiro alto con tejido efecto brillo. Bolsillos delanteros. Pernera recta. Cierre frontal con cremallera, botón interior y gancho.",
    "Leggings semitransparente confeccionado en encaje suave. Tiro alto y cintura elástica. Forro interior combinado a tono.",
    "Pantalón de tiro alto con bolsillos laterales ocultos en costura, falsos bolsillos de vivo en espalda. Detalle de pliegues en delantero. Pierna ancha. Cierre frontal con cremallera, botón interior y gancho metálico.",
    "Pantalón de tiro medio con trabillas. Bolsillos laterales ocultos en costura y falsos bolsillos de vivo en espalda. Detalle de pliegues en delantero. Pierna recta ancha. Cierre frontal con cremallera, botón interior y ganchos metálicos.",
    "Pantalón de tiro alto con cintura elástica efecto boxer a tono con detalle de botones. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste. Cierre frontal con cremallera y gancho metálico.",
    "Pantalón de tiro medio con trabillas. Cintura elástica ajustable con cordón en mismo tejido. Bolsillos laterales y de plastrón es espalda. Pierna recta ancha.",
    "Pantalón confeccionado en hilatura con algodón. Tiro medio y cintura con elástico interior. Pierna ancha.",
    "Pantalón de tiro medio con cintura elástica ajustable con lazada. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste.",
    "Pantalón de tiro medio con cintura elástica ajustable con cordones. Bolsillos laterales y de vivo en espalda. Detalle de banda lateral con vivo a contraste.",
    "Leggings semitransparente de tiro alto con cintura elástica. Detalle de encaje. Cierre lateral con cremallera.",
    "Pantalón de tiro medio con cintura elástica. Detalle de pliegues en delantero. Pierna recta.",
    "Pantalón de tiro alto con cintura elástica. Pierna recta.",
    "Pantalón de tiro alto con cintura elástica. Detalle de pliegues en delantero. Pierna ancha.",
]

color = [
    "Crudo",
    "Camel claro",
    "Khaki claro",
    "Negro",
    "Gris antracita",
    "Negro",
    "Negro",
    "Negro / Verde",
    "Gris",
    "Negro",
    "Marrón oscuro",
    "Negro",
    "Gris antracita",
    "Negro",
    "Azul medio",
    "Negro",
    "Khaki oscuro",
    "Gris topo",
    "Beige vigoré",
    "Gris vigoré",
    "Marino",
    "Negro",
    "Negro",
    "Gris medio",
    "Negro",
    "Petróleo claro",
    "Gris medio",
    "Marino",
    "Marrón",
    "Khaki"
]




if (len(nombre) == len(precio) == len(descripcion) == len(color)):
    
    pantalones_df = pd.DataFrame({
        "Nombre": nombre,
        "Precio": precio,
        "Descripción": descripcion,
        "Color": color
    })
else:
    print("Error: Las listas no tienen la misma longitud.")


pantalones_df.head()
# Out:
#                                           Nombre     Precio  \
# 0           PANTALÓN JOGGER SOFT - Crudo de Zara  29,95 EUR
# 1     PANTALÓN JOGGER SOFT - Camel claro de Zara  29,95 EUR
# 2     PANTALÓN JOGGER SOFT - Khaki claro de Zara  25,95 EUR
# 3     PANTALÓN TOBILLERO BRILLOS - Negro de Zara  25,95 EUR
# 4  PANTALÓN LARGO EVASÉ - Gris antracita de Zara  29,95 EUR
#
#                                          Descripción           Color
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro
# 3  Pantalón de tiro alto con cintura elástica. Bo...           Negro
# 4  Pantalón de tiro bajo con trabillas. Bolsillos...  Gris antracita

# %%
bolsos_df.head()
# Out:
#                                               Nombre  \
# 0           MINI SACA TERCIOPELO FLOR - Ocre de Zara
# 1        MAXI SACA EFECTO TERCIOPELO - Negro de Zara
# 2           BOLSO DE HOMBRO ALARGADO - Negro de Zara
# 3      BANDOLERA EFECTO COCO SERRAJE - 1-155 de Zara
# 4  BOLSO DE HOMBRO OVALADO CON EFECTO ENGOMADO - ...
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría
# 0    Bolsos
# 1    Bolsos
# 2    Bolsos
# 3    Bolsos
# 4    Bolsos

# %%
abrigos_df.head()
# Out:
#                                     Nombre  \
# 0    ABRIGO LARGO CON LANA - Negro de Zara
# 1  ABRIGO CRUZADO CON LANA - Negro de Zara
# 2      ABRIGO OVERSIZE SOFT - Gris de Zara
# 3     ABRIGO OVERSIZE SOFT - Beige de Zara
# 4     ABRIGO OVERSIZE SOFT - Negro de Zara
#
#                                          Descripción        Color     Precio
# 0  Abrigo de cuello solapa y manga larga. Bolsill...        Crudo  89,95 EUR
# 1  Abrigo de cuello solapa y manga larga. Bolsill...         Rojo  49,95 EUR
# 2  Abrigo de cuello solapa y manga larga. Bolsill...      Tostado  39,95 EUR
# 3  Abrigo con capucha y manga larga. Bolsillos la...  Camel claro  49,95 EUR
# 4  Anorak acolchado resistente al agua y al vient...        Negro  69,95 EUR

# %%
camisas_df.head()
# Out:
#                                               Nombre  \
# 0  CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de...
# 1  BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro...
# 2       BLUSA VOLANTES ZW COLLECTION - Negro de Zara
# 3                 BLUSA TUL ESTAMPADO - Azul de Zara
# 4        BLUSA TUL ESTAMPADO - Negro / Arena de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/camisa-denim-pespun...
# 1  https://www.zara.com/es/es/blusa-romantica-vol...
# 2  https://www.zara.com/es/es/blusa-volantes-zw-c...
# 3  https://www.zara.com/es/es/blusa-tul-estampado...
# 4  https://www.zara.com/es/es/blusa-tul-estampado...
#
#                                          Descripción  Precio categoría
# 0  ZARA WOMAN COLLECTIONCamisa confeccionada en h...   29.99    prenda
# 1  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   35.99    prenda
# 2  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   39.99    prenda
# ...

# %%
vestidos_df.head()
# Out:
#                                 Nombre           Color     Precio  \
# 0          VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón  35,95 EUR
# 1          VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón  35,95 EUR
# 2              VESTIDO MIDI PUNTO LISO       Azul pato  39,95 EUR
# 3              VESTIDO MIDI TERCIOPELO     Rojo oscuro  29,95 EUR
# 4  VESTIDO MINI LENTEJUELAS ASIMÉTRICO            Rojo  39,95 EUR
#
#                                          Descripción
# 0  Vestido de cuello redondo y manga sisa. Detall...
# 1  Vestido de cuello barco y manga larga con apli...
# 2  Vestido de cuello halter con escote pico fluid...
# 3  Vestido de cuello subido y manga larga asimétr...
# 4  Vestido de escote pico y tirantes anchos. Deta...

# %%
zapatos_df.head()
# Out:
#                                        Nombre  \
# 0        BOTÍN PLANO PICADOS - Marrón de Zara
# 1        BOTÍN PLANO PICADOS - Marrón de Zara
# 2  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 3  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 4           BOTÍN COWBOY PIEL - Negro de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/botin-plano-picados...
# 1  https://www.zara.com/es/es/botin-plano-picados...
# 2  https://www.zara.com/es/es/botin-plano-piel-co...
# 3  https://www.zara.com/es/es/botin-plano-piel-co...
# 4  https://www.zara.com/es/es/botin-cowboy-piel-p...
#
#                                          Descripción     Precio
# 0  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR
# 1  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR
# 2  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR
# 3  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR
# ...

# %%
chalecos_df.head()
# Out:
#                                               Nombre  \
# 0  BLAZER SIN SOLAPA LENTEJUELAS - Negro / Plata ...
# 1      BLAZER SIN SOLAPA LENTEJUELAS - Negro de Zara
# 2        BLAZER CORTA BRILLO - Negro / Plata de Zara
# 3  BLAZER OVERSIZE RAYA DIPLOMÁTICA - Gris oscuro...
# 4  CHALECO RAYA DIPLOMÁTICA - Gris antracita de Zara
#
#                                          Descripción     Precio  \
# 0  Blazer sin solapa con manga larga y hombreras....  59,95 EUR
# 1  Blazer de cuello sin solapa y manga larga con ...  59,95 EUR
# 2  Blazer corta con tejido efecto brillo. Cuello ...  49,95 EUR
# 3  Blazer oversize de cuello solapa y manga larga...  59,95 EUR
# 4  Chaleco de escote pico y manga sisa. Bolsillos...  25,95 EUR
#
#             Color Categoría
# 0   Negro / Plata   Blazers
# 1           Negro   Blazers
# 2   Negro / Plata   Blazers
# 3     Gris oscuro   Blazers
# 4  Gris antracita   Blazers

# %%
jerseys_df.head()
# Out:
#                                             Nombre     Color  \
# 0  JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara  Leopardo
# 1    JERSEY PUNTO BOTONES LATERALES - Gris de Zara      Gris
# 2   JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara     Crudo
# 3     CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara      Gris
# 4             JERSEY PUNTO ABIERTO - Negro de Zara     Negro
#
#                                          Descripción     Precio
# 0                                   Acabados en rib.  29,95 EUR
# 1                Bajo acabado con botones laterales.  27,95 EUR
# 2  Acabados con volantes y bajo con cordón delant...  49,95 EUR
# 3  Escote pico y manga larga. Cierre frontal con ...  29,95 EUR
# 4                        Detalle de tiras laterales.  39,95 EUR

# %%
pantalones_df['categoría'] = 'pantalón'

# %%
pantalones_df.head()
# Out:
#                                           Nombre     Precio  \
# 0           PANTALÓN JOGGER SOFT - Crudo de Zara  29,95 EUR
# 1     PANTALÓN JOGGER SOFT - Camel claro de Zara  29,95 EUR
# 2     PANTALÓN JOGGER SOFT - Khaki claro de Zara  25,95 EUR
# 3     PANTALÓN TOBILLERO BRILLOS - Negro de Zara  25,95 EUR
# 4  PANTALÓN LARGO EVASÉ - Gris antracita de Zara  29,95 EUR
#
#                                          Descripción           Color categoría
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo  pantalón
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro  pantalón
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro  pantalón
# 3  Pantalón de tiro alto con cintura elástica. Bo...           Negro  pantalón
# 4  Pantalón de tiro bajo con trabillas. Bolsillos...  Gris antracita  pantalón

# %%
bolsos_df['categoría'] = 'accesorio'
abrigos_df['categoría'] = 'prenda'
camisas_df['categoría'] = 'prenda'
zapatos_df['categoría'] = 'calzado'
jerseys_df['categoría'] = 'prenda'
vestidos_df['categoría'] = 'prenda'
chalecos_df['categoría'] = 'prenda'
pantalones_df['categoría'] = 'prenda'

# %%
bolsos_df.head()
# Out:
#                                               Nombre  \
# 0           MINI SACA TERCIOPELO FLOR - Ocre de Zara
# 1        MAXI SACA EFECTO TERCIOPELO - Negro de Zara
# 2           BOLSO DE HOMBRO ALARGADO - Negro de Zara
# 3      BANDOLERA EFECTO COCO SERRAJE - 1-155 de Zara
# 4  BOLSO DE HOMBRO OVALADO CON EFECTO ENGOMADO - ...
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría  categoría
# 0    Bolsos  accesorio
# 1    Bolsos  accesorio
# 2    Bolsos  accesorio
# 3    Bolsos  accesorio
# 4    Bolsos  accesorio

# %%
pantalones_df.head()
# Out:
#                                           Nombre     Precio  \
# 0           PANTALÓN JOGGER SOFT - Crudo de Zara  29,95 EUR
# 1     PANTALÓN JOGGER SOFT - Camel claro de Zara  29,95 EUR
# 2     PANTALÓN JOGGER SOFT - Khaki claro de Zara  25,95 EUR
# 3     PANTALÓN TOBILLERO BRILLOS - Negro de Zara  25,95 EUR
# 4  PANTALÓN LARGO EVASÉ - Gris antracita de Zara  29,95 EUR
#
#                                          Descripción           Color categoría
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo    prenda
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro    prenda
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro    prenda
# 3  Pantalón de tiro alto con cintura elástica. Bo...           Negro    prenda
# 4  Pantalón de tiro bajo con trabillas. Bolsillos...  Gris antracita    prenda

# %%
camisas_df.head()
# Out:
#                                               Nombre  \
# 0  CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de...
# 1  BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro...
# 2       BLUSA VOLANTES ZW COLLECTION - Negro de Zara
# 3                 BLUSA TUL ESTAMPADO - Azul de Zara
# 4        BLUSA TUL ESTAMPADO - Negro / Arena de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/camisa-denim-pespun...
# 1  https://www.zara.com/es/es/blusa-romantica-vol...
# 2  https://www.zara.com/es/es/blusa-volantes-zw-c...
# 3  https://www.zara.com/es/es/blusa-tul-estampado...
# 4  https://www.zara.com/es/es/blusa-tul-estampado...
#
#                                          Descripción  Precio categoría
# 0  ZARA WOMAN COLLECTIONCamisa confeccionada en h...   29.99    prenda
# 1  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   35.99    prenda
# 2  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   39.99    prenda
# ...

# %%
zapatos_df.head()
# Out:
#                                        Nombre  \
# 0        BOTÍN PLANO PICADOS - Marrón de Zara
# 1        BOTÍN PLANO PICADOS - Marrón de Zara
# 2  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 3  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 4           BOTÍN COWBOY PIEL - Negro de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/botin-plano-picados...
# 1  https://www.zara.com/es/es/botin-plano-picados...
# 2  https://www.zara.com/es/es/botin-plano-piel-co...
# 3  https://www.zara.com/es/es/botin-plano-piel-co...
# 4  https://www.zara.com/es/es/botin-cowboy-piel-p...
#
#                                          Descripción     Precio categoría
# 0  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR   calzado
# 1  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR   calzado
# 2  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR   calzado
# ...

# %%
jerseys_df.head()
# Out:
#                                             Nombre     Color  \
# 0  JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara  Leopardo
# 1    JERSEY PUNTO BOTONES LATERALES - Gris de Zara      Gris
# 2   JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara     Crudo
# 3     CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara      Gris
# 4             JERSEY PUNTO ABIERTO - Negro de Zara     Negro
#
#                                          Descripción     Precio categoría
# 0                                   Acabados en rib.  29,95 EUR    prenda
# 1                Bajo acabado con botones laterales.  27,95 EUR    prenda
# 2  Acabados con volantes y bajo con cordón delant...  49,95 EUR    prenda
# 3  Escote pico y manga larga. Cierre frontal con ...  29,95 EUR    prenda
# 4                        Detalle de tiras laterales.  39,95 EUR    prenda

# %%
vestidos_df.head()
# Out:
#                                 Nombre           Color     Precio  \
# 0          VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón  35,95 EUR
# 1          VESTIDO MINI PUNTO CINTURÓN  Negro / Marrón  35,95 EUR
# 2              VESTIDO MIDI PUNTO LISO       Azul pato  39,95 EUR
# 3              VESTIDO MIDI TERCIOPELO     Rojo oscuro  29,95 EUR
# 4  VESTIDO MINI LENTEJUELAS ASIMÉTRICO            Rojo  39,95 EUR
#
#                                          Descripción categoría
# 0  Vestido de cuello redondo y manga sisa. Detall...    prenda
# 1  Vestido de cuello barco y manga larga con apli...    prenda
# 2  Vestido de cuello halter con escote pico fluid...    prenda
# 3  Vestido de cuello subido y manga larga asimétr...    prenda
# 4  Vestido de escote pico y tirantes anchos. Deta...    prenda

# %%
chalecos_df.head()
# Out:
#                                               Nombre  \
# 0  BLAZER SIN SOLAPA LENTEJUELAS - Negro / Plata ...
# 1      BLAZER SIN SOLAPA LENTEJUELAS - Negro de Zara
# 2        BLAZER CORTA BRILLO - Negro / Plata de Zara
# 3  BLAZER OVERSIZE RAYA DIPLOMÁTICA - Gris oscuro...
# 4  CHALECO RAYA DIPLOMÁTICA - Gris antracita de Zara
#
#                                          Descripción     Precio  \
# 0  Blazer sin solapa con manga larga y hombreras....  59,95 EUR
# 1  Blazer de cuello sin solapa y manga larga con ...  59,95 EUR
# 2  Blazer corta con tejido efecto brillo. Cuello ...  49,95 EUR
# 3  Blazer oversize de cuello solapa y manga larga...  59,95 EUR
# 4  Chaleco de escote pico y manga sisa. Bolsillos...  25,95 EUR
#
#             Color Categoría categoría
# 0   Negro / Plata   Blazers    prenda
# 1           Negro   Blazers    prenda
# 2   Negro / Plata   Blazers    prenda
# 3     Gris oscuro   Blazers    prenda
# 4  Gris antracita   Blazers    prenda

# %%
abrigos_df.head()
# Out:
#                                     Nombre  \
# 0    ABRIGO LARGO CON LANA - Negro de Zara
# 1  ABRIGO CRUZADO CON LANA - Negro de Zara
# 2      ABRIGO OVERSIZE SOFT - Gris de Zara
# 3     ABRIGO OVERSIZE SOFT - Beige de Zara
# 4     ABRIGO OVERSIZE SOFT - Negro de Zara
#
#                                          Descripción        Color     Precio  \
# 0  Abrigo de cuello solapa y manga larga. Bolsill...        Crudo  89,95 EUR
# 1  Abrigo de cuello solapa y manga larga. Bolsill...         Rojo  49,95 EUR
# 2  Abrigo de cuello solapa y manga larga. Bolsill...      Tostado  39,95 EUR
# 3  Abrigo con capucha y manga larga. Bolsillos la...  Camel claro  49,95 EUR
# 4  Anorak acolchado resistente al agua y al vient...        Negro  69,95 EUR
#
#   categoría
# 0    prenda
# 1    prenda
# 2    prenda
# 3    prenda
# 4    prenda

# %%
bolsos_df.to_csv("bolsos.csv", index=False)
abrigos_df.to_csv("abrigos.csv", index=False)
camisas_df.to_csv("camisas.csv", index=False)
zapatos_df.to_csv("zapatos.csv", index=False)
jerseys_df.to_csv("jerseys.csv", index=False)
vestidos_df.to_csv("vestidos.csv", index=False)
chalecos_df.to_csv("chalecos.csv", index=False)
pantalones_df.to_csv("pantalones.csv", index=False)
