# %%
import pandas as pd

# %%
bolsos_df = pd.read_csv("bolsos.csv")

# %%
bolsos_df.head()
# Out:
#                                               Nombre  \
# 0           MINI SACA TERCIOPELO FLOR - Ocre de Zara
# 1        MAXI SACA EFECTO TERCIOPELO - Negro de Zara
# 2           BOLSO DE HOMBRO ALARGADO - Negro de Zara
# 3      BANDOLERA EFECTO COCO SERRAJE - 1-155 de Zara
# 4  BOLSO DE HOMBRO OVALADO CON EFECTO ENGOMADO - ...
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría  categoría
# 0    Bolsos  accesorio
# 1    Bolsos  accesorio
# 2    Bolsos  accesorio
# 3    Bolsos  accesorio
# 4    Bolsos  accesorio

# %%
bolsos_df.tail()
# Out:
#                                               Nombre  \
# 10            BOLSO EFECTO COCODRILO - Negro de Zara
# 11                      BOLSO CANGURO - Rosa de Zara
# 12  SACA TERCIOPELO CON DETALLE FLOR - Verde de Zara
# 13                     CLUTCH BRILLO - Negro de Zara
# 14        BOLSO TOTE EFECTO COCODRILO - Azul de Zara
#
#                                           Descripción     Precio  Color  \
# 10  Bolso efecto cocodrilo con cierre mediante cre...  59,95 EUR  Negro
# 11  Bolso tipo canguro con diseño suave. Asa de ho...  49,95 EUR   Rosa
# 12  Bolso saca en terciopelo con detalle de flor e...  39,95 EUR  Verde
# 13  Clutch con efecto brillo y cadena. Cierre medi...  34,95 EUR  Negro
# 14  Bolso tipo tote en efecto cocodrilo. Asa larga...  69,95 EUR   Azul
#
#    Categoría  categoría
# 10    Bolsos  accesorio
# 11    Bolsos  accesorio
# 12    Bolsos  accesorio
# 13    Bolsos  accesorio
# 14    Bolsos  accesorio

# %%
bolsos_df.shape
# Out:
# (15, 6)

# %%
bolsos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       15 non-null     object
#  1   Descripción  15 non-null     object
#  2   Precio       15 non-null     object
#  3   Color        15 non-null     object
#  4   Categoría    15 non-null     object
#  5   categoría    15 non-null     object
# dtypes: object(6)
# memory usage: 852.0+ bytes

# %%
print(bolsos_df.isnull().sum())
# Out:
# Nombre         0
# Descripción    0
# Precio         0
# Color          0
# Categoría      0
# categoría      0
# dtype: int64

# %%
bolsos_df.dtypes
# Out:
# Nombre         object
# Descripción    object
# Precio         object
# Color          object
# Categoría      object
# categoría      object
# dtype: object

# %%
bolsos_df2 = bolsos_df.copy()

# %%
bolsos_df2['Nombre'] = bolsos_df2['Nombre'].str.title()

# %%
bolsos_df2.head()
# Out:
#                                               Nombre  \
# 0           Mini Saca Terciopelo Flor - Ocre De Zara
# 1        Maxi Saca Efecto Terciopelo - Negro De Zara
# 2           Bolso De Hombro Alargado - Negro De Zara
# 3      Bandolera Efecto Coco Serraje - 1-155 De Zara
# 4  Bolso De Hombro Ovalado Con Efecto Engomado - ...
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría  categoría
# 0    Bolsos  accesorio
# 1    Bolsos  accesorio
# 2    Bolsos  accesorio
# 3    Bolsos  accesorio
# 4    Bolsos  accesorio

# %%
bolsos_df2['Nombre'] = bolsos_df2["Nombre"].str.split(" - ").str[0]

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción     Precio  Color  \
# 0  Bolso formato mini saca en efecto terciopelo. ...  39,95 EUR   Ocre
# 1  Bolso formato maxi saca en efecto terciopelo. ...  49,95 EUR  Negro
# 2  Bolso formato de hombro con forma alargada. De...  35,95 EUR  Negro
# 3  Bolso formato bandolera en serraje. Efecto coc...  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría  categoría
# 0    Bolsos  accesorio
# 1    Bolsos  accesorio
# 2    Bolsos  accesorio
# 3    Bolsos  accesorio
# 4    Bolsos  accesorio

# %%
bolsos_df2['Descripción']
# Out:
# 0     Bolso formato mini saca en efecto terciopelo. ...
# 1     Bolso formato maxi saca en efecto terciopelo. ...
# 2     Bolso formato de hombro con forma alargada. De...
# 3     Bolso formato bandolera en serraje. Efecto coc...
# 4     Bolso de hombro de formato ovalado con efecto ...
# 5     Bolso de hombro de formato rectangular con efe...
# 6     Bolso bandolera en material suave. Cierre medi...
# 7     Clutch en efecto piel con asa de mano. Cierre ...
# 8     Mallet de efecto brillo con detalle de cadena ...
# 9     Bolso de saca pequeña con asa ajustable. Cierr...
# 10    Bolso efecto cocodrilo con cierre mediante cre...
# 11    Bolso tipo canguro con diseño suave. Asa de ho...
# 12    Bolso saca en terciopelo con detalle de flor e...
# 13    Clutch con efecto brillo y cadena. Cierre medi...
# 14    Bolso tipo tote en efecto cocodrilo. Asa larga...
# Name: Descripción, dtype: object

# %%
with pd.option_context('display.max_colwidth', None):
    print(bolsos_df2['Descripción'])
# Out:
# 0                                                                                                                                                                                                                                                                                                 Bolso formato mini saca en efecto terciopelo. Detalle de flor en la parte delantera. Asa de mano y asa bandolera en cadena. Bolsillo interior con cierre mediante fruncido. Alto x Ancho x Fondo: 18 x 21 x 3,5 cm.
# ...

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.')  
        return partes[0].strip()  

    
      

   
    bolsos_df2['Descripción'] = bolsos_df2['Descripción'].apply(quitar_despues_primer_punto)

    
    print(bolsos_df2['Descripción'])

    
    bolsos_df2.to_csv('ruta_a_tu_nuevo_archivo.csv', index=False)
# Out:
# 0                                    Bolso formato mini saca en efecto terciopelo
# 1                                    Bolso formato maxi saca en efecto terciopelo
# 2                                      Bolso formato de hombro con forma alargada
# 3                                              Bolso formato bandolera en serraje
# 4     Bolso de hombro de formato ovalado con efecto engomado en la parte inferior
# 5                      Bolso de hombro de formato rectangular con efecto engomado
# 6                                               Bolso bandolera en material suave
# 7                                           Clutch en efecto piel con asa de mano
# 8                      Mallet de efecto brillo con detalle de cadena en el cierre
# 9                                         Bolso de saca pequeña con asa ajustable
# 10                          Bolso efecto cocodrilo con cierre mediante cremallera
# ...

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción     Precio  Color  \
# 0       Bolso formato mini saca en efecto terciopelo  39,95 EUR   Ocre
# 1       Bolso formato maxi saca en efecto terciopelo  49,95 EUR  Negro
# 2         Bolso formato de hombro con forma alargada  35,95 EUR  Negro
# 3                 Bolso formato bandolera en serraje  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#   Categoría  categoría
# 0    Bolsos  accesorio
# 1    Bolsos  accesorio
# 2    Bolsos  accesorio
# 3    Bolsos  accesorio
# 4    Bolsos  accesorio

# %%
bolsos_df2 = bolsos_df2.drop('Categoría', axis=1)

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción     Precio  Color  \
# 0       Bolso formato mini saca en efecto terciopelo  39,95 EUR   Ocre
# 1       Bolso formato maxi saca en efecto terciopelo  49,95 EUR  Negro
# 2         Bolso formato de hombro con forma alargada  35,95 EUR  Negro
# 3                 Bolso formato bandolera en serraje  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#    categoría
# 0  accesorio
# 1  accesorio
# 2  accesorio
# 3  accesorio
# 4  accesorio

# %%
bolsos_df2['categoría'] = bolsos_df2['categoría'].str.title()

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción     Precio  Color  \
# 0       Bolso formato mini saca en efecto terciopelo  39,95 EUR   Ocre
# 1       Bolso formato maxi saca en efecto terciopelo  49,95 EUR  Negro
# 2         Bolso formato de hombro con forma alargada  35,95 EUR  Negro
# 3                 Bolso formato bandolera en serraje  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#    categoría
# 0  Accesorio
# 1  Accesorio
# 2  Accesorio
# 3  Accesorio
# 4  Accesorio

# %%
bolsos_df2.columns = [col.capitalize() for col in bolsos_df2.columns]

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción     Precio  Color  \
# 0       Bolso formato mini saca en efecto terciopelo  39,95 EUR   Ocre
# 1       Bolso formato maxi saca en efecto terciopelo  49,95 EUR  Negro
# 2         Bolso formato de hombro con forma alargada  35,95 EUR  Negro
# 3                 Bolso formato bandolera en serraje  55,95 EUR  1-155
# 4  Bolso de hombro de formato ovalado con efecto ...  35,95 EUR  Negro
#
#    Categoría
# 0  Accesorio
# 1  Accesorio
# 2  Accesorio
# 3  Accesorio
# 4  Accesorio

# %%
bolsos_df2['Color'].unique()
# Out:
# array(['Ocre', 'Negro', '1-155', 'Verde', 'Azul', 'Rosa'], dtype=object)

# %%
bolsos_df2['Color'].nunique()
# Out:
# 6

# %%
bolsos_df2['Color'] = bolsos_df2['Color'].str.replace(r'.*1-155.*', 'Marron', regex=True)

# %% [markdown]
# ### Limpieza Abrigos

# %%
abrigos_df = pd.read_csv("abrigos.csv")

# %%
abrigos_df.head()
# Out:
#                                     Nombre  \
# 0    ABRIGO LARGO CON LANA - Negro de Zara
# 1  ABRIGO CRUZADO CON LANA - Negro de Zara
# 2      ABRIGO OVERSIZE SOFT - Gris de Zara
# 3     ABRIGO OVERSIZE SOFT - Beige de Zara
# 4     ABRIGO OVERSIZE SOFT - Negro de Zara
#
#                                          Descripción        Color     Precio  \
# 0  Abrigo de cuello solapa y manga larga. Bolsill...        Crudo  89,95 EUR
# 1  Abrigo de cuello solapa y manga larga. Bolsill...         Rojo  49,95 EUR
# 2  Abrigo de cuello solapa y manga larga. Bolsill...      Tostado  39,95 EUR
# 3  Abrigo con capucha y manga larga. Bolsillos la...  Camel claro  49,95 EUR
# 4  Anorak acolchado resistente al agua y al vient...        Negro  69,95 EUR
#
#   categoría
# 0    prenda
# 1    prenda
# 2    prenda
# 3    prenda
# 4    prenda

# %%
abrigos_df.tail()
# Out:
#                                                Nombre Descripción       Color  \
# 27  ABRIGO EFECTO PELO ESTAMPADO ANIMAL - Leopardo...         NaN     Tostado
# 28           ABRIGO LARGO BORREGUILLO - Negro de Zara         NaN  Gris claro
# 29      ABRIGO CORTO EFECTO PELO - Gris perla de Zara         NaN       Negro
# 30                                                NaN         NaN       Crudo
# 31                                                NaN         NaN       Crudo
#
#        Precio categoría
# 27  59,95 EUR    prenda
# 28  59,95 EUR    prenda
# 29  59,95 EUR    prenda
# 30        NaN    prenda
# 31        NaN    prenda

# %%
abrigos_df.shape
# Out:
# (32, 5)

# %%
abrigos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       30 non-null     object
#  1   Descripción  22 non-null     object
#  2   Color        32 non-null     object
#  3   Precio       30 non-null     object
#  4   categoría    32 non-null     object
# dtypes: object(5)
# memory usage: 1.4+ KB

# %%
print(abrigos_df.isnull().sum())
# Out:
# Nombre          2
# Descripción    10
# Color           0
# Precio          2
# categoría       0
# dtype: int64

# %%
abrigos_df = abrigos_df.dropna()

# %%
abrigos_df.isnull().sum()
# Out:
# Nombre         0
# Descripción    0
# Color          0
# Precio         0
# categoría      0
# dtype: int64

# %%
abrigos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       22 non-null     object
#  1   Descripción  22 non-null     object
#  2   Color        22 non-null     object
#  3   Precio       22 non-null     object
#  4   categoría    22 non-null     object
# dtypes: object(5)
# memory usage: 1.0+ KB

# %%
abrigos_df.dtypes
# Out:
# Nombre         object
# Descripción    object
# Color          object
# Precio         object
# categoría      object
# dtype: object

# %%
abrigos_df2 = abrigos_df.copy()

# %%
abrigos_df2['Nombre'] = abrigos_df2['Nombre'].str.title()

# %%
abrigos_df2['Nombre'] = abrigos_df2['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
abrigos_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       22 non-null     object
#  1   Descripción  22 non-null     object
#  2   Color        22 non-null     object
#  3   Precio       22 non-null     object
#  4   categoría    22 non-null     object
# dtypes: object(5)
# memory usage: 1.0+ KB

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.')  
        return partes[0].strip()  

    
      

    
    abrigos_df2['Descripción'] = abrigos_df2['Descripción'].apply(quitar_despues_primer_punto)

    
    print(abrigos_df2['Descripción'])

    
    abrigos_df2.to_csv('ruta_a_tu_nuevo_archivo.csv', index=False)
# Out:
# 0                                                         Abrigo de cuello solapa y manga larga
# 1                                                         Abrigo de cuello solapa y manga larga
# 2                                                         Abrigo de cuello solapa y manga larga
# 3                                                              Abrigo con capucha y manga larga
# 4     Anorak acolchado resistente al agua y al viento con aislamiento térmico para climas fríos
# 5     Anorak acolchado resistente al agua y al viento con aislamiento térmico para climas fríos
# 6                                                                 Abrigo confeccionado con lana
# 7                                                                 Abrigo confeccionado con lana
# 8                                                                 Abrigo confeccionado con lana
# 9                                                                 Abrigo confeccionado con lana
# ...

# %%
abrigos_df2.head()
# Out:
#                     Nombre                                        Descripción  \
# 0    Abrigo Largo Con Lana              Abrigo de cuello solapa y manga larga
# 1  Abrigo Cruzado Con Lana              Abrigo de cuello solapa y manga larga
# 2     Abrigo Oversize Soft              Abrigo de cuello solapa y manga larga
# 3     Abrigo Oversize Soft                   Abrigo con capucha y manga larga
# 4     Abrigo Oversize Soft  Anorak acolchado resistente al agua y al vient...
#
#          Color     Precio categoría
# 0        Crudo  89,95 EUR    prenda
# 1         Rojo  49,95 EUR    prenda
# 2      Tostado  39,95 EUR    prenda
# 3  Camel claro  49,95 EUR    prenda
# 4        Negro  69,95 EUR    prenda

# %%
abrigos_df2['categoría'] = abrigos_df2['categoría'].str.title()

# %%
abrigos_df2.columns = [col.capitalize() for col in abrigos_df2.columns]

# %%
abrigos_df2.sample(22)
# Out:
#                                               Nombre  \
# 14                  Chaqueta Acolchada Zw Collection
# 5                 Abrigo Solapa Efecto Pelo Con Lana
# 18       Plumífero Capucha Water And Wind Protection
# 21                          Abrigo Largo Punto Ochos
# 11                      Abrigo Soft Cinturón Capucha
# 3                               Abrigo Oversize Soft
# 13                      Abrigo Soft Cinturón Capucha
# 4                               Abrigo Oversize Soft
# 2                               Abrigo Oversize Soft
# 8   Anorak Acolchado Corto Water And Wind Protection
# 0                              Abrigo Largo Con Lana
# 15                          Abrigo Largo Efecto Pelo
# 19                          Abrigo Largo Borreguillo
# 10                  Anorak Water And Wind Protection
# 1                            Abrigo Cruzado Con Lana
# 7   Anorak Acolchado Corto Water And Wind Protection
# 16       Plumífero Capucha Water And Wind Protection
# ...

# %%
abrigos_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       22 non-null     object
#  1   Descripción  22 non-null     object
#  2   Color        22 non-null     object
#  3   Precio       22 non-null     object
#  4   Categoría    22 non-null     object
# dtypes: object(5)
# memory usage: 1.0+ KB

# %%
abrigos_df2['Descripción'] = abrigos_df2['Descripción'].str.replace(r'.*ZARA WOMAN COLLECTION*', 'Zara Woman Collection', regex=True)

# %%
camisas_df = pd.read_csv("camisas.csv")

# %% [markdown]
# ### Limpieza Camisas

# %%
camisas_df.head()
# Out:
#                                               Nombre  \
# 0  CAMISA DENIM PESPUNTES ZW COLLECTION - Azul de...
# 1  BLUSA ROMÁNTICA VOLANTES ZW COLLECTION - Negro...
# 2       BLUSA VOLANTES ZW COLLECTION - Negro de Zara
# 3                 BLUSA TUL ESTAMPADO - Azul de Zara
# 4        BLUSA TUL ESTAMPADO - Negro / Arena de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/camisa-denim-pespun...
# 1  https://www.zara.com/es/es/blusa-romantica-vol...
# 2  https://www.zara.com/es/es/blusa-volantes-zw-c...
# 3  https://www.zara.com/es/es/blusa-tul-estampado...
# 4  https://www.zara.com/es/es/blusa-tul-estampado...
#
#                                          Descripción  Precio categoría
# 0  ZARA WOMAN COLLECTIONCamisa confeccionada en h...   29.99    prenda
# 1  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   35.99    prenda
# 2  ZARA WOMAN COLLECTIONBlusa confeccionada en hi...   39.99    prenda
# ...

# %%
camisas_df = camisas_df.drop('Enlace', axis=1)

# %%
camisas_df.shape
# Out:
# (24, 4)

# %%
camisas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       24 non-null     object
#  1   Descripción  24 non-null     object
#  2   Precio       24 non-null     float64
#  3   categoría    24 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 900.0+ bytes

# %%
print(bolsos_df.isnull().sum())
# Out:
# Nombre         0
# Descripción    0
# Precio         0
# Color          0
# Categoría      0
# categoría      0
# dtype: int64

# %%
camisas_df = camisas_df.apply(lambda col: col.str.capitalize() if col.dtype == "object" else col)

# %%
camisas_df.head()
# Out:
#                                               Nombre  \
# 0  Camisa denim pespuntes zw collection - azul de...
# 1  Blusa romántica volantes zw collection - negro...
# 2       Blusa volantes zw collection - negro de zara
# 3                 Blusa tul estampado - azul de zara
# 4        Blusa tul estampado - negro / arena de zara
#
#                                          Descripción  Precio categoría
# 0  Zara woman collectioncamisa confeccionada en h...   29.99    Prenda
# 1  Zara woman collectionblusa confeccionada en hi...   35.99    Prenda
# 2  Zara woman collectionblusa confeccionada en hi...   39.99    Prenda
# 3  Blusa de cuello solapa y escote pico cruzado. ...   19.99    Prenda
# 4  Blusa semitransparente de cuello subido. manga...   22.99    Prenda

# %%
with pd.option_context('display.max_colwidth', None):
   
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.')  
        return partes[0].strip()  

   

    
    camisas_df['Descripción'] = camisas_df['Descripción'].apply(quitar_despues_primer_punto)

    
    print(camisas_df['Descripción'])

    
    camisas_df.to_csv('ruta_a_tu_nuevo_archivo.csv', index=False)
# Out:
# 0       Zara woman collectioncamisa confeccionada en hilatura con mezcla de algodón
# 1                   Zara woman collectionblusa confeccionada en hilatura de viscosa
# 2        Zara woman collectionblusa confeccionada en hilatura con viscosa y algodón
# 3                                      Blusa de cuello solapa y escote pico cruzado
# 4                                           Blusa semitransparente de cuello subido
# 5                                             Camisa de cuello solapa y manga larga
# 6                                             Camisa de cuello solapa y manga larga
# 7        Zara woman collectioncamisa de cuello solapa y manga larga acabada en puño
# 8        Zara woman collectioncamisa de cuello solapa y manga larga acabada en puño
# 9              Zara woman collectionblusa confeccionada en hilatura de viscosa 100%
# 10                  Camisa semitransparente de escote pico y lazada en mismo tejido
# ...

# %%
camisas_df.head()
# Out:
#                                               Nombre  \
# 0  Camisa denim pespuntes zw collection - azul de...
# 1  Blusa romántica volantes zw collection - negro...
# 2       Blusa volantes zw collection - negro de zara
# 3                 Blusa tul estampado - azul de zara
# 4        Blusa tul estampado - negro / arena de zara
#
#                                          Descripción  Precio categoría
# 0  Zara woman collectioncamisa confeccionada en h...   29.99    Prenda
# 1  Zara woman collectionblusa confeccionada en hi...   35.99    Prenda
# 2  Zara woman collectionblusa confeccionada en hi...   39.99    Prenda
# 3       Blusa de cuello solapa y escote pico cruzado   19.99    Prenda
# 4            Blusa semitransparente de cuello subido   22.99    Prenda

# %%
camisas_df['Nombre']
# Out:
# 0     Camisa denim pespuntes zw collection - azul de...
# 1     Blusa romántica volantes zw collection - negro...
# 2          Blusa volantes zw collection - negro de zara
# 3                    Blusa tul estampado - azul de zara
# 4           Blusa tul estampado - negro / arena de zara
# 5     Camisa popelín botones dorados - azul claro de...
# 6               Camisa crepe entredoses - negro de zara
# 7     Camisa maxi flecos zw collection - marrón de zara
# 8           Camisa flecos zw collection - negro de zara
# 9     Blusa bordada frunces zw collection - marrón c...
# 10        Camisa lazadas volantes - blanco roto de zara
# 11                     Camisa volantes - marrón de zara
# 12    Blusa multiposición zw collection - negro de zara
# 13    Blusa hilo metalizado zw collection - negro de...
# 14                   Polo liso lana 100% - gris de zara
# 15                  Polo liso lana 100% - toffe de zara
# 16    Camisa satinada bolsillos zw collection - burg...
# ...

# %%
camisas_df['Color'] = camisas_df['Nombre'].str.split(" - ").str[-1].str.extract(r'(\b\w+\b(?: / \b\w+\b)?)')


print(camisas_df[['Nombre', 'Color']].head())
# Out:
#                                               Nombre          Color
# 0  Camisa denim pespuntes zw collection - azul de...           azul
# 1  Blusa romántica volantes zw collection - negro...          negro
# 2       Blusa volantes zw collection - negro de zara          negro
# 3                 Blusa tul estampado - azul de zara           azul
# 4        Blusa tul estampado - negro / arena de zara  negro / arena

# %%
camisas_df.sample(20)
# Out:
#                                                Nombre  \
# 16  Camisa satinada bolsillos zw collection - burg...
# 2        Blusa volantes zw collection - negro de zara
# 10      Camisa lazadas volantes - blanco roto de zara
# 17  Camisa bordados cuadro vichy - crudo / negro d...
# 19           Camisa z1975 básica denim - azul de zara
# 8         Camisa flecos zw collection - negro de zara
# 1   Blusa romántica volantes zw collection - negro...
# 5   Camisa popelín botones dorados - azul claro de...
# 23       Blusa volantes zw collection - crudo de zara
# 15                Polo liso lana 100% - toffe de zara
# 13  Blusa hilo metalizado zw collection - negro de...
# 3                  Blusa tul estampado - azul de zara
# 0   Camisa denim pespuntes zw collection - azul de...
# 20     Camisa z1975 básica denim - azul medio de zara
# 4         Blusa tul estampado - negro / arena de zara
# 7   Camisa maxi flecos zw collection - marrón de zara
# ...

# %%
camisas_df['Nombre'] = camisas_df['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
camisas_df['Precio']
# Out:
# 0     29.99
# 1     35.99
# 2     39.99
# 3     19.99
# 4     22.99
# 5     29.99
# 6     32.99
# 7     45.99
# 8     39.99
# 9     24.99
# 10    27.99
# 11    33.99
# 12    19.99
# 13    22.99
# 14    27.99
# 15    34.99
# 16    38.99
# 17    40.99
# 18    29.99
# 19    35.99
# 20    39.99
# 21    45.99
# 22    29.99
# 23    35.99
# Name: Precio, dtype: float64

# %%
camisas_df['Precio'] = camisas_df['Precio'].astype(str) + " EUR"

# %%
camisas_df['Color'] = camisas_df['Color'].str.title()

# %%
camisas_df.sample(22)
# Out:
#                                      Nombre  \
# 11                          Camisa volantes
# 16  Camisa satinada bolsillos zw collection
# 17             Camisa bordados cuadro vichy
# 2              Blusa volantes zw collection
# 13      Blusa hilo metalizado zw collection
# 9       Blusa bordada frunces zw collection
# 15                      Polo liso lana 100%
# 22              Blusa pañuelo zw collection
# 19                Camisa z1975 básica denim
# 21                        Blusa fluida lazo
# 5            Camisa popelín botones dorados
# 23             Blusa volantes zw collection
# 14                      Polo liso lana 100%
# 20                Camisa z1975 básica denim
# 3                       Blusa tul estampado
# 18             Blusa volantes zw collection
# 8               Camisa flecos zw collection
# 4                       Blusa tul estampado
# 1    Blusa romántica volantes zw collection
# 6                   Camisa crepe entredoses
# ...

# %%
camisas_df['Descripción'] = camisas_df['Descripción'].str.replace(r'^Zara Woman\s*', '', case=False, regex=True)

# %%
camisas_df.columns = camisas_df.columns.str.capitalize()

# %%
camisas_df.head()
# Out:
#                                    Nombre  \
# 0    Camisa denim pespuntes zw collection
# 1  Blusa romántica volantes zw collection
# 2            Blusa volantes zw collection
# 3                     Blusa tul estampado
# 4                     Blusa tul estampado
#
#                                          Descripción     Precio Categoría  \
# 0  collectioncamisa confeccionada en hilatura con...  29.99 EUR    Prenda
# 1  collectionblusa confeccionada en hilatura de v...  35.99 EUR    Prenda
# 2  collectionblusa confeccionada en hilatura con ...  39.99 EUR    Prenda
# 3       Blusa de cuello solapa y escote pico cruzado  19.99 EUR    Prenda
# 4            Blusa semitransparente de cuello subido  22.99 EUR    Prenda
#
#            Color
# 0           Azul
# 1          Negro
# 2          Negro
# 3           Azul
# 4  Negro / Arena

# %%
zapatos_df = pd.read_csv("zapatos.csv")

# %% [markdown]
# ### Limpieza Zapatos

# %%
zapatos_df.head()
# Out:
#                                        Nombre  \
# 0        BOTÍN PLANO PICADOS - Marrón de Zara
# 1        BOTÍN PLANO PICADOS - Marrón de Zara
# 2  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 3  BOTÍN PLANO PIEL CON PELO - Marrón de Zara
# 4           BOTÍN COWBOY PIEL - Negro de Zara
#
#                                               Enlace  \
# 0  https://www.zara.com/es/es/botin-plano-picados...
# 1  https://www.zara.com/es/es/botin-plano-picados...
# 2  https://www.zara.com/es/es/botin-plano-piel-co...
# 3  https://www.zara.com/es/es/botin-plano-piel-co...
# 4  https://www.zara.com/es/es/botin-cowboy-piel-p...
#
#                                          Descripción     Precio categoría
# 0  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR   calzado
# 1  Zapato tipo botín plano. Detalles en picado. T...  39,95 EUR   calzado
# 2  Zapato tipo botín en piel con pelo. Caña ancha...  99,95 EUR   calzado
# ...

# %%
zapatos_df.tail()
# Out:
#                                                Nombre  \
# 25   BAILARINA TEJIDO DETALLE BRILLOS - Negro de Zara
# 26   BAILARINA TEJIDO DETALLE BRILLOS - Negro de Zara
# 27  DESTALONADO LAZO EFECTO TERCIOPELO - Negro de ...
# 28  DESTALONADO LAZO EFECTO TERCIOPELO - Negro de ...
# 29     ZAPATO TACÓN EFECTO ACHAROLADO - Negro de Zara
#
#                                                Enlace  \
# 25  https://www.zara.com/es/es/bailarina-tejido-de...
# 26  https://www.zara.com/es/es/bailarina-tejido-de...
# 27  https://www.zara.com/es/es/destalonado-lazo-ef...
# 28  https://www.zara.com/es/es/destalonado-lazo-ef...
# 29  https://www.zara.com/es/es/zapato-tacon-efecto...
#
#                                           Descripción     Precio categoría
# 25  Zapato plano tipo bailarina en tejido. Detalle...  29,95 EUR   calzado
# 26  Zapato plano tipo bailarina en tejido. Detalle...  29,95 EUR   calzado
# 27  Zapato tipo destalonado con lazo decorativo en...  49,95 EUR   calzado
# ...

# %%
zapatos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       30 non-null     object
#  1   Enlace       30 non-null     object
#  2   Descripción  30 non-null     object
#  3   Precio       30 non-null     object
#  4   categoría    30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
zapatos_df.columns = zapatos_df.columns.str.capitalize()

# %%
zapatos_df.drop(columns=['Enlace'], inplace=True)

# %%
zapatos_df['Categoría'] = zapatos_df['Categoría'].str.capitalize()

# %%
zapatos_df['Nombre'] = zapatos_df['Nombre'].str.title()

# %%
zapatos_df['Nombre']
# Out:
# 0                  Botín Plano Picados - Marrón De Zara
# 1                  Botín Plano Picados - Marrón De Zara
# 2            Botín Plano Piel Con Pelo - Marrón De Zara
# 3            Botín Plano Piel Con Pelo - Marrón De Zara
# 4                     Botín Cowboy Piel - Negro De Zara
# 5                     Botín Cowboy Piel - Negro De Zara
# 6                      Botín Tacón Piel - Negro De Zara
# 7                      Botín Tacón Piel - Negro De Zara
# 8               Bota Hípica Efecto Coco - Negro De Zara
# 9               Bota Hípica Efecto Coco - Negro De Zara
# 10                  Botín Plano Hebilla - Negro De Zara
# 11                  Botín Plano Hebilla - Negro De Zara
# 12               Bota Tacón Alto - Rojo Burdeos De Zara
# 13               Bota Tacón Alto - Rojo Burdeos De Zara
# 14               Botín Tacón Ancho Piel - Negro De Zara
# 15               Botín Tacón Ancho Piel - Negro De Zara
# 16      Zapatillas Deportivas Serraje - Tostado De Zara
# ...

# %%
zapatos_df['Colores'] = zapatos_df['Nombre'].str.extract(r' - (.+) De Zara')

# %%
zapatos_df['Nombre'] = zapatos_df['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
zapatos_df.sample(20)
# Out:
#                                 Nombre  \
# 18          Zueco Detalle Pelo Serraje
# 13                     Bota Tacón Alto
# 22                       Botín Serraje
# 25    Bailarina Tejido Detalle Brillos
# 3            Botín Plano Piel Con Pelo
# 6                     Botín Tacón Piel
# 9              Bota Hípica Efecto Coco
# 1                  Botín Plano Picados
# 7                     Botín Tacón Piel
# 14              Botín Tacón Ancho Piel
# 20          Bailarina Estampado Animal
# 0                  Botín Plano Picados
# 24              Botín Detalle Fruncido
# 17          Zueco Detalle Pelo Serraje
# 16       Zapatillas Deportivas Serraje
# 27  Destalonado Lazo Efecto Terciopelo
# 2            Botín Plano Piel Con Pelo
# 11                 Botín Plano Hebilla
# 8              Bota Hípica Efecto Coco
# 4                    Botín Cowboy Piel
#
#                                           Descripción      Precio Categoría  \
# ...

# %% [markdown]
# ### Limpieza Jerseys

# %%
jerseys_df = pd.read_csv("jerseys.csv")

# %%
jerseys_df.head()
# Out:
#                                             Nombre     Color  \
# 0  JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara  Leopardo
# 1    JERSEY PUNTO BOTONES LATERALES - Gris de Zara      Gris
# 2   JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara     Crudo
# 3     CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara      Gris
# 4             JERSEY PUNTO ABIERTO - Negro de Zara     Negro
#
#                                          Descripción     Precio categoría
# 0                                   Acabados en rib.  29,95 EUR    prenda
# 1                Bajo acabado con botones laterales.  27,95 EUR    prenda
# 2  Acabados con volantes y bajo con cordón delant...  49,95 EUR    prenda
# 3  Escote pico y manga larga. Cierre frontal con ...  29,95 EUR    prenda
# 4                        Detalle de tiras laterales.  39,95 EUR    prenda

# %%
jerseys_df.tail()
# Out:
#                                                Nombre           Color  \
# 25  JERSEY PUNTO EFECTO PELO BROCHES - Marrón de Zara          Marrón
# 26  JERSEY PUNTO JACQUARD CUADROS - Negro / Marrón...  Negro / Marrón
# 27             JERSEY SOFT PUNTO - Gris claro de Zara      Gris claro
# 28  JERSEY OVERSIZE PUNTO JACQUARD - Multicolor de...      Multicolor
# 29        JERSEY PONCHO PUNTO CALADOS - Crudo de Zara           Crudo
#
#                                           Descripción     Precio categoría
# 25  Detalle de tejido efecto pelo y broches delant...  35,95 EUR    prenda
# 26     Detalle de jacquard y tejido efecto cepillado.  29,95 EUR    prenda
# 27                                   Acabados en rib.  27,95 EUR    prenda
# 28     Detalle de jacquard y tejido efecto cepillado.  35,95 EUR    prenda
# 29  Jersey estilo poncho de cuello subido y manga ...  59,95 EUR    prenda

# %%
jerseys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       30 non-null     object
#  1   Color        30 non-null     object
#  2   Descripción  30 non-null     object
#  3   Precio       30 non-null     object
#  4   categoría    30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
jerseys_df.shape
# Out:
# (30, 5)

# %%
print(jerseys_df.isnull().sum())
# Out:
# Nombre         0
# Color          0
# Descripción    0
# Precio         0
# categoría      0
# dtype: int64

# %%
jerseys_df.dtypes
# Out:
# Nombre         object
# Color          object
# Descripción    object
# Precio         object
# categoría      object
# dtype: object

# %%
jerseys_df['Nombre']
# Out:
# 0       JERSEY PUNTO JACQUARD ANIMAL - Leopardo de Zara
# 1         JERSEY PUNTO BOTONES LATERALES - Gris de Zara
# 2        JERSEY ROMÁNTICO PUNTO CALADOS - Crudo de Zara
# 3          CHAQUETA PUNTO CUELLO BUFANDA - Gris de Zara
# 4                  JERSEY PUNTO ABIERTO - Negro de Zara
# 5            JERSEY PUNTO CALADOS - Mantequilla de Zara
# 6          JERSEY PUNTO CUELLO VOLANTES - Crudo de Zara
# 7        CHAQUETA PUNTO JACQUARD ANIMAL - Tigre de Zara
# 8     JERSEY PUNTO JACQUARD ANIMAL - Crudo/Kaki de Zara
# 9     TOP MANGA CORTA CON ALPACA Y LANA - Mostaza de...
# 10        JERSEY PUNTO CUELLO ASIMÉTRICO - Lila de Zara
# 11    SUDADERA PUNTO JACQUARD ANIMAL - Leopardo de Zara
# 12            JERSEY EFECTO PELO FLORES - Crudo de Zara
# 13               TOP PUNTO LAZO ORGANZA - Crudo de Zara
# 14               TOP PUNTO LAZO ORGANZA - Negro de Zara
# 15                   JERSEY PUNTO LISO - Marino de Zara
# 16             ABRIGO LARGO PUNTO OCHOS - Crudo de Zara
# ...

# %%
jerseys_df['Colores'] = jerseys_df['Nombre'].str.extract(r' - (.+) de Zara')

# %%
jerseys_df['Nombre'] = jerseys_df['Nombre'].str.title()

# %%
jerseys_df.sample(10)
# Out:
#                                                Nombre           Color  \
# 11  Sudadera Punto Jacquard Animal - Leopardo De Zara        Leopardo
# 7      Chaqueta Punto Jacquard Animal - Tigre De Zara           Tigre
# 19  Jersey Punto Jacquard Cuadros - Negro / Marrón...  Negro / Marrón
# 23  Jersey Punto Pedrería Con Alpaca - Verde Agua ...      Verde agua
# 27             Jersey Soft Punto - Gris Claro De Zara      Gris claro
# 24  Chaqueta Punto Aplique Dorado - Gris Oscuro De...     Gris oscuro
# 16           Abrigo Largo Punto Ochos - Crudo De Zara           Crudo
# 12          Jersey Efecto Pelo Flores - Crudo De Zara           Crudo
# 10      Jersey Punto Cuello Asimétrico - Lila De Zara            Lila
# 8   Jersey Punto Jacquard Animal - Crudo/Kaki De Zara      Crudo/Kaki
#
#                                           Descripción     Precio categoría  \
# 11               Bolsillo delantero. Acabados en rib.  49,95 EUR    prenda
# ...

# %%
jerseys_df['Nombre'] = jerseys_df['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
jerseys_df['Categoría'] = jerseys_df['categoría'].str.capitalize()

# %%
jerseys_df.drop(columns=['categoría'], inplace=True)

# %%
jerseys_df.head()
# Out:
#                            Nombre     Color  \
# 0    Jersey Punto Jacquard Animal  Leopardo
# 1  Jersey Punto Botones Laterales      Gris
# 2  Jersey Romántico Punto Calados     Crudo
# 3   Chaqueta Punto Cuello Bufanda      Gris
# 4            Jersey Punto Abierto     Negro
#
#                                          Descripción     Precio   Colores  \
# 0                                   Acabados en rib.  29,95 EUR  Leopardo
# 1                Bajo acabado con botones laterales.  27,95 EUR      Gris
# 2  Acabados con volantes y bajo con cordón delant...  49,95 EUR     Crudo
# 3  Escote pico y manga larga. Cierre frontal con ...  29,95 EUR      Gris
# 4                        Detalle de tiras laterales.  39,95 EUR     Negro
#
#   Categoría
# 0    Prenda
# 1    Prenda
# 2    Prenda
# 3    Prenda
# 4    Prenda

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.') 
        return partes[0].strip()  

   

    jerseys_df['Descripción'] = jerseys_df['Descripción'].apply(quitar_despues_primer_punto)

    
    print(jerseys_df['Descripción'])

    
    jerseys_df.to_csv('ruta_a_tu_nuevo_archivo.csv', index=False)
# Out:
# 0                                              Acabados en rib
# 1                           Bajo acabado con botones laterales
# 2            Acabados con volantes y bajo con cordón delantero
# 3                                    Escote pico y manga larga
# 4                                   Detalle de tiras laterales
# 5     Jersey de punto abierto con cuello redondo y manga larga
# 6                                             Acabados en puño
# 7                                         Bolsillos delanteros
# 8                        Jersey de cuello subido y manga larga
# 9                                 Cuello redondo y manga corta
# 10                                           Botones en hombro
# 11                                          Bolsillo delantero
# 12                                          Tejido tacto suave
# 13                        Detalle de lazo combinado en organza
# 14                        Detalle de lazo combinado en organza
# ...

# %%
jerseys_df['Descripción']
# Out:
# 0                                       Acabados en rib
# 1                    Bajo acabado con botones laterales
# 2     Acabados con volantes y bajo con cordón delantero
# 3                             Escote pico y manga larga
# 4                            Detalle de tiras laterales
# 5     Jersey de punto abierto con cuello redondo y m...
# 6                                      Acabados en puño
# 7                                  Bolsillos delanteros
# 8                 Jersey de cuello subido y manga larga
# 9                          Cuello redondo y manga corta
# 10                                    Botones en hombro
# 11                                   Bolsillo delantero
# 12                                   Tejido tacto suave
# 13                 Detalle de lazo combinado en organza
# 14                 Detalle de lazo combinado en organza
# 15                                      Acabados en rib
# 16                     Bolsillos delanteros de plastrón
# ...

# %%
jerseys_df.head()
# Out:
#                            Nombre     Color  \
# 0    Jersey Punto Jacquard Animal  Leopardo
# 1  Jersey Punto Botones Laterales      Gris
# 2  Jersey Romántico Punto Calados     Crudo
# 3   Chaqueta Punto Cuello Bufanda      Gris
# 4            Jersey Punto Abierto     Negro
#
#                                          Descripción     Precio   Colores  \
# 0                                    Acabados en rib  29,95 EUR  Leopardo
# 1                 Bajo acabado con botones laterales  27,95 EUR      Gris
# 2  Acabados con volantes y bajo con cordón delantero  49,95 EUR     Crudo
# 3                          Escote pico y manga larga  29,95 EUR      Gris
# 4                         Detalle de tiras laterales  39,95 EUR     Negro
#
#   Categoría
# 0    Prenda
# 1    Prenda
# 2    Prenda
# 3    Prenda
# 4    Prenda

# %% [markdown]
# ### Limpieza Vestidos

# %%
vestidos_df = pd.read_csv("vestidos.csv")

# %%
vestidos_df.head()
# Out:
#                                 Nombre           Color     Precio  \
# 0          Vestido Mini Punto Cinturón  Negro / Marrón  35,95 EUR
# 1          Vestido Mini Punto Cinturón  Negro / Marrón  35,95 EUR
# 2              Vestido Midi Punto Liso       Azul pato  39,95 EUR
# 3              Vestido Midi Terciopelo     Rojo oscuro  29,95 EUR
# 4  Vestido Mini Lentejuelas Asimétrico            Rojo  39,95 EUR
#
#                                          Descripción Categoría
# 0             Vestido de cuello redondo y manga sisa    Prenda
# 1  Vestido de cuello barco y manga larga con apli...    Prenda
# 2  Vestido de cuello halter con escote pico fluid...    Prenda
# 3  Vestido de cuello subido y manga larga asimétrica    Prenda
# 4           Vestido de escote pico y tirantes anchos    Prenda

# %%
vestidos_df.shape
# Out:
# (29, 5)

# %%
vestidos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       29 non-null     object
#  1   Color        29 non-null     object
#  2   Precio       29 non-null     object
#  3   Descripción  29 non-null     object
#  4   Categoría    29 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
vestidos_df.dropna(inplace=True)

# %%
vestidos_df.shape
# Out:
# (29, 5)

# %%
vestidos_df.columns = vestidos_df.columns.str.capitalize()

# %%
vestidos_df['Nombre'] = vestidos_df['Nombre'].str.title()

# %%
vestidos_df.columns = vestidos_df.columns.str.capitalize()

# %%
vestidos_df.head()
# Out:
#                                 Nombre           Color     Precio  \
# 0          Vestido Mini Punto Cinturón  Negro / Marrón  35,95 EUR
# 1          Vestido Mini Punto Cinturón  Negro / Marrón  35,95 EUR
# 2              Vestido Midi Punto Liso       Azul pato  39,95 EUR
# 3              Vestido Midi Terciopelo     Rojo oscuro  29,95 EUR
# 4  Vestido Mini Lentejuelas Asimétrico            Rojo  39,95 EUR
#
#                                          Descripción Categoría
# 0             Vestido de cuello redondo y manga sisa    Prenda
# 1  Vestido de cuello barco y manga larga con apli...    Prenda
# 2  Vestido de cuello halter con escote pico fluid...    Prenda
# 3  Vestido de cuello subido y manga larga asimétrica    Prenda
# 4           Vestido de escote pico y tirantes anchos    Prenda

# %%
vestidos_df['Categoría'] = vestidos_df['Categoría'].str.title()

# %%
vestidos_df['Descripción']
# Out:
# 0                Vestido de cuello redondo y manga sisa
# 1     Vestido de cuello barco y manga larga con apli...
# 2     Vestido de cuello halter con escote pico fluid...
# 3     Vestido de cuello subido y manga larga asimétrica
# 4              Vestido de escote pico y tirantes anchos
# 5           Vestido de escote redondo y tirantes anchos
# 6      Vestido de cuello redondo y manga sisa enroscada
# 7          Vestido corto de cuello redondo y manga sisa
# 8            Vestido corto de cuello barco y manga sisa
# 9       Vestido midi confeccionado en tejido tipo punto
# 10    Vestido confeccionado en tejido de punto elást...
# 11    Vestido confeccionado en tejido de punto elást...
# 12    Vestido confeccionado en tejido de punto elást...
# 13    Vestido largo con cuello redondo confeccionado...
# 14         Vestido corto de cuello redondo y manga sisa
# 15     Vestido corto confeccionado en tejido tipo punto
# 16              Vestido de cuello redondo y manga larga
# ...

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.')  
        return partes[0].strip()  

    

    
    vestidos_df['Descripción'] = vestidos_df['Descripción'].apply(quitar_despues_primer_punto)

    
    print(vestidos_df['Descripción'])

    
    vestidos_df.to_csv('vestidos.csv', index=False)
# Out:
# 0                                                               Vestido de cuello redondo y manga sisa
# 1                                   Vestido de cuello barco y manga larga con aplique dorado en hombro
# 2                                Vestido de cuello halter con escote pico fluido y espalda descubierta
# 3                                                    Vestido de cuello subido y manga larga asimétrica
# 4                                                             Vestido de escote pico y tirantes anchos
# 5                                                          Vestido de escote redondo y tirantes anchos
# 6                                                     Vestido de cuello redondo y manga sisa enroscada
# 7                                                         Vestido corto de cuello redondo y manga sisa
# 8                                                           Vestido corto de cuello barco y manga sisa
# ...

# %% [markdown]
# ### Limpieza Chalecos

# %%
chalecos_df = pd.read_csv("chalecos.csv")

# %%
chalecos_df.head()
# Out:
#                              Nombre  \
# 0     Blazer Sin Solapa Lentejuelas
# 1     Blazer Sin Solapa Lentejuelas
# 2               Blazer Corta Brillo
# 3  Blazer Oversize Raya Diplomática
# 4          Chaleco Raya Diplomática
#
#                                          Descripción     Precio  \
# 0      Blazer sin solapa con manga larga y hombreras  59,95 EUR
# 1  Blazer de cuello sin solapa y manga larga con ...  59,95 EUR
# 2              Blazer corta con tejido efecto brillo  49,95 EUR
# 3  Blazer oversize de cuello solapa y manga larga...  59,95 EUR
# 4                Chaleco de escote pico y manga sisa  25,95 EUR
#
#             Color Categoría
# 0   Negro / Plata    Prenda
# 1           Negro    Prenda
# 2   Negro / Plata    Prenda
# 3     Gris oscuro    Prenda
# 4  Gris antracita    Prenda

# %%
chalecos_df.tail()
# Out:
#                              Nombre  \
# 24  Blazer Maxi Botón Zw Collection
# 25  Blazer Espiga Combinada Capucha
# 26  Blazer Cruzada Cinturón Espalda
# 27          Blazer Cruzada Oversize
# 28            Blazer Escote Redondo
#
#                                           Descripción     Precio        Color  \
# 24                 Blazer de cuello solapa con muesca  79,95 EUR        Negro
# 25    Blazer de cuello con solapa y capucha combinada  49,95 EUR  Gris vigoré
# 26      Blazer de cuello solapa y escote pico cruzado  59,95 EUR       Morado
# 27  Blazer amplia de cuello solapa y manga larga c...  39,95 EUR        Negro
# 28  Blazer con escote redondo y manga larga con ho...  49,95 EUR        Negro
#
#    Categoría
# 24    Prenda
# 25    Prenda
# 26    Prenda
# 27    Prenda
# 28    Prenda

# %%
chalecos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       29 non-null     object
#  1   Descripción  29 non-null     object
#  2   Precio       29 non-null     object
#  3   Color        29 non-null     object
#  4   Categoría    29 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
chalecos_df.shape
# Out:
# (29, 5)

# %% [markdown]
# chalecos_df.drop(columns=['Categoría'], inplace=True)

# %% [markdown]
# chalecos_df['categoría'] = chalecos_df['categoría'].str.title()

# %%
chalecos_df.columns = chalecos_df.columns.str.capitalize()

# %%
chalecos_df['Nombre'] = chalecos_df['Nombre'].str.title()

# %%
chalecos_df['Nombre'] = chalecos_df['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.')  
        return partes[0].strip()  

    

   
    chalecos_df['Descripción'] = chalecos_df['Descripción'].apply(quitar_despues_primer_punto)

   
    print(chalecos_df['Descripción'])

    
    chalecos_df.to_csv('chalecos.csv', index=False)
# Out:
# 0                           Blazer sin solapa con manga larga y hombreras
# 1                 Blazer de cuello sin solapa y manga larga con hombreras
# 2                                   Blazer corta con tejido efecto brillo
# 3            Blazer oversize de cuello solapa y manga larga con hombreras
# 4                                     Chaleco de escote pico y manga sisa
# 5                    Blazer de cuellos solapa y manga larga con hombreras
# 6            Blazer oversize de cuello solapa y manga larga con hombreras
# 7                                     Chaleco de escote pico y manga sisa
# 8                       Chaleco top entallado de cuello pico y manga sisa
# 9     Blazer de cuello solapa con escote pico y manga larga con hombreras
# 10       Blazer de cuello con solapa satinada y manga larga con hombreras
# 11                                    Chaleco de escote pico y manga sisa
# 12                                          Blazer confeccionada con lana
# ...

# %%
chalecos_df.sample(10)
# Out:
#                               Nombre  \
# 12      Blazer Recta Espiga Con Lana
# 27           Blazer Cruzada Oversize
# 9      Blazer Entallada Botón Dorado
# 5   Blazer Raya Diplomática Cinturón
# 15        Blazer Corta Pata De Gallo
# 26   Blazer Cruzada Cinturón Espalda
# 14                  Blazer Entallada
# 2                Blazer Corta Brillo
# 1      Blazer Sin Solapa Lentejuelas
# 28             Blazer Escote Redondo
#
#                                           Descripción     Precio  \
# 12                      Blazer confeccionada con lana  49,95 EUR
# 27  Blazer amplia de cuello solapa y manga larga c...  39,95 EUR
# 9   Blazer de cuello solapa con escote pico y mang...  49,95 EUR
# 5   Blazer de cuellos solapa y manga larga con hom...  39,95 EUR
# 15  Blazer de cuello solapa y manga larga con homb...  55,95 EUR
# 26      Blazer de cuello solapa y escote pico cruzado  59,95 EUR
# 14  Blazer entallada de cuello solapa y manga larg...  55,95 EUR
# ...

# %%
chalecos_df['Descripción'] = chalecos_df['Descripción'].str.title()

# %% [markdown]
# ### Limpieza Pantalones

# %%
pantalones_df = pd.read_csv("pantalones.csv")

# %%
pantalones_df.head()
# Out:
#                        Nombre     Precio  \
# 0        PANTALÓN JOGGER SOFT  29,95 EUR
# 1        PANTALÓN JOGGER SOFT  29,95 EUR
# 2        PANTALÓN JOGGER SOFT  25,95 EUR
# 3  PANTALÓN TOBILLERO BRILLOS  25,95 EUR
# 4        PANTALÓN LARGO EVASÉ  29,95 EUR
#
#                                          Descripción           Color Categoría
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo    Prenda
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro    Prenda
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro    Prenda
# 3         Pantalón de tiro alto con cintura elástica           Negro    Prenda
# 4                Pantalón de tiro bajo con trabillas  Gris antracita    Prenda

# %%
pantalones_df.tail()
# Out:
#                                 Nombre     Precio  \
# 25         PANTALÓN BOXER VIVO LATERAL  35,95 EUR
# 26         PANTALÓN JOGGER TEXTO BANDA  35,95 EUR
# 27  PANTALÓN FELPA TEXTO BANDA LATERAL  35,95 EUR
# 28   PANTALÓN FLARE INTERLOCK COSTURAS  25,95 EUR
# 29  BERMUDA LARGA PINZAS ZW COLLECTION  35,95 EUR
#
#                                           Descripción           Color  \
# 25  Pantalón de tiro medio con cintura elástica aj...  Petróleo claro
# 26  Leggings semitransparente de tiro alto con cin...      Gris medio
# 27        Pantalón de tiro medio con cintura elástica          Marino
# 28         Pantalón de tiro alto con cintura elástica          Marrón
# 29         Pantalón de tiro alto con cintura elástica           Khaki
#
#    Categoría
# 25    Prenda
# 26    Prenda
# 27    Prenda
# 28    Prenda
# 29    Prenda

# %%
pantalones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       30 non-null     object
#  1   Precio       30 non-null     object
#  2   Descripción  30 non-null     object
#  3   Color        30 non-null     object
#  4   Categoría    30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
pantalones_df.shape
# Out:
# (30, 5)

# %%
print(pantalones_df.isnull().sum())
# Out:
# Nombre         0
# Precio         0
# Descripción    0
# Color          0
# Categoría      0
# dtype: int64

# %% [markdown]
# pantalones_df['categoría'] = pantalones_df['categoría'].str.title()

# %%
pantalones_df.columns = pantalones_df.columns.str.capitalize()

# %%
pantalones_df['Nombre'] = pantalones_df['Nombre'].apply(lambda x: x.split(" - ")[0] if isinstance(x, str) and " - " in x else x)

# %%
with pd.option_context('display.max_colwidth', None):
    
    def quitar_despues_primer_punto(texto):
        partes = texto.split('.') 
        return partes[0].strip()  

    

    
    pantalones_df['Descripción'] = pantalones_df['Descripción'].apply(quitar_despues_primer_punto)

    
    print(pantalones_df['Descripción'])

    
    pantalones_df.to_csv('pantalones.csv', index=False)
# Out:
# 0                  Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado
# 1                  Pantalón de tiro alto con doble cintura elástica ajustable con cordón y tejido combinado
# 2                   Pantalón tobillero de tiro alto con detalle de costuras marcadas en delantero y espalda
# 3                                                                Pantalón de tiro alto con cintura elástica
# 4                                                                       Pantalón de tiro bajo con trabillas
# 5                                                                 Pantalón de tiro medio y cintura elástica
# 6                                                                                     ZARA WOMAN COLLECTION
# 7                                                                Pantalón de tiro alto con cintura elástica
# 8                                                                                     ZARA WOMAN COLLECTION
# ...

# %%
pantalones_df.head()
# Out:
#                        Nombre     Precio  \
# 0        PANTALÓN JOGGER SOFT  29,95 EUR
# 1        PANTALÓN JOGGER SOFT  29,95 EUR
# 2        PANTALÓN JOGGER SOFT  25,95 EUR
# 3  PANTALÓN TOBILLERO BRILLOS  25,95 EUR
# 4        PANTALÓN LARGO EVASÉ  29,95 EUR
#
#                                          Descripción           Color Categoría
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo    Prenda
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro    Prenda
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro    Prenda
# 3         Pantalón de tiro alto con cintura elástica           Negro    Prenda
# 4                Pantalón de tiro bajo con trabillas  Gris antracita    Prenda

# %%
pantalones_df['Nombre'] = pantalones_df['Nombre'].str.title()

# %%
pantalones_df.head()
# Out:
#                        Nombre     Precio  \
# 0        Pantalón Jogger Soft  29,95 EUR
# 1        Pantalón Jogger Soft  29,95 EUR
# 2        Pantalón Jogger Soft  25,95 EUR
# 3  Pantalón Tobillero Brillos  25,95 EUR
# 4        Pantalón Largo Evasé  29,95 EUR
#
#                                          Descripción           Color Categoría
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo    Prenda
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro    Prenda
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro    Prenda
# 3         Pantalón de tiro alto con cintura elástica           Negro    Prenda
# 4                Pantalón de tiro bajo con trabillas  Gris antracita    Prenda

# %%
zapatos_df.rename(columns={'Colores': 'Color'}, inplace=True)
jerseys_df.rename(columns={'Colores': 'Color'}, inplace=True)

# %%
columnas_ordenadas = ['Nombre', 'Descripción', 'Color', 'Precio', 'Categoría']

zapatos_df = zapatos_df[columnas_ordenadas]
jerseys_df = jerseys_df[columnas_ordenadas]
bolsos_df2 = bolsos_df2[columnas_ordenadas]
abrigos_df2 = abrigos_df2[columnas_ordenadas]
camisas_df = camisas_df[columnas_ordenadas]
vestidos_df = vestidos_df[columnas_ordenadas]
chalecos_df = chalecos_df[columnas_ordenadas]
pantalones_df = pantalones_df[columnas_ordenadas]

# %%
zapatos_df.head()
# Out:
#                       Nombre  \
# 0        Botín Plano Picados
# 1        Botín Plano Picados
# 2  Botín Plano Piel Con Pelo
# 3  Botín Plano Piel Con Pelo
# 4          Botín Cowboy Piel
#
#                                          Descripción   Color     Precio  \
# 0  Zapato tipo botín plano. Detalles en picado. T...  Marrón  39,95 EUR
# 1  Zapato tipo botín plano. Detalles en picado. T...  Marrón  39,95 EUR
# 2  Zapato tipo botín en piel con pelo. Caña ancha...  Marrón  99,95 EUR
# 3  Zapato tipo botín en piel con pelo. Caña ancha...  Marrón  99,95 EUR
# 4  Zapato tipo botín en piel. Estilo cowboy. Elás...   Negro  69,95 EUR
#
#   Categoría
# 0   Calzado
# 1   Calzado
# 2   Calzado
# 3   Calzado
# 4   Calzado

# %%
jerseys_df.head()
# Out:
#                            Nombre  \
# 0    Jersey Punto Jacquard Animal
# 1  Jersey Punto Botones Laterales
# 2  Jersey Romántico Punto Calados
# 3   Chaqueta Punto Cuello Bufanda
# 4            Jersey Punto Abierto
#
#                                          Descripción     Color     Color  \
# 0                                    Acabados en rib  Leopardo  Leopardo
# 1                 Bajo acabado con botones laterales      Gris      Gris
# 2  Acabados con volantes y bajo con cordón delantero     Crudo     Crudo
# 3                          Escote pico y manga larga      Gris      Gris
# 4                         Detalle de tiras laterales     Negro     Negro
#
#       Precio Categoría
# 0  29,95 EUR    Prenda
# 1  27,95 EUR    Prenda
# 2  49,95 EUR    Prenda
# 3  29,95 EUR    Prenda
# 4  39,95 EUR    Prenda

# %%
jerseys_df = jerseys_df.loc[:, ~jerseys_df.columns.duplicated()]


jerseys_df.head()
# Out:
#                            Nombre  \
# 0    Jersey Punto Jacquard Animal
# 1  Jersey Punto Botones Laterales
# 2  Jersey Romántico Punto Calados
# 3   Chaqueta Punto Cuello Bufanda
# 4            Jersey Punto Abierto
#
#                                          Descripción     Color     Precio  \
# 0                                    Acabados en rib  Leopardo  29,95 EUR
# 1                 Bajo acabado con botones laterales      Gris  27,95 EUR
# 2  Acabados con volantes y bajo con cordón delantero     Crudo  49,95 EUR
# 3                          Escote pico y manga larga      Gris  29,95 EUR
# 4                         Detalle de tiras laterales     Negro  39,95 EUR
#
#   Categoría
# 0    Prenda
# 1    Prenda
# 2    Prenda
# 3    Prenda
# 4    Prenda

# %%
bolsos_df2.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción   Color     Precio  \
# 0       Bolso formato mini saca en efecto terciopelo    Ocre  39,95 EUR
# 1       Bolso formato maxi saca en efecto terciopelo   Negro  49,95 EUR
# 2         Bolso formato de hombro con forma alargada   Negro  35,95 EUR
# 3                 Bolso formato bandolera en serraje  Marron  55,95 EUR
# 4  Bolso de hombro de formato ovalado con efecto ...   Negro  35,95 EUR
#
#    Categoría
# 0  Accesorio
# 1  Accesorio
# 2  Accesorio
# 3  Accesorio
# 4  Accesorio

# %%
abrigos_df2.head()
# Out:
#                     Nombre                                        Descripción  \
# 0    Abrigo Largo Con Lana              Abrigo de cuello solapa y manga larga
# 1  Abrigo Cruzado Con Lana              Abrigo de cuello solapa y manga larga
# 2     Abrigo Oversize Soft              Abrigo de cuello solapa y manga larga
# 3     Abrigo Oversize Soft                   Abrigo con capucha y manga larga
# 4     Abrigo Oversize Soft  Anorak acolchado resistente al agua y al vient...
#
#          Color     Precio Categoría
# 0        Crudo  89,95 EUR    Prenda
# 1         Rojo  49,95 EUR    Prenda
# 2      Tostado  39,95 EUR    Prenda
# 3  Camel claro  49,95 EUR    Prenda
# 4        Negro  69,95 EUR    Prenda

# %%
chalecos_df.head()
# Out:
#                              Nombre  \
# 0     Blazer Sin Solapa Lentejuelas
# 1     Blazer Sin Solapa Lentejuelas
# 2               Blazer Corta Brillo
# 3  Blazer Oversize Raya Diplomática
# 4          Chaleco Raya Diplomática
#
#                                          Descripción           Color  \
# 0      Blazer Sin Solapa Con Manga Larga Y Hombreras   Negro / Plata
# 1  Blazer De Cuello Sin Solapa Y Manga Larga Con ...           Negro
# 2              Blazer Corta Con Tejido Efecto Brillo   Negro / Plata
# 3  Blazer Oversize De Cuello Solapa Y Manga Larga...     Gris oscuro
# 4                Chaleco De Escote Pico Y Manga Sisa  Gris antracita
#
#       Precio Categoría
# 0  59,95 EUR    Prenda
# 1  59,95 EUR    Prenda
# 2  49,95 EUR    Prenda
# 3  59,95 EUR    Prenda
# 4  25,95 EUR    Prenda

# %%
vestidos_df.head()
# Out:
#                                 Nombre  \
# 0          Vestido Mini Punto Cinturón
# 1          Vestido Mini Punto Cinturón
# 2              Vestido Midi Punto Liso
# 3              Vestido Midi Terciopelo
# 4  Vestido Mini Lentejuelas Asimétrico
#
#                                          Descripción           Color  \
# 0             Vestido de cuello redondo y manga sisa  Negro / Marrón
# 1  Vestido de cuello barco y manga larga con apli...  Negro / Marrón
# 2  Vestido de cuello halter con escote pico fluid...       Azul pato
# 3  Vestido de cuello subido y manga larga asimétrica     Rojo oscuro
# 4           Vestido de escote pico y tirantes anchos            Rojo
#
#       Precio Categoría
# 0  35,95 EUR    Prenda
# 1  35,95 EUR    Prenda
# 2  39,95 EUR    Prenda
# 3  29,95 EUR    Prenda
# 4  39,95 EUR    Prenda

# %%
pantalones_df.head()
# Out:
#                        Nombre  \
# 0        Pantalón Jogger Soft
# 1        Pantalón Jogger Soft
# 2        Pantalón Jogger Soft
# 3  Pantalón Tobillero Brillos
# 4        Pantalón Largo Evasé
#
#                                          Descripción           Color  \
# 0  Pantalón de tiro alto con doble cintura elásti...           Crudo
# 1  Pantalón de tiro alto con doble cintura elásti...     Camel claro
# 2  Pantalón tobillero de tiro alto con detalle de...     Khaki claro
# 3         Pantalón de tiro alto con cintura elástica           Negro
# 4                Pantalón de tiro bajo con trabillas  Gris antracita
#
#       Precio Categoría
# 0  29,95 EUR    Prenda
# 1  29,95 EUR    Prenda
# 2  25,95 EUR    Prenda
# 3  25,95 EUR    Prenda
# 4  29,95 EUR    Prenda

# %%
dataframes = [bolsos_df2, abrigos_df2, camisas_df, zapatos_df, jerseys_df, vestidos_df, chalecos_df, pantalones_df]


df_total = pd.concat(dataframes, ignore_index=True)

# %%
df_total.head()
# Out:
#                                         Nombre  \
# 0                    Mini Saca Terciopelo Flor
# 1                  Maxi Saca Efecto Terciopelo
# 2                     Bolso De Hombro Alargado
# 3                Bandolera Efecto Coco Serraje
# 4  Bolso De Hombro Ovalado Con Efecto Engomado
#
#                                          Descripción   Color     Precio  \
# 0       Bolso formato mini saca en efecto terciopelo    Ocre  39,95 EUR
# 1       Bolso formato maxi saca en efecto terciopelo   Negro  49,95 EUR
# 2         Bolso formato de hombro con forma alargada   Negro  35,95 EUR
# 3                 Bolso formato bandolera en serraje  Marron  55,95 EUR
# 4  Bolso de hombro de formato ovalado con efecto ...   Negro  35,95 EUR
#
#    Categoría
# 0  Accesorio
# 1  Accesorio
# 2  Accesorio
# 3  Accesorio
# 4  Accesorio

# %%
df_total.shape
# Out:
# (209, 5)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       209 non-null    object
#  1   Descripción  209 non-null    object
#  2   Color        209 non-null    object
#  3   Precio       209 non-null    object
#  4   Categoría    209 non-null    object
# dtypes: object(5)
# memory usage: 8.3+ KB

# %%
df_total.to_csv("dftotal.csv", index=False)
